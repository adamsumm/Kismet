# %%
if False:
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet.ebnv
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_initialization.ebnf
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_sequence.ebnf

# %%
import KismetSequence

# %%
sequence = KismetSequence.KismetSequence(sequence_file = 'gtbbt.seq')#'gtbbt.seq')
# Out:
# SEQUENCE STATEMENT [('Load', [('File', 'fantasy_broad.kismet'), ('TRACERY', []), ('File', '../tracery/fantasy.tracery')])]
# SEQUENCE STATEMENT [('Initialize', [('File', 'fantasy_setting.init')])]
# INITIALIZATION []
# SEQUENCE STATEMENT [('Run', [('Until', [('UntilClauses', [('Duration', [('Num', '10'), ('Name', 'steps')])])])])]

# %%
# %%time
from IPython.display import clear_output


clear_output(wait=True)
sequence()
# Out:
# Running Kismet Sequence from "gtbbt.seq"
# Starting New Step: Loading ['fantasy_broad.kismet'] with Tracery Files ['../tracery/fantasy.tracery']
# TRAIT introvert Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['introvert'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['talk'])], propensityASP=['propensity(talk, -3, introvert,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, introvert),\n\t\tis(ACTION_NAME,talk).'], opposition='extrovert')
# TRAIT extrovert Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['extrovert'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['talk'])], propensityASP=['propensity(talk, 3, extrovert, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, extrovert),\n\t\tis(ACTION_NAME,talk).'], opposition='introvert')
# TRAIT curious Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['curious'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['risky'])], propensityASP=['propensity(risky, 3, curious,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, curious),\n\t\tis(ACTION_NAME,risky).'], opposition='cautious')
# TRAIT cautious Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['cautious'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['risky'])], propensityASP=['propensity(risky, -3, cautious, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, cautious),\n\t\tis(ACTION_NAME,risky).'], opposition='curious')
# TRAIT bully Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['bully'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['mean']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['kind'])], propensityASP=['propensity(mean, 3, bully,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, bully),\n\t\tis(ACTION_NAME,mean).', 'propensity(kind, -3, bully,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, bully),\n\t\tis(ACTION_NAME,kind).'], opposition='carer')
# TRAIT carer Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['carer'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['mean']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['kind'])], propensityASP=['propensity(mean, -3, carer, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, carer),\n\t\tis(ACTION_NAME,mean).', 'propensity(kind, 3, carer, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, carer),\n\t\tis(ACTION_NAME,kind).'], opposition='bully')
# TRAIT scholar Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['scholar'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['scholarly'])], propensityASP=['propensity(scholarly, 3, scholar,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, scholar),\n\t\tis(ACTION_NAME,scholarly).'], opposition='ignoramus')
# TRAIT ignoramus Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['ignoramus'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['scholarly'])], propensityASP=['propensity(scholarly, -3, ignoramus, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, ignoramus),\n\t\tis(ACTION_NAME,scholarly).'], opposition='scholar')
# TRAIT conscientious Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['conscientious'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['thoughtful']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['careless'])], propensityASP=['propensity(thoughtful, 3, conscientious,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, conscientious),\n\t\tis(ACTION_NAME,thoughtful).', 'propensity(careless, -3, conscientious,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, conscientious),\n\t\tis(ACTION_NAME,careless).'], opposition='careless')
# TRAIT careless Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['careless'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['thoughtful']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['careless'])], propensityASP=['propensity(thoughtful, -3, careless, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, careless),\n\t\tis(ACTION_NAME,thoughtful).', 'propensity(careless, 3, careless, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, careless),\n\t\tis(ACTION_NAME,careless).'], opposition='conscientious')
# TRAIT agreeable Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['agreeable'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['agree']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['critical'])], propensityASP=['propensity(agree, 3, agreeable,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, agreeable),\n\t\tis(ACTION_NAME,agree).', 'propensity(critical, -3, agreeable,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, agreeable),\n\t\tis(ACTION_NAME,critical).'], opposition='critical')
# TRAIT critical Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['critical'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['agree']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['critical'])], propensityASP=['propensity(agree, -3, critical, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, critical),\n\t\tis(ACTION_NAME,agree).', 'propensity(critical, 3, critical, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, critical),\n\t\tis(ACTION_NAME,critical).'], opposition='agreeable')
# TRAIT compassionate Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['compassionate'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['thoughtful']), Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['kind']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['mean'])], propensityASP=['propensity(thoughtful, 3, compassionate,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, compassionate),\n\t\tis(ACTION_NAME,thoughtful).', 'propensity(kind, 3, compassionate,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, compassionate),\n\t\tis(ACTION_NAME,kind).', 'propensity(mean, -3, compassionate,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, compassionate),\n\t\tis(ACTION_NAME,mean).'], opposition='indifferent')
# TRAIT indifferent Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['indifferent'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['thoughtful']), Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['kind']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['mean'])], propensityASP=['propensity(thoughtful, -3, indifferent, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, indifferent),\n\t\tis(ACTION_NAME,thoughtful).', 'propensity(kind, -3, indifferent, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, indifferent),\n\t\tis(ACTION_NAME,kind).', 'propensity(mean, 3, indifferent, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, indifferent),\n\t\tis(ACTION_NAME,mean).'], opposition='compassionate')
# TRAIT neurotic Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['neurotic'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['worry']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['bold'])], propensityASP=['propensity(worry, 3, neurotic,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, neurotic),\n\t\tis(ACTION_NAME,worry).', 'propensity(bold, -3, neurotic,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, neurotic),\n\t\tis(ACTION_NAME,bold).'], opposition='confident')
# TRAIT confident Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['confident'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['worry']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['bold'])], propensityASP=['propensity(worry, -3, confident, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, confident),\n\t\tis(ACTION_NAME,worry).', 'propensity(bold, 3, confident, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, confident),\n\t\tis(ACTION_NAME,bold).'], opposition='neurotic')
# TRAIT family_oriented Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['family_oriented'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[['is(Self,related_to,Other)']], modified_tags=['thoughtful']), Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[['is(Self,related_to,Other)']], modified_tags=['kind']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[['is(Self,related_to,Other)']], modified_tags=['mean'])], propensityASP=['propensity(thoughtful, 3, family_oriented,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, family_oriented),\n\t\tis(Self,related_to,Other),\n\t\tis(ACTION_NAME,thoughtful).', 'propensity(kind, 3, family_oriented,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, family_oriented),\n\t\tis(Self,related_to,Other),\n\t\tis(ACTION_NAME,kind).', 'propensity(mean, -3, family_oriented,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, family_oriented),\n\t\tis(Self,related_to,Other),\n\t\tis(ACTION_NAME,mean).'], opposition='')
# TRAIT duty_bound Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['duty_bound'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['duty']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['free'])], propensityASP=['propensity(duty, 3, duty_bound,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, duty_bound),\n\t\tis(ACTION_NAME,duty).', 'propensity(free, -3, duty_bound,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, duty_bound),\n\t\tis(ACTION_NAME,free).'], opposition='free_spirited')
# TRAIT free_spirited Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['free_spirited'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['duty']), Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=[], modified_tags=['free'])], propensityASP=['propensity(duty, -3, free_spirited, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, free_spirited),\n\t\tis(ACTION_NAME,duty).', 'propensity(free, 3, free_spirited, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, free_spirited),\n\t\tis(ACTION_NAME,free).'], opposition='duty_bound')
# TRAIT romantic Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['romantic'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['romance'])], propensityASP=['propensity(romance, 3, romantic,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, romantic),\n\t\tis(ACTION_NAME,romance).'], opposition='')
# TRAIT gruff Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['gruff'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['critical']), Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[['is(Self,likes,Other)']], modified_tags=['agree'])], propensityASP=['propensity(critical, 3, gruff,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, gruff),\n\t\tis(ACTION_NAME,critical).', 'propensity(agree, 3, gruff,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, gruff),\n\t\tis(Self,likes,Other),\n\t\tis(ACTION_NAME,agree).'], opposition='')
# TRAIT feral Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['feral'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-4, constraints=[], modified_tags=['talk']), Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['risky']), Propensity(is_propensity=True, is_goto=False, valence=-2, constraints=[], modified_tags=['religious'])], propensityASP=['propensity(talk, -4, feral,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, feral),\n\t\tis(ACTION_NAME,talk).', 'propensity(risky, 3, feral,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, feral),\n\t\tis(ACTION_NAME,risky).', 'propensity(religious, -2, feral,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, feral),\n\t\tis(ACTION_NAME,religious).'], opposition='')
# TRAIT comic Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['comic'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['silly']), Propensity(is_propensity=True, is_goto=False, valence=-1, constraints=[], modified_tags=['thoughtful'])], propensityASP=['propensity(silly, 3, comic,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, comic),\n\t\tis(ACTION_NAME,silly).', 'propensity(thoughtful, -1, comic,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, comic),\n\t\tis(ACTION_NAME,thoughtful).'], opposition='stern')
# TRAIT stern Trait(is_default=False, is_num=False, is_trait=True, is_status=False, alternative_names=['stern'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['silly']), Propensity(is_propensity=True, is_goto=False, valence=-1, constraints=[], modified_tags=['thoughtful'])], propensityASP=['propensity(silly, -3, stern, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, stern),\n\t\tis(ACTION_NAME,silly).', 'propensity(thoughtful, 1, stern, Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, stern),\n\t\tis(ACTION_NAME,thoughtful).'], opposition='comic')
# TRAIT rare_things_rare Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['rare_things_rare'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-2, constraints=[], modified_tags=['rare'])], propensityASP=['propensity(rare, -2, rare_things_rare,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, rare_things_rare),\n\t\tis(ACTION_NAME,rare).'], opposition='')
# TRAIT do_more_specific_things Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['do_more_specific_things'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[], modified_tags=['specific'])], propensityASP=['propensity(specific, 3, do_more_specific_things,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, do_more_specific_things),\n\t\tis(ACTION_NAME,specific).'], opposition='')
# TRAIT stay_in_confinement Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['stay_in_confinement'], arguments={'>': 'Self', '<': 'null', '^': 'null', '*': 'null', '@': 'Location'}, propensities=[Propensity(is_propensity=False, is_goto=True, valence=6, constraints=[['is(Self,confined,Location)']], modified_tags=[])], propensityASP=['go_to_propensity(go_to_location, 6, stay_in_confinement,Self, null, null, null, Location )  :- \n\t\tis(Self, stay_in_confinement),\n\t\tis(Self,confined,Location).'], opposition='')
# TRAIT visiting_places_you_like Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['visiting_places_you_like'], arguments={'>': 'Self', '<': 'null', '^': 'null', '*': 'null', '@': 'Location'}, propensities=[Propensity(is_propensity=False, is_goto=True, valence=1, constraints=[['is(Self,tourist,Location)']], modified_tags=[])], propensityASP=['go_to_propensity(go_to_location, 1, visiting_places_you_like,Self, null, null, null, Location )  :- \n\t\tis(Self, visiting_places_you_like),\n\t\tis(Self,tourist,Location).'], opposition='')
# TRAIT visiting_as_regular Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['visiting_as_regular'], arguments={'>': 'Self', '<': 'null', '^': 'null', '*': 'null', '@': 'Location'}, propensities=[Propensity(is_propensity=False, is_goto=True, valence=3, constraints=[['is(Self,regular,Location)']], modified_tags=[])], propensityASP=['go_to_propensity(go_to_location, 3, visiting_as_regular,Self, null, null, null, Location )  :- \n\t\tis(Self, visiting_as_regular),\n\t\tis(Self,regular,Location).'], opposition='')
# TRAIT romantic_towards_crush Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['romantic_towards_crush'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=3, constraints=[['is(Self,crushing_on,Other)']], modified_tags=['romance'])], propensityASP=['propensity(romance, 3, romantic_towards_crush,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, romantic_towards_crush),\n\t\tis(Self,crushing_on,Other),\n\t\tis(ACTION_NAME,romance).'], opposition='')
# TRAIT stay_at_hometown Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['stay_at_hometown'], arguments={'>': 'Self', '<': 'null', '^': 'null', '*': 'null', '@': 'Location'}, propensities=[Propensity(is_propensity=False, is_goto=True, valence=3, constraints=['is(Self,hometown,V_Self_hometown), is(Location,hometown,V_Location_hometown), V_Self_hometown == V_Location_hometown'], modified_tags=[])], propensityASP=['go_to_propensity(go_to_location, 3, stay_at_hometown,Self, null, null, null, Location )  :- \n\t\tis(Self, stay_at_hometown),\n\t\tis(Self,hometown,V_Self_hometown), is(Location,hometown,V_Location_hometown), V_Self_hometown == V_Location_hometown.'], opposition='')
# TRAIT do_role_specific_actions Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['do_role_specific_actions'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=4, constraints=[], modified_tags=['role_specific'])], propensityASP=['propensity(role_specific, 4, do_role_specific_actions,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, do_role_specific_actions),\n\t\tis(ACTION_NAME,role_specific).'], opposition='')
# TRAIT go_to_locations_you_have_connection_with Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['go_to_locations_you_have_connection_with'], arguments={'>': 'Self', '<': 'null', '^': 'null', '*': 'null', '@': 'Location'}, propensities=[Propensity(is_propensity=False, is_goto=True, valence=5, constraints=[['is(Self,connected,Location)']], modified_tags=[])], propensityASP=['go_to_propensity(go_to_location, 5, go_to_locations_you_have_connection_with,Self, null, null, null, Location )  :- \n\t\tis(Self, go_to_locations_you_have_connection_with),\n\t\tis(Self,connected,Location).'], opposition='')
# TRAIT no_pedophilia Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['no_pedophilia'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-7, constraints=['is(Self,age,V_Self_age), V_Self_age >= 18', 'is(Other,age,V_Other_age), V_Other_age <= 17'], modified_tags=['romance'])], propensityASP=['propensity(romance, -7, no_pedophilia,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, no_pedophilia),\n\t\tis(Self,age,V_Self_age), V_Self_age >= 18,\n\t\tis(Other,age,V_Other_age), V_Other_age <= 17,\n\t\tis(ACTION_NAME,romance).'], opposition='')
# TRAIT family_ties Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['family_ties'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=1, constraints=[['is(Self,related_to,Other)']], modified_tags=['thoughtful']), Propensity(is_propensity=True, is_goto=False, valence=1, constraints=[['is(Self,related_to,Other)']], modified_tags=['kind']), Propensity(is_propensity=True, is_goto=False, valence=-1, constraints=[['is(Self,related_to,Other)']], modified_tags=['mean']), Propensity(is_propensity=True, is_goto=False, valence=1, constraints=[['is(Self,related_to,Other)']], modified_tags=['critical']), Propensity(is_propensity=True, is_goto=False, valence=-7, constraints=[['is(Self,related_to,Other)']], modified_tags=['romance'])], propensityASP=['propensity(thoughtful, 1, family_ties,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, family_ties),\n\t\tis(Self,related_to,Other),\n\t\tis(ACTION_NAME,thoughtful).', 'propensity(kind, 1, family_ties,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, family_ties),\n\t\tis(Self,related_to,Other),\n\t\tis(ACTION_NAME,kind).', 'propensity(mean, -1, family_ties,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, family_ties),\n\t\tis(Self,related_to,Other),\n\t\tis(ACTION_NAME,mean).', 'propensity(critical, 1, family_ties,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, family_ties),\n\t\tis(Self,related_to,Other),\n\t\tis(ACTION_NAME,critical).', 'propensity(romance, -7, family_ties,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, family_ties),\n\t\tis(Self,related_to,Other),\n\t\tis(ACTION_NAME,romance).'], opposition='')
# TRAIT mean_to_people_you_dislike1 Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['mean_to_people_you_dislike1'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=1, constraints=['is(Self,likes,Other,V_Self_likes_Other), V_Self_likes_Other <= -1'], modified_tags=['mean'])], propensityASP=['propensity(mean, 1, mean_to_people_you_dislike1,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, mean_to_people_you_dislike1),\n\t\tis(Self,likes,Other,V_Self_likes_Other), V_Self_likes_Other <= -1,\n\t\tis(ACTION_NAME,mean).'], opposition='')
# TRAIT mean_to_people_you_dislike2 Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['mean_to_people_you_dislike2'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-2, constraints=['is(Self,likes,Other,V_Self_likes_Other), V_Self_likes_Other >= 3'], modified_tags=['mean'])], propensityASP=['propensity(mean, -2, mean_to_people_you_dislike2,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, mean_to_people_you_dislike2),\n\t\tis(Self,likes,Other,V_Self_likes_Other), V_Self_likes_Other >= 3,\n\t\tis(ACTION_NAME,mean).'], opposition='')
# TRAIT mean_to_people_you_dislike3 Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['mean_to_people_you_dislike3'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-3, constraints=['is(Self,likes,Other,V_Self_likes_Other), V_Self_likes_Other >= 5'], modified_tags=['mean'])], propensityASP=['propensity(mean, -3, mean_to_people_you_dislike3,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, mean_to_people_you_dislike3),\n\t\tis(Self,likes,Other,V_Self_likes_Other), V_Self_likes_Other >= 5,\n\t\tis(ACTION_NAME,mean).'], opposition='')
# TRAIT nice_to_people_you_like1 Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['nice_to_people_you_like1'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-1, constraints=['is(Self,likes,Other,V_Self_likes_Other), V_Self_likes_Other >= 1'], modified_tags=['mean'])], propensityASP=['propensity(mean, -1, nice_to_people_you_like1,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, nice_to_people_you_like1),\n\t\tis(Self,likes,Other,V_Self_likes_Other), V_Self_likes_Other >= 1,\n\t\tis(ACTION_NAME,mean).'], opposition='')
# TRAIT people_are_usually_serious Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['people_are_usually_serious'], arguments={'>': 'Self', '<': 'DEFAULT_TARGET', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=-1, constraints=[], modified_tags=['silly'])], propensityASP=['propensity(silly, -1, people_are_usually_serious,Self, DEFAULT_TARGET, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,DEFAULT_TARGET,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, people_are_usually_serious),\n\t\tis(ACTION_NAME,silly).'], opposition='')
# TRAIT fail_when_interactin_with_person_who_dislikes_you1 Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['fail_when_interactin_with_person_who_dislikes_you1'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=1, constraints=['is(Other,likes,Self,V_Other_likes_Self), V_Other_likes_Self <= -1'], modified_tags=['failure'])], propensityASP=['propensity(failure, 1, fail_when_interactin_with_person_who_dislikes_you1,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, fail_when_interactin_with_person_who_dislikes_you1),\n\t\tis(Other,likes,Self,V_Other_likes_Self), V_Other_likes_Self <= -1,\n\t\tis(ACTION_NAME,failure).'], opposition='')
# TRAIT fail_when_interactin_with_person_who_dislikes_you2 Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['fail_when_interactin_with_person_who_dislikes_you2'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=2, constraints=['is(Other,likes,Self,V_Other_likes_Self), V_Other_likes_Self <= -3'], modified_tags=['failure'])], propensityASP=['propensity(failure, 2, fail_when_interactin_with_person_who_dislikes_you2,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, fail_when_interactin_with_person_who_dislikes_you2),\n\t\tis(Other,likes,Self,V_Other_likes_Self), V_Other_likes_Self <= -3,\n\t\tis(ACTION_NAME,failure).'], opposition='')
# TRAIT people_joke_with_joker Trait(is_default=True, is_num=False, is_trait=True, is_status=False, alternative_names=['people_joke_with_joker'], arguments={'>': 'Self', '<': 'Other', '^': 'DEFAULT_OBJECT', '*': 'DEFAULT_ACTION', '@': 'DEFAULT_LOCATION'}, propensities=[Propensity(is_propensity=True, is_goto=False, valence=1, constraints=['is(Other, comic)'], modified_tags=['silly'])], propensityASP=['propensity(silly, 1, people_joke_with_joker,Self, Other, DEFAULT_OBJECT, DEFAULT_ACTION, DEFAULT_LOCATION )  :- \n\t\taction(ACTION_NAME,Self,Other,DEFAULT_OBJECT,DEFAULT_ACTION,DEFAULT_LOCATION),\n\t\tis(Self, people_joke_with_joker),\n\t\tis(Other, comic),\n\t\tis(ACTION_NAME,silly).'], opposition='')
# TRAIT likes Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['likes', 'like', 'liked'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT loves Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['loves', 'love', 'loved'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT respects Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['respects', 'respect_towards'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT rivalry Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['rivalry'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT dissapointed_in Trait(is_default=False, is_num=False, is_trait=False, is_status=True, alternative_names=['dissapointed_in', 'disappointed_with'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT proud_of Trait(is_default=False, is_num=False, is_trait=False, is_status=True, alternative_names=['proud_of'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT embarrassed_by Trait(is_default=False, is_num=False, is_trait=False, is_status=True, alternative_names=['embarrassed_by'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT protective_of Trait(is_default=False, is_num=False, is_trait=False, is_status=True, alternative_names=['protective_of'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT friends_with Trait(is_default=False, is_num=False, is_trait=False, is_status=True, alternative_names=['friends_with'], arguments={'>': 'Self', '<': 'Other'}, propensities=[], propensityASP=[], opposition='')
# TRAIT happiness Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['happiness'], arguments={'>': 'Self'}, propensities=[], propensityASP=[], opposition='')
# TRAIT anger Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['anger'], arguments={'>': 'Self'}, propensities=[], propensityASP=[], opposition='')
# TRAIT tiredness Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['tiredness'], arguments={'>': 'Self'}, propensities=[], propensityASP=[], opposition='')
# TRAIT sadness Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['sadness'], arguments={'>': 'Self'}, propensities=[], propensityASP=[], opposition='')
# TRAIT guilt Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['guilt'], arguments={'>': 'Self'}, propensities=[], propensityASP=[], opposition='')
# TRAIT shame Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['shame'], arguments={'>': 'Self'}, propensities=[], propensityASP=[], opposition='')
# TRAIT self_worth Trait(is_default=False, is_num=True, is_trait=False, is_status=True, alternative_names=['self_worth'], arguments={'>': 'Self'}, propensities=[], propensityASP=[], opposition='')
# *************************POTENTIAL PROBLEMS*************************
# Locations: Not referenced in actions or traits
# 	opera_house
# 	boat
# 	classroom
# 	quad
# 	thieves_den
# 	amphitheatre
# 	library
# 	ballroom
# 	throne_room
# 	ruins
# 	smith
# 	dungeon
# 	garden
# 	auction_house
# 	shipyard
# 	mine
# 	kitchen
# 	elders_house
# 	docks
# 	marketplace
# 	temple
# 	tavern
# Tags: Not referenced in traits
# 	criticial
# 	work
# 	criminal
# 	angry
# 	mariner
# Tags: Referenced in traits but not found in actions
# 	agree
# Traits: Not referenced in actions
# 	curious
# 	confident
# 	romantic_towards_crush
# 	ignoramus
# 	nice_to_people_you_like1
# 	dissapointed_in
# 	embarrassed_by
# 	stay_in_confinement
# 	protective_of
# 	people_are_usually_serious
# 	romantic
# 	sadness
# 	mean_to_people_you_dislike2
# 	do_more_specific_things
# 	extrovert
# 	free_spirited
# 	family_ties
# 	visiting_as_regular
# 	no_pedophilia
# 	carer
# 	family_oriented
# 	friends_with
# 	proud_of
# 	stern
# 	visiting_places_you_like
# 	fail_when_interactin_with_person_who_dislikes_you1
# 	guilt
# 	feral
# 	fail_when_interactin_with_person_who_dislikes_you2
# 	cautious
# 	gruff
# 	people_joke_with_joker
# 	go_to_locations_you_have_connection_with
# 	rivalry
# 	stay_at_hometown
# 	mean_to_people_you_dislike1
# 	conscientious
# 	do_role_specific_actions
# 	introvert
# 	neurotic
# 	comic
# 	mean_to_people_you_dislike3
# 	careless
# 	critical
# 	rare_things_rare
# Traits: Referenced in actions but not found
# 	worker
# 	employee
# 	child
# 	diva
# 	coworker
# 	rival
# 	hometown
# 	auctioneer
# 	student
# 	tourist
# 	plotting_against
# 	guest
# 	researcher
# 	royalty
# 	ex_royalty
# 	free_sprited
# 	rich
# 	crushing_on
# 	patron
# 	fealty
# 	knows_personal_info_about
# 	sibling
# 	important
# 	devotion
# 	fears
# 	spy
# *************************Reference Section*************************
# Actions
# 	complain_to_and_make_annoyed
# 	hustle
# 	impress
# 	sulk
# 	insult_as_bully
# 	search_for_treasure
# 	cast_foreman
# 	flirt_at
# 	cast_treasure_hunter
# 	boss_miner_around
# 	work_at_mine
# 	cast_enforcer
# 	bitch_about_boss
# 	cast_archaelogist
# 	use_humor_to_spark_love
# 	curate_collection
# 	sell_wares
# 	pray
# 	assist_research
# 	acquire_ingredients
# 	hold_auction
# 	investigate_ruins
# 	develop_crush
# 	give_deal_to
# 	complain_to_compassionate
# 	sabotage_rival_treasure_hunter
# 	be_open_about_crush_and_burn
# 	perform_research
# 	sway_monarch_to_kindness
# 	annoy_diva_for_laughs
# 	cast_miner
# 	stock_books
# 	manage_dispute_between_miners
# 	praise_boss_to_resistance
# 	screw_up_ritual
# 	assist_student
# 	help_struggling_friend
# 	criticize
# 	consult_with_chancellor
# 	encourage_fellow_performer
# 	catalog_findings
# 	reject_romance
# 	become_annoyed_with_bard
# 	plot_about_sabotaging_romantic_rival
# 	argue_with_playmate
# 	joke_around_with
# 	discuss_collection
# 	be_amused_by_bard
# 	demand_a_new_piece
# 	acquire_artifacts
# 	boss_cooks_around
# 	cast_chancellor
# 	cast_monarch
# 	share_personal_info
# 	develop_begrudging_respect_towards
# 	make_imprudent_decree
# 	cast_monk
# 	banish_monarchling
# 	endanger_miners
# 	get_into_argument
# 	shush_patron
# 	commiserate_with_fellow_vendor
# 	perform_to_no_effect
# 	cast_ur_job
# 	have_crisis_of_faith
# 	cast_vendor
# 	strike_motherlode
# 	flirt_with
# 	collect_protection_fees
# 	amuse_with_performance
# 	perform_ritual
# 	help_really_struggling_person
# 	rough_up
# 	load_cargo
# 	cast_spy_master
# 	undercut
# 	support_banished_sibling
# 	hold_lecture
# 	make_callous_decree
# 	fight_seagull
# 	argue_with_treasure_hunter
# 	blow_up_love_triangle
# 	stand_up_for_friend_and_persuade
# 	make_benevolent_decree
# 	play
# 	send_underlings
# 	grouse_backstage
# 	worry_about_future
# 	worry_about_mortality
# 	find_treasure
# 	cast_professor
# 	create_culinary_masterpiece
# 	overcome_rivalry_to_work_together
# 	conspire_against
# 	stand_up_for_friend_and_fail
# 	cast_bard
# 	cast_dockworker
# 	have_catharsis
# 	sway_monarch_to_indifference
# 	shun_banished_sibling
# 	praise_boss
# 	make_judicious_decree
# 	insult
# 	bitch_about_boss_to_resistance
# 	be_open_about_crush
# 	chit_chat
# 	develop_recipe
# 	make_out_with
# 	pine_over
# 	provide_critical_feedback
# 	cast_chef
# 	play_together
# 	hold_boring_lecture
# 	mentor_cook
# 	argue_about_duty
# 	standup_to_enforcer_together
# 	manage_mine
# 	joke_around_with_the_wrong_person
# 	cast_curator
# 	cast_librarian
# 	convince_importance_of_duty
# 	trigger_trap
# 	try_to_help_struggling_friend
# 	try_to_impress_and_fail
# Patterns
# 	dislikes_friend
# 		 referenced in: stand_up_for_friend_and_persuade, stand_up_for_friend_and_fail
# 	non_joker
# 		 referenced in: joke_around_with_the_wrong_person
# Roles
# 	miner
# 		 referenced in: endanger_miners, boss_miner_around, manage_dispute_between_miners, work_at_mine, strike_motherlode, cast_miner
# 	professor
# 		 referenced in: hold_lecture, cast_professor, hold_boring_lecture, perform_research
# 	spy_master
# 		 referenced in: cast_spy_master, conspire_against, send_underlings
# 	monk
# 		 referenced in: cast_monk, pray, have_crisis_of_faith, perform_ritual, screw_up_ritual
# 	enforcer
# 		 referenced in: rough_up, cast_enforcer, collect_protection_fees
# 	chancellor
# 		 referenced in: sway_monarch_to_kindness, cast_chancellor, sway_monarch_to_indifference, consult_with_chancellor
# 	chef
# 		 referenced in: develop_recipe, cast_chef, boss_cooks_around, create_culinary_masterpiece, mentor_cook, acquire_ingredients
# 	librarian
# 		 referenced in: stock_books, shush_patron, cast_librarian, assist_student, assist_research
# 	treasure_hunter
# 		 referenced in: sabotage_rival_treasure_hunter, search_for_treasure, find_treasure, argue_with_treasure_hunter, cast_treasure_hunter, develop_begrudging_respect_towards, overcome_rivalry_to_work_together, trigger_trap
# 	curator
# 		 referenced in: curate_collection, cast_curator, discuss_collection, demand_a_new_piece, acquire_artifacts
# 	vendor
# ...
# 	guilt
# 	like
# 	stay_at_hometown
# 	mean_to_people_you_dislike1
# 	patron
# 		 referenced in: hold_auction
# 	anger
# 		 referenced in: fight_seagull
# 	curious
# 	indifferent
# 		 referenced in: sway_monarch_to_kindness, sway_monarch_to_indifference
# 	nice_to_people_you_like1
# 	age
# 		 referenced in: banish_monarchling, worry_about_mortality, play, play_together, argue_with_playmate, worry_about_future
# 	dissapointed_in
# 	embarrassed_by
# 	stay_in_confinement
# 	scholar
# 		 referenced in: assist_research
# 	love
# 	extrovert
# 	likes
# 		 referenced in: banish_monarchling, complain_to_and_make_annoyed, hustle, impress, endanger_miners, get_into_argument, insult_as_bully, shush_patron, flirt_at, commiserate_with_fellow_vendor, boss_miner_around, manage_dispute_between_miners, praise_boss_to_resistance, conspire_against, screw_up_ritual, strike_motherlode, overcome_rivalry_to_work_together, flirt_with, assist_student, stand_up_for_friend_and_fail, collect_protection_fees, bitch_about_boss, use_humor_to_spark_love, help_struggling_friend, criticize, consult_with_chancellor, encourage_fellow_performer, try_to_impress_and_fail, sell_wares, amuse_with_performance, reject_romance, shun_banished_sibling, praise_boss, help_really_struggling_person, rough_up, become_annoyed_with_bard, make_judicious_decree, plot_about_sabotaging_romantic_rival, assist_research, bitch_about_boss_to_resistance, insult, acquire_ingredients, argue_with_playmate, be_open_about_crush, chit_chat, joke_around_with, undercut, make_out_with, be_amused_by_bard, support_banished_sibling, demand_a_new_piece, give_deal_to, provide_critical_feedback, boss_cooks_around, play_together, mentor_cook, hold_boring_lecture, hold_lecture, make_callous_decree, complain_to_compassionate, argue_about_duty, standup_to_enforcer_together, joke_around_with_the_wrong_person, sabotage_rival_treasure_hunter, share_personal_info, argue_with_treasure_hunter, blow_up_love_triangle, stand_up_for_friend_and_persuade, make_benevolent_decree, convince_importance_of_duty, make_imprudent_decree, develop_begrudging_respect_towards, grouse_backstage, try_to_help_struggling_friend, annoy_diva_for_laughs
# 	feral
# 	cautious
# 	people_joke_with_joker
# 	loves
# 		 referenced in: use_humor_to_spark_love, be_open_about_crush, blow_up_love_triangle, flirt_at, make_out_with, be_open_about_crush_and_burn, pine_over, reject_romance, flirt_with, plot_about_sabotaging_romantic_rival
# 	conscientious
# 	rich
# 		 referenced in: find_treasure
# 	sibling
# 		 referenced in: shun_banished_sibling, support_banished_sibling
# 	introvert
# 	neurotic
# 	comic
# 	fears
# 		 referenced in: rough_up, standup_to_enforcer_together
# 	happiness
# 		 referenced in: worry_about_mortality, play, play_together, create_culinary_masterpiece, argue_with_playmate
# 	critical
# 		 referenced in: agreeable, gruff, critical, family_ties
# 	spy
# 		 referenced in: send_underlings
# 	romantic_towards_crush
# 	worker
# 		 referenced in: boss_cooks_around, mentor_cook
# 	compassionate
# 		 referenced in: sway_monarch_to_kindness, complain_to_and_make_annoyed, sway_monarch_to_indifference, complain_to_compassionate
# 	diva
# 		 referenced in: annoy_diva_for_laughs
# 	mean_to_people_you_dislike2
# 	hometown
# 		 referenced in: banish_monarchling
# 	family_ties
# 	auctioneer
# 		 referenced in: demand_a_new_piece, hold_auction
# 	no_pedophilia
# 	carer
# 	researcher
# 	gruff
# 	rivalry
# 	agreeable
# 		 referenced in: provide_critical_feedback
# 	ex_royalty
# 		 referenced in: banish_monarchling, shun_banished_sibling, support_banished_sibling
# 	free_sprited
# 		 referenced in: argue_about_duty, convince_importance_of_duty
# 	fealty
# 		 referenced in: make_judicious_decree, make_imprudent_decree, make_callous_decree, make_benevolent_decree
# 	mean_to_people_you_dislike3
# 	devotion
# 		 referenced in: pray, have_crisis_of_faith, perform_ritual, screw_up_ritual
# 	careless
# 		 referenced in: conscientious, careless
# 	rare_things_rare
# 	bully
# 		 referenced in: insult_as_bully, insult
# 	ignoramus
# 	employee
# 		 referenced in: praise_boss_to_resistance, bitch_about_boss, bitch_about_boss_to_resistance, praise_boss
# 	people_are_usually_serious
# 	romantic
# 	tiredness
# 		 referenced in: load_cargo, stock_books, worry_about_mortality, search_for_treasure, perform_to_no_effect, work_at_mine, worry_about_future
# 	student
# 		 referenced in: hold_lecture, assist_student, hold_boring_lecture
# 	plotting_against
# 		 referenced in: conspire_against, send_underlings
# 	guest
# 		 referenced in: shush_patron, assist_research, create_culinary_masterpiece
# 	friends_with
# 	fail_when_interactin_with_person_who_dislikes_you2
# 	duty_bound
# 		 referenced in: argue_about_duty, convince_importance_of_duty
# 	go_to_locations_you_have_connection_with
# 	royalty
# 		 referenced in: banish_monarchling, shun_banished_sibling, support_banished_sibling
# 	crushing_on
# 		 referenced in: use_humor_to_spark_love, be_open_about_crush_and_burn, be_open_about_crush, develop_crush
# 	do_role_specific_actions
# 	knows_personal_info_about
# 		 referenced in: share_personal_info
# 	important
# 		 referenced in: conspire_against
# 	respects
# 		 referenced in: endanger_miners, sabotage_rival_treasure_hunter, discuss_collection, manage_dispute_between_miners, create_culinary_masterpiece, strike_motherlode
# Requirements:
# chit_chat
# complain_to_and_make_annoyed
# 	References: compassionate
# complain_to_compassionate
# 	References: compassionate
# flirt_at
# flirt_with
# use_humor_to_spark_love
# be_open_about_crush
# 	References: loves, crushing_on
# be_open_about_crush_and_burn
# 	References: loves, crushing_on
# develop_crush
# pine_over
# make_out_with
# 	References: love
# blow_up_love_triangle
# 	References: love
# plot_about_sabotaging_romantic_rival
# 	References: love
# reject_romance
# 	References: loves, likes
# insult_as_bully
# 	References: bully
# insult
# 	References: bully
# sulk
# 	References: self_worth
# have_catharsis
# 	References: self_worth
# try_to_help_struggling_friend
# 	References: likes, self_worth
# help_struggling_friend
# 	References: like, self_worth
# share_personal_info
# help_really_struggling_person
# 	References: self_worth
# joke_around_with
# joke_around_with_the_wrong_person
# 	References: non_joker
# criticize
# provide_critical_feedback
# 	References: agreeable
# get_into_argument
# 	References: likes
# impress
# try_to_impress_and_fail
# stand_up_for_friend_and_persuade
# 	References: dislikes_friend
# stand_up_for_friend_and_fail
# 	References: dislikes_friend
# pray
# 	References: monk
# perform_ritual
# 	References: monk
# screw_up_ritual
# 	References: monk
# have_crisis_of_faith
# 	References: monk
# manage_mine
# 	References: foreman
# boss_miner_around
# 	References: miner, foreman
# manage_dispute_between_miners
# 	References: likes, miner, foreman
# endanger_miners
# 	References: miner, foreman
# strike_motherlode
# 	References: miner, foreman
# work_at_mine
# 	References: miner
# hold_auction
# 	References: auctioneer, patron
# discuss_collection
# 	References: curator
# demand_a_new_piece
# 	References: auctioneer, curator
# curate_collection
# 	References: curator
# acquire_artifacts
# 	References: curator
# sell_wares
# 	References: vendor
# give_deal_to
# 	References: vendor, likes
# hustle
# 	References: vendor, likes
# commiserate_with_fellow_vendor
# 	References: vendor
# undercut
# 	References: vendor, likes
# standup_to_enforcer_together
# 	References: vendor, fears
# collect_protection_fees
# 	References: enforcer, vendor
# rough_up
# 	References: enforcer, vendor
# load_cargo
# 	References: dockworker
# fight_seagull
# 	References: dockworker
# stock_books
# 	References: librarian
# shush_patron
# 	References: guest, librarian
# assist_research
# 	References: guest, scholar, librarian
# assist_student
# 	References: librarian, student
# acquire_ingredients
# 	References: vendor, chef
# develop_recipe
# 	References: chef
# boss_cooks_around
# 	References: chef, worker
# mentor_cook
# 	References: chef, worker
# create_culinary_masterpiece
# 	References: guest, chef
# bitch_about_boss
# 	References: coworker, employee
# bitch_about_boss_to_resistance
# 	References: likes, coworker, employee
# praise_boss
# 	References: likes, coworker, employee
# praise_boss_to_resistance
# 	References: likes, coworker, employee
# search_for_treasure
# 	References: treasure_hunter
# find_treasure
# 	References: treasure_hunter
# investigate_ruins
# 	References: archaelogist
# trigger_trap
# 	References: treasure_hunter
# sabotage_rival_treasure_hunter
# 	References: treasure_hunter, rival
# overcome_rivalry_to_work_together
# 	References: treasure_hunter, rival
# catalog_findings
# 	References: archaelogist
# argue_with_treasure_hunter
# 	References: archaelogist, treasure_hunter, rival
# develop_begrudging_respect_towards
# 	References: archaelogist, treasure_hunter, rival
# perform_to_no_effect
# 	References: bard
# amuse_with_performance
# 	References: bard, tourist
# grouse_backstage
# 	References: bard
# encourage_fellow_performer
# 	References: bard
# annoy_diva_for_laughs
# 	References: likes, bard, diva
# become_annoyed_with_bard
# 	References: bard, tourist
# be_amused_by_bard
# 	References: bard, tourist
# make_judicious_decree
# 	References: monarch, fealty
# make_imprudent_decree
# 	References: monarch, fealty
# make_callous_decree
# 	References: monarch, fealty
# make_benevolent_decree
# 	References: monarch, fealty
# banish_monarchling
# 	References: child, age, royalty, monarch, likes
# consult_with_chancellor
# 	References: monarch, chancellor
# sway_monarch_to_kindness
# 	References: monarch, chancellor
# sway_monarch_to_indifference
# 	References: monarch, chancellor
# support_banished_sibling
# 	References: ex_royalty, royalty, sibling
# shun_banished_sibling
# 	References: ex_royalty, royalty, sibling
# play
# 	References: age
# play_together
# 	References: age
# argue_with_playmate
# 	References: age
# worry_about_future
# 	References: age
# worry_about_mortality
# 	References: age
# argue_about_duty
# 	References: free_sprited, duty_bound
# convince_importance_of_duty
# 	References: free_sprited, duty_bound
# hold_lecture
# 	References: professor, student
# hold_boring_lecture
# 	References: professor, student
# perform_research
# 	References: professor
# conspire_against
# 	References: important, spy_master
# send_underlings
# 	References: plotting_against, spy_master, spy
# cast_ur_job
# 	References: ur_job
# cast_monk
# 	References: ur_job
# cast_foreman
# 	References: ur_job
# cast_miner
# 	References: ur_job
# cast_curator
# 	References: ur_job
# cast_vendor
# 	References: ur_job
# cast_enforcer
# 	References: ur_job
# cast_dockworker
# 	References: ur_job
# cast_librarian
# 	References: ur_job
# cast_chef
# 	References: ur_job
# cast_treasure_hunter
# 	References: ur_job
# cast_archaelogist
# 	References: ur_job
# cast_bard
# 	References: ur_job
# cast_monarch
# 	References: ur_job
# cast_chancellor
# 	References: ur_job
# cast_professor
# 	References: ur_job
# cast_spy_master
# 	References: ur_job
# introvert
# 	References: talk
# extrovert
# 	References: talk
# curious
# 	References: risky
# cautious
# 	References: risky
# bully
# 	References: kind, mean
# carer
# 	References: kind, mean
# scholar
# 	References: scholarly
# ignoramus
# 	References: scholarly
# conscientious
# 	References: thoughtful, careless
# careless
# 	References: thoughtful, careless
# agreeable
# 	References: critical, agree
# critical
# 	References: critical, agree
# compassionate
# 	References: kind, thoughtful, mean
# indifferent
# 	References: kind, thoughtful, mean
# neurotic
# 	References: bold, worry
# confident
# 	References: bold, worry
# family_oriented
# 	References: kind, thoughtful, mean
# duty_bound
# 	References: duty, free
# free_spirited
# 	References: duty, free
# romantic
# 	References: romance
# gruff
# 	References: critical, agree
# feral
# 	References: risky, religious, talk
# comic
# 	References: thoughtful, silly
# stern
# 	References: thoughtful, silly
# rare_things_rare
# 	References: rare
# do_more_specific_things
# 	References: specific
# stay_in_confinement
# visiting_places_you_like
# visiting_as_regular
# romantic_towards_crush
# 	References: romance
# stay_at_hometown
# do_role_specific_actions
# 	References: role_specific
# go_to_locations_you_have_connection_with
# no_pedophilia
# 	References: romance
# family_ties
# 	References: romance, thoughtful, kind, critical, mean
# mean_to_people_you_dislike1
# 	References: mean
# mean_to_people_you_dislike2
# 	References: mean
# mean_to_people_you_dislike3
# 	References: mean
# nice_to_people_you_like1
# 	References: mean
# people_are_usually_serious
# 	References: silly
# fail_when_interactin_with_person_who_dislikes_you1
# 	References: failure
# fail_when_interactin_with_person_who_dislikes_you2
# 	References: failure
# people_joke_with_joker
# 	References: silly
# likes
# loves
# respects
# rivalry
# dissapointed_in
# proud_of
# embarrassed_by
# protective_of
# friends_with
# happiness
# anger
# tiredness
# sadness
# guilt
# shame
# self_worth
# Starting New Step: Initializing from fantasy_setting.init
# *************************POTENTIAL PROBLEMS BETWEEN INIT AND KISMET*************************
# Traits: Referenced in initialization but not found
# 	worker
# 	child
# 	follower
# 	connected
# 	impresario
# 	diva
# 	ship_builder
# 	vocation
# 	coworker
# 	boss
# 	rival
# 	criminal
# 	hometown
# 	auctioneer
# 	tourist
# 	servant
# 	engineer
# 	regular
# 	researcher
# 	believer
# 	citizen
# 	thief
# 	spouse
# 	mariner
# 	patron
# 	fealty
# 	victim
# 	pronouns
# 	priest
# 	parent
# 	artist
# 	employee
# 	scared
# 	tutor
# 	confined
# 	ruler
# 	guard
# 	sailor
# 	elder
# 	skin
# 	student
# 	presentation
# 	captain
# 	pickpocket
# 	fisher
# 	guest
# 	smith_apprentice
# 	barkeep
# 	master_thief
# 	drinker
# 	royalty
# 	smithy
# 	rich
# 	sibling
# 	owner
# 	related_to
# 	important
# 	last_birthday
# 	prostitute
# 	spy
# 	high_priest
# Starting New Step: Running...
# [('season', 'summer'), ('year', 1072)]
# ERROR clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population_locations.lp C:\Users\adams\Documents\Research\Kismet\kismet\volition.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_history.lp -t 8  | tr [:space:] \\n | sort
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Documents\Research\Kismet\kismet\KismetSequence.py in __call__(self)
#     697
#     698             print(f'Starting New Step: {action}')
# --> 699             self.active_module, self.state = action(self.active_module,self.state)
#     700
#
# ~\Documents\Research\Kismet\kismet\KismetSequence.py in __call__(self, module, state)
#     456
#     457         while not self.passes(module,state):
# --> 458             module.step_actions()
#     459
#     460         return module, module.to_json()
#
# ~\Documents\Research\Kismet\kismet\Kismet.py in step_actions(self)
#    3410             self.population2asp()
#    3411
# -> 3412             volitions = self.calculate_volitions()
#    3413
#    3414             chosen_actions = self.compute_actions(volitions)
#
# ~\Documents\Research\Kismet\kismet\Kismet.py in calculate_volitions(self)
#    2831         #print(' '.join([os.path.join(self.path,t) for t in ['default.lp', f'{self.module_file}_rules.lp', f'{self.module_file}_population.lp', 'testing.lp','volition.lp',f'{self.module_file}_history.lp']]))
#    2832
# -> 2833         volitions = solve([os.path.join(self.path,t) for t in ['default.lp', f'{self.module_file}_action_rules.lp', f'{self.module_file}_pattern_rules.lp', f'{self.module_file}_population.lp', f'{self.module_file}_population_locations.lp','volition.lp',f'{self.module_file}_history.lp']]+['-t','8'],clingo_exe=self.clingo_exe)
#    2834
#    2835         #Only select one of a given Actor, Action Type pair -- this is to stop combinatorics from dominating the likelihood
#
# ~\Documents\Research\Kismet\kismet\Kismet.py in solve(args, clingo_exe)
#     111         if len( result['Call'][0]) == 0 or 'Witnesses' not in result['Call'][0]:
#     112             print('ERROR', ' '.join(print_args))
# --> 113         witness = result['Call'][0]['Witnesses'][-1]['Value']
#     114         for atom in sorted(witness):
#     115             outfile.write(atom + '\n')
#
# KeyError: 'Witnesses'

# %%
print(sequence.active_module.pretty_print_history())
# Out:
# [('season', 'summer'), ('year', 1072)]
# -------
# None

# %%
print(sequence.active_module.display_relationships())
# Out:
# Irma Adomu:
# 	spy:
# 		the den of the thieves guild of Figliz
# 	employee:
# 		Vida Dasa
# 	coworker:
# 		Nacreous Wilma
# 		Kefom Zeres
# 	connected:
# 		the den of the thieves guild of Figliz
# Monook Solstalker:
# 	connected:
# 		the marketplace of Tenepo
# 	pickpocket:
# 		the marketplace of Tenepo
# Barnoa Baroth:
# 	connected:
# 		Library of Yarmecia Academy
# 	researcher:
# 		Library of Yarmecia Academy
# Adryl Straan:
# 	connected:
# 		Mable's Tavern
# 	regular:
# 		Mable's Tavern
# Waea Otis:
# 	connected:
# 		The Red Lion Inn
# 	regular:
# 		The Red Lion Inn
# Haze Conook:
# 	employee:
# 		Dorothy Banes
# 	coworker:
# 		Tidia Bramwalker
# 	connected:
# 		The Poisoned Kobold Tavern
# 	barkeep:
# 		The Poisoned Kobold Tavern
# Brangan Ria:
# 	employee:
# 		Ryle Vana
# 		Horace Seifis
# 		Jeanette Vana
# 	coworker:
# 		Ledane Steingo
# 		Kefvi Frides
# 		Kiau Morteheart
# 	connected:
# 		the shipyard of Ebrook
# 	spouse:
# 		Strayu Ria
# 	ship_builder:
# 		the shipyard of Ebrook
# 	related_to:
# 		Strayu Ria
# Quirett Roon:
# 	connected:
# 		The Old Lonely Yak
# 	regular:
# 		The Old Lonely Yak
# Sea Zerdow:
# 	tourist:
# 		the  opera house of Melamb
# Owea Tia:
# 	employee:
# 		Kathryn Sophia
# 	coworker:
# 		Sefzer Umaphie
# 	connected:
# 		Old Wana's Inn
# 	barkeep:
# 		Old Wana's Inn
# Quisom Noctwalker:
# 	employee:
# 		Zion Ziro
# 		Umadus Noctwalker
# 	coworker:
# 		Raindrop Kaon
# 		Branka Noctwalker
# 		Sleet Kefka
# 	connected:
# 		castle kitchen of Baltissia
# 	related_to:
# 		Umadus Noctwalker
# 		Wayne Noctwalker
# 		Anvil Noctwalker
# 	worker:
# 		castle kitchen of Baltissia
# 	child:
# 		Anvil Noctwalker
# 		Wayne Noctwalker
# 	sibling:
# 		Umadus Noctwalker
# 	fealty:
# 		Waa Secil
# Penro Quitis:
# 	employee:
# 		Adzer Moan
# 	coworker:
# 		Yuomu Eddie
# 		Banrett Sedus
# 		Gust Seifer
# 		Cean Seifer
# 		Pentzer Letel
# 		Viridian Ola
# 	connected:
# 		the mines of Dolbrae
# 	tourist:
# 		amphitheatre
# 	worker:
# 		the mines of Dolbrae
# 	miner:
# 		the mines of Dolbrae
# Kaan Katherine:
# 	connected:
# 		The Red Lion Inn
# 	regular:
# 		The Red Lion Inn
# Raindrop Kaon:
# 	employee:
# 		Zion Ziro
# 		Umadus Noctwalker
# 	coworker:
# 		Quisom Noctwalker
# 		Branka Noctwalker
# 		Sleet Kefka
# 	connected:
# 		castle kitchen of Baltissia
# 	worker:
# 		castle kitchen of Baltissia
# 	fealty:
# 		Waa Secil
# Wana Earnest:
# 	connected:
# 		the marketplace of Tenepo
# 	pickpocket:
# 		the marketplace of Tenepo
# 	spouse:
# 		Updraft Earnest
# 	related_to:
# 		Owa Earnest
# 		Frrett Earnest
# 		Updraft Earnest
# 		Seifan Earnest
# 	child:
# 		Seifan Earnest
# 		Frrett Earnest
# 	parent:
# 		Owa Earnest
# Wave Celyu:
# 	connected:
# 		Old Tellelia's Tavern
# 	regular:
# 		Old Tellelia's Tavern
# Air Umago:
# 	connected:
# 		The Red Lion Inn
# 	regular:
# 		The Red Lion Inn
# Aero Noctstalker:
# 	employee:
# 		Bandia Penin
# 	coworker:
# 		Tier Noctstalker
# 		Updraft Earnest
# 	connected:
# 		the marketplace of Tenepo
# 	spouse:
# 		Tier Noctstalker
# 	related_to:
# 		Umaoth Noctstalker
# 		Tier Noctstalker
# 		Blow Noctstalker
# 	parent:
# 		Blow Noctstalker
# 		Umaoth Noctstalker
# 	enforcer:
# 		the marketplace of Tenepo
# Rynoa Roan:
# 	coworker:
# 		Eda Steingan
# 		Vermillion Seford
# 		Eddy Sophia
# 		Ice Ryith
# 	connected:
# 		the marketplace of Garitrea
# 	victim:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	vendor:
# 		the marketplace of Garitrea
# 	scared:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	likes:
# 		Cyog Cous -8
# 		Whirlwind Savi -4
# 		Celau Sophia -6
# 		Umain Owryl -3
# Wind Aerea:
# 	connected:
# 		Library of Yarmecia Academy
# 	researcher:
# 		Library of Yarmecia Academy
# Frrett Earnest:
# 	coworker:
# 		Pylae Zio
# 		Pileus Freyro
# 		Kefus Vizer
# 		Seifan Earnest
# 	connected:
# 		the marketplace of Tenepo
# 	spouse:
# 		Seifan Earnest
# 	related_to:
# 		Wana Earnest
# 		Seifan Earnest
# 	parent:
# 		Wana Earnest
# 	victim:
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 		Aero Noctstalker
# 	vendor:
# 		the marketplace of Tenepo
# 	scared:
# 		Aero Noctstalker
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 	likes:
# 		Bandia Penin -7
# 		Updraft Earnest -6
# 		Tier Noctstalker -5
# 		Wana Earnest -3
# Fog Teres:
# 	connected:
# 		the docks of Ebrook
# 	fisher:
# 		the docks of Ebrook
# Jessie Frides:
# 	employee:
# 		Shower Brightheart
# 	coworker:
# 		Freeze Coith
# 		Quisan Tidia
# 		Steindow Vana
# 		Chadara Goah
# 	connected:
# 		a boat docked in the port of Ebrook
# 	spouse:
# 		Kefvi Frides
# 	related_to:
# 		Kefvi Frides
# 	sailor:
# 		a boat docked in the port of Ebrook
# Amos Moan:
# 	employee:
# 		Calamine Letel
# 	coworker:
# 		Roin Kefdane
# 	connected:
# 		the blacksmith of Dolbrae
# 	spouse:
# 		Adzer Moan
# 	related_to:
# 		Adzer Moan
# 	smith_apprentice:
# 		the blacksmith of Dolbrae
# Front Opal:
# 	connected:
# 		Melvin's Inn
# 		the blacksmith of Jundacio
# 	regular:
# 		Melvin's Inn
# 	boss:
# 		Tifsa Pylaewalker
# 		Kirett Roelo
# 	smithy:
# 		the blacksmith of Jundacio
# Vara Lifecursor:
# 	tourist:
# 		the  opera house of Melamb
# Kaka Freyin:
# 	connected:
# 		the  kitchen of Edon manor
# 	chef:
# 		the  kitchen of Edon manor
# 	servant:
# 		Barelia Edon
# Sefzer Umaphie:
# 	employee:
# 		Kathryn Sophia
# 	coworker:
# 		Owea Tia
# 	connected:
# 		Old Wana's Inn
# 	barkeep:
# 		Old Wana's Inn
# Flurry Adgo:
# 	coworker:
# 		Quisah Pensa
# 		Ashau Andorwalker
# 		Kana Rogan
# 		Nacreous Codus
# 		Bancil Quion
# 	connected:
# 		the marketplace of Jundacio
# 	spouse:
# 		Brandia Adgo
# 	related_to:
# 		Calamine Quion
# 		Brandia Adgo
# 	parent:
# 		Calamine Quion
# 	victim:
# 		Burlywood Yudus
# 		Downburst Pensa
# 		Aerka Alma
# 	vendor:
# 		the marketplace of Jundacio
# 	scared:
# 		Downburst Pensa
# 		Aerka Alma
# 		Burlywood Yudus
# 	likes:
# 		Burlywood Yudus -1
# 		Aerka Alma -8
# 		Tifyu Highvenator -1
# 		Downburst Pensa -1
# Quiel Shayu:
# 	employee:
# 		Ollie Lerett
# 	coworker:
# 		Downburst Darkcursor
# 	connected:
# 		Old Lerett's Inn
# 	barkeep:
# 		Old Lerett's Inn
# Cean Seifer:
# 	employee:
# 		Adzer Moan
# 	coworker:
# 		Yuomu Eddie
# 		Banrett Sedus
# 		Penro Quitis
# 		Gust Seifer
# 		Pentzer Letel
# 		Viridian Ola
# 	connected:
# 		the mines of Dolbrae
# 	spouse:
# 		Gust Seifer
# 	related_to:
# 		Kaelia Seifer
# 		Gust Seifer
# 	worker:
# 		the mines of Dolbrae
# 	miner:
# 		the mines of Dolbrae
# 	parent:
# 		Kaelia Seifer
# Tier Noctstalker:
# 	employee:
# 		Bandia Penin
# 	coworker:
# 		Updraft Earnest
# 		Aero Noctstalker
# 	connected:
# 		the marketplace of Tenepo
# 	spouse:
# 		Aero Noctstalker
# 	related_to:
# 		Aero Noctstalker
# 		Umaoth Noctstalker
# 		Blow Noctstalker
# 	parent:
# 		Blow Noctstalker
# 		Umaoth Noctstalker
# 	enforcer:
# 		the marketplace of Tenepo
# Jeanette Vana:
# 	employee:
# 		Horace Seifis
# 	connected:
# 		the shipyard of Ebrook
# 	spouse:
# 		Ryle Vana
# 	related_to:
# 		Steindow Vana
# 		Zeran Vana
# 		Ryle Vana
# 	parent:
# 		Steindow Vana
# 		Zeran Vana
# 	boss:
# 		Kefvi Frides
# 		Brangan Ria
# 		Ledane Steingo
# 		Kiau Morteheart
# 	engineer:
# 		the shipyard of Ebrook
# Zera Quiom:
# 	tourist:
# 		the  opera house of Melamb
# Baron Gordon:
# 	connected:
# 		A classroom of Yarmecia Academy
# 	spouse:
# 		Quiso Gordon
# 	related_to:
# 		Quiso Gordon
# 		Flurry Gordon
# 		Gael Gordon
# 	parent:
# 		Flurry Gordon
# 		Gael Gordon
# 	professor:
# 		A classroom of Yarmecia Academy
# Yuyu Barang:
# 	employee:
# 		Freyan Mole
# 	coworker:
# 		Nacreous Banyu
# 		Auvi Moelo
# 		Cyang Lionelwind
# 		Riog Banbin
# 		Sefros Alvin
# 	connected:
# 		the den of the thieves guild of Figliz
# 	thief:
# 		the den of the thieves guild of Figliz
# Umadus Noctwalker:
# 	connected:
# 		castle kitchen of Baltissia
# 	spouse:
# 		Branka Noctwalker
# 	related_to:
# 		Vanook Noctwalker
# 		Quisom Noctwalker
# 		Wayne Noctwalker
# 		Anvil Noctwalker
# 		Branka Noctwalker
# 	child:
# 		Anvil Noctwalker
# 		Wayne Noctwalker
# 	sibling:
# 		Quisom Noctwalker
# 	fealty:
# 		Waa Secil
# 	parent:
# 		Vanook Noctwalker
# 	boss:
# 		Quisom Noctwalker
# 		Sleet Kefka
# 		Raindrop Kaon
# 		Branka Noctwalker
# 	chef:
# 		castle kitchen of Baltissia
# Barvi Riryl:
# 	employee:
# 		Mable Steinon
# 	coworker:
# 		Ziro Marguerite
# 	connected:
# 		Mable's Tavern
# 	barkeep:
# 		Mable's Tavern
# 	tourist:
# 		the  opera house of Melamb
# Terdia Shaa:
# 	coworker:
# 		Fractus Deathhart
# 		Gust Shininghunter
# 		Rime Riryl
# 		Frith Mortewind
# 	connected:
# 		the marketplace of Melamb
# 	tourist:
# 		the  opera house of Melamb
# 	victim:
# 		Yuel Leroy
# 		Jet Umadus
# 		Edna Kinoa
# 	vendor:
# 		the marketplace of Melamb
# 	scared:
# 		Edna Kinoa
# 		Yuel Leroy
# 		Jet Umadus
# 	likes:
# 		Jet Umadus -4
# 		Ira Lifemoon -7
# 		Yuel Leroy -4
# 		Edna Kinoa -9
# Quisine Seford:
# 	connected:
# 		ruins
# 	spouse:
# 		Vermillion Seford
# 	related_to:
# 		Vermillion Seford
# 	archaelogist:
# 		ruins
# 	rival:
# 		Roa Morteheart
# 		Coang Adea
# 		Aeromu Aerle
# Zeran Vana:
# 	employee:
# 		Kefka Atrein
# 	coworker:
# 		Anvil Coith
# 		Gara Terus
# 		Frith Leocursor
# 		Zerro Calandrasun
# 	connected:
# 		the docks of Ebrook
# 	related_to:
# 		Steindow Vana
# 		Jeanette Vana
# 		Ryle Vana
# 	child:
# 		Ryle Vana
# 		Jeanette Vana
# 	sibling:
# 		Steindow Vana
# 	dockworker:
# 		the docks of Ebrook
# Chadara Goah:
# 	employee:
# 		Shower Brightheart
# 	coworker:
# 		Freeze Coith
# 		Jessie Frides
# 		Quisan Tidia
# 		Steindow Vana
# 	connected:
# 		a boat docked in the port of Ebrook
# 	sailor:
# 		a boat docked in the port of Ebrook
# Cyclone Bandia:
# 	connected:
# 		ruins
# 	archaelogist:
# 		ruins
# 	rival:
# 		Roa Morteheart
# 		Coang Adea
# 		Aeromu Aerle
# Roin Kefdane:
# 	employee:
# 		Calamine Letel
# 	coworker:
# 		Amos Moan
# 	connected:
# 		the blacksmith of Dolbrae
# 	smith_apprentice:
# 		the blacksmith of Dolbrae
# Virgil Mona:
# 	connected:
# 		ruins
# 	archaelogist:
# 		ruins
# 	rival:
# 		Roa Morteheart
# 		Coang Adea
# 		Aeromu Aerle
# Cyog Cous:
# 	employee:
# 		Umain Owryl
# 	coworker:
# 		Whirlwind Savi
# 	connected:
# 		the marketplace of Garitrea
# 	enforcer:
# 		the marketplace of Garitrea
# Atrean Moka:
# 	employee:
# 		Tibin Deathsun
# 		Riomu Yugo
# 		Cele Deathsun
# 	coworker:
# 		Odtzer Della
# 		Abraham Glaucous
# 		Baris Ceryl
# 		Zemdane Ceryl
# 		Quiku Della
# 		Edwin Seldane
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Penon Moka
# 	related_to:
# 		Lesa Moka
# 		Penon Moka
# 	parent:
# 		Lesa Moka
# 	bard:
# 		the  opera house of Melamb
# Pileus Andorwalker:
# 	employee:
# 		Breeze Melvin
# 	coworker:
# 		Kadia Pylaewalker
# 		Calamine Quion
# 	connected:
# 		Melvin's Inn
# 	barkeep:
# 		Melvin's Inn
# 	spouse:
# 		Ashau Andorwalker
# 	related_to:
# 		Riine Andorwalker
# 		Karo Andorwalker
# 		Ashau Andorwalker
# 	parent:
# 		Karo Andorwalker
# 		Riine Andorwalker
# Banrett Sedus:
# 	employee:
# 		Adzer Moan
# 	coworker:
# 		Yuomu Eddie
# 		Gust Seifer
# 		Cean Seifer
# 		Pentzer Letel
# 		Penro Quitis
# 		Viridian Ola
# 	connected:
# 		the mines of Dolbrae
# 	worker:
# 		the mines of Dolbrae
# 	miner:
# 		the mines of Dolbrae
# Elbert Quio:
# 	tourist:
# 		the  opera house of Melamb
# Odra Yugo:
# 	employee:
# 		Drought Deathsun
# 	coworker:
# 		Auides Glaucous
# 	connected:
# 		The Red Lion Inn
# 	barkeep:
# 		The Red Lion Inn
# 	spouse:
# 		Wadia Yugo
# 	related_to:
# 		Baromu Yugo
# 		Wadia Yugo
# 		Riomu Yugo
# 		Kefelo Yugo
# 	child:
# 		Riomu Yugo
# 		Kefelo Yugo
# 	parent:
# 		Baromu Yugo
# Brandia Adgo:
# 	connected:
# 		The elder of Jundacio's house
# 	spouse:
# 		Flurry Adgo
# 	related_to:
# 		Calamine Quion
# 		Flurry Adgo
# 	parent:
# 		Calamine Quion
# 	elder:
# 		The elder of Jundacio's house
# Freeze Coith:
# 	employee:
# 		Shower Brightheart
# 	coworker:
# 		Jessie Frides
# 		Quisan Tidia
# 		Steindow Vana
# 		Chadara Goah
# 	connected:
# 		a boat docked in the port of Ebrook
# 	related_to:
# 		Quiea Coith
# 		Quisog Coith
# 		Anvil Coith
# 	child:
# 		Quisog Coith
# 		Quiea Coith
# 	sibling:
# 		Anvil Coith
# 	sailor:
# 		a boat docked in the port of Ebrook
# Vida Dasa:
# 	connected:
# 		the den of the thieves guild of Figliz
# 	boss:
# 		Irma Adomu
# 		Kefom Zeres
# 		Nacreous Wilma
# 	spy_master:
# 		the den of the thieves guild of Figliz
# Yuel Leroy:
# 	employee:
# 		Jet Umadus
# 	coworker:
# 		Edna Kinoa
# 	connected:
# 		the marketplace of Melamb
# 	enforcer:
# 		the marketplace of Melamb
# Tidia Bramwalker:
# 	employee:
# 		Dorothy Banes
# 	coworker:
# 		Haze Conook
# 	connected:
# 		The Poisoned Kobold Tavern
# 	barkeep:
# 		The Poisoned Kobold Tavern
# 	spouse:
# 		Tiah Bramwalker
# 	related_to:
# 		Vian Bramwalker
# 		Tiah Bramwalker
# 	parent:
# 		Vian Bramwalker
# Vian Rira:
# 	tourist:
# 		the  opera house of Melamb
# Zidane Clearmoon:
# 	connected:
# 		Old Tellelia's Tavern
# 	regular:
# 		Old Tellelia's Tavern
# Strayu Ria:
# 	connected:
# 		the docks of Ebrook
# 	spouse:
# 		Brangan Ria
# 	related_to:
# 		Brangan Ria
# 	prostitute:
# 		the docks of Ebrook
# Ice Ryith:
# 	coworker:
# 		Eda Steingan
# 		Vermillion Seford
# 		Eddy Sophia
# 		Rynoa Roan
# 	connected:
# 		the marketplace of Garitrea
# 	victim:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	vendor:
# 		the marketplace of Garitrea
# 	scared:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	likes:
# 		Cyog Cous -7
# 		Whirlwind Savi -6
# 		Celau Sophia -7
# 		Umain Owryl -5
# Bancil Quion:
# 	coworker:
# 		Quisah Pensa
# 		Ashau Andorwalker
# 		Flurry Adgo
# 		Kana Rogan
# 		Nacreous Codus
# 	connected:
# 		the marketplace of Jundacio
# 	spouse:
# 		Calamine Quion
# 	related_to:
# 		Calamine Quion
# 	tourist:
# 		the  opera house of Melamb
# 	victim:
# 		Burlywood Yudus
# 		Downburst Pensa
# 		Aerka Alma
# 	vendor:
# 		the marketplace of Jundacio
# 	scared:
# 		Downburst Pensa
# 		Aerka Alma
# 		Burlywood Yudus
# 	likes:
# 		Burlywood Yudus -7
# 		Aerka Alma -2
# 		Waan Cerise -8
# 		Tifyu Highvenator -4
# 		Downburst Pensa -2
# Freyan Mole:
# 	connected:
# 		the den of the thieves guild of Figliz
# 	boss:
# 		Irma Adomu
# 		Kefom Zeres
# 		Nacreous Banyu
# 		Cyang Lionelwind
# 		Nacreous Wilma
# 		Auvi Moelo
# 		Riog Banbin
# 		Yuyu Barang
# 		Vida Dasa
# 		Sefros Alvin
# 	master_thief:
# 		the den of the thieves guild of Figliz
# Sleet Kefka:
# 	employee:
# 		Zion Ziro
# 		Umadus Noctwalker
# 	coworker:
# 		Quisom Noctwalker
# 		Raindrop Kaon
# 		Branka Noctwalker
# 	connected:
# 		castle kitchen of Baltissia
# 	spouse:
# 		Adros Kefka
# 	related_to:
# 		Adros Kefka
# 		Crest Kefka
# 	worker:
# 		castle kitchen of Baltissia
# 	fealty:
# 		Waa Secil
# 	parent:
# 		Crest Kefka
# Waan Cerise:
# 	connected:
# 		the marketplace of Jundacio
# 	pickpocket:
# 		the marketplace of Jundacio
# Saus Barau:
# 	connected:
# 		the docks of Ebrook
# 	fisher:
# 		the docks of Ebrook
# Kefka Atrein:
# 	connected:
# 		the docks of Ebrook
# 	tourist:
# 		the  opera house of Melamb
# 	boss:
# 		Zerro Calandrasun
# 		Anvil Coith
# 		Frith Leocursor
# 		Gara Terus
# 		Zeran Vana
# 	foreman:
# 		the docks of Ebrook
# Eda Steingan:
# 	coworker:
# 		Vermillion Seford
# 		Ice Ryith
# 		Eddy Sophia
# 		Rynoa Roan
# 	connected:
# 		the marketplace of Garitrea
# 	victim:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	vendor:
# 		the marketplace of Garitrea
# 	scared:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	likes:
# 		Whirlwind Savi -2
# 		Celau Sophia -3
# 		Umain Owryl -6
# Whirlwind Savi:
# 	employee:
# 		Umain Owryl
# 	coworker:
# 		Cyog Cous
# 	connected:
# 		the marketplace of Garitrea
# 	enforcer:
# 		the marketplace of Garitrea
# Cyang Lionelwind:
# 	employee:
# 		Freyan Mole
# 	coworker:
# 		Nacreous Banyu
# 		Auvi Moelo
# 		Riog Banbin
# 		Yuyu Barang
# 		Sefros Alvin
# 	connected:
# 		the den of the thieves guild of Figliz
# 	thief:
# 		the den of the thieves guild of Figliz
# Bardow Doris:
# 	connected:
# 		The Poisoned Kobold Tavern
# 	regular:
# 		The Poisoned Kobold Tavern
# Burlywood Yudus:
# 	employee:
# 		Downburst Pensa
# 	coworker:
# 		Aerka Alma
# 	connected:
# 		the marketplace of Jundacio
# 	enforcer:
# 		the marketplace of Jundacio
# Dorothy Banes:
# 	connected:
# 		The Poisoned Kobold Tavern
# 	boss:
# 		Haze Conook
# 		Tidia Bramwalker
# 	owner:
# 		The Poisoned Kobold Tavern
# Quiso Gordon:
# 	employee:
# 		Porah Leelia
# 	coworker:
# 		Terku Ashvi
# 	connected:
# 		The Old Lonely Yak
# 	barkeep:
# 		The Old Lonely Yak
# 	spouse:
# 		Baron Gordon
# 	related_to:
# 		Baron Gordon
# 		Flurry Gordon
# 		Gael Gordon
# 	parent:
# 		Flurry Gordon
# 		Gael Gordon
# Kirett Roelo:
# 	employee:
# 		Front Opal
# 	coworker:
# 		Tifsa Pylaewalker
# 	connected:
# 		the blacksmith of Jundacio
# 	smith_apprentice:
# 		the blacksmith of Jundacio
# Citrine Owzer:
# 	connected:
# 		The Poisoned Kobold Tavern
# 	regular:
# 		The Poisoned Kobold Tavern
# Quisan Tidia:
# 	employee:
# 		Shower Brightheart
# 	coworker:
# 		Freeze Coith
# 		Jessie Frides
# 		Steindow Vana
# 		Chadara Goah
# 	connected:
# 		a boat docked in the port of Ebrook
# 	sailor:
# 		a boat docked in the port of Ebrook
# Sefna Lonistalker:
# 	connected:
# 		Melvin's Inn
# 	regular:
# 		Melvin's Inn
# Quiku Della:
# 	employee:
# 		Tibin Deathsun
# 		Riomu Yugo
# 		Cele Deathsun
# 	coworker:
# 		Odtzer Della
# 		Abraham Glaucous
# 		Zemdane Ceryl
# 		Baris Ceryl
# 		Atrean Moka
# 		Edwin Seldane
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Odtzer Della
# 	related_to:
# 		Odtzer Della
# 	bard:
# 		the  opera house of Melamb
# Tellelia Merlynwind:
# 	connected:
# 		Old Tellelia's Tavern
# 	boss:
# 		Ashea Orsawind
# 		Quisnoa Letomu
# 		Eddy Cyryl
# 	owner:
# 		Old Tellelia's Tavern
# Frith Mortewind:
# 	coworker:
# 		Fractus Deathhart
# 		Gust Shininghunter
# 		Rime Riryl
# 		Terdia Shaa
# 	connected:
# 		the marketplace of Melamb
# 	victim:
# 		Yuel Leroy
# 		Jet Umadus
# 		Edna Kinoa
# 	vendor:
# 		the marketplace of Melamb
# 	scared:
# 		Edna Kinoa
# 		Yuel Leroy
# 		Jet Umadus
# 	likes:
# 		Jet Umadus -3
# 		Ira Lifemoon -2
# 		Yuel Leroy -9
# 		Edna Kinoa -1
# Vermillion Seford:
# 	coworker:
# 		Eda Steingan
# 		Ice Ryith
# 		Eddy Sophia
# 		Rynoa Roan
# 	connected:
# 		the marketplace of Garitrea
# 	spouse:
# 		Quisine Seford
# 	related_to:
# 		Quisine Seford
# 	victim:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	vendor:
# 		the marketplace of Garitrea
# 	scared:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	likes:
# 		Cyog Cous -3
# 		Umain Owryl -2
# Zerin Sanoa:
# 	coworker:
# 		Jet Seldane
# 		Storm Branith
# 	connected:
# 		the  gardens of Edon manor
# 	worker:
# 		the  gardens of Edon manor
# 	servant:
# 		Barelia Edon
# Umber Penin:
# 	employee:
# 		Penon Moka
# 	coworker:
# 		Lesa Moka
# 		Kefelo Yugo
# 	connected:
# 		the  auction house of Melamb
# 	spouse:
# 		Bandia Penin
# 	related_to:
# 		Bandia Penin
# 	tourist:
# 		the  opera house of Melamb
# 	curator:
# 		the  auction house of Melamb
# Breeze Melvin:
# 	connected:
# 		Melvin's Inn
# 	boss:
# 		Pileus Andorwalker
# 		Kadia Pylaewalker
# 		Calamine Quion
# 	owner:
# 		Melvin's Inn
# Bandia Penin:
# 	connected:
# 		the marketplace of Tenepo
# 	spouse:
# 		Umber Penin
# 	related_to:
# 		Umber Penin
# 	boss:
# 		Aero Noctstalker
# 		Tier Noctstalker
# 		Updraft Earnest
# Steindow Vana:
# 	employee:
# 		Shower Brightheart
# 	coworker:
# 		Freeze Coith
# 		Jessie Frides
# 		Quisan Tidia
# 		Chadara Goah
# 	connected:
# 		a boat docked in the port of Ebrook
# 	related_to:
# 		Zeran Vana
# 		Jeanette Vana
# 		Ryle Vana
# 	tourist:
# 		the  opera house of Melamb
# 	child:
# 		Ryle Vana
# 		Jeanette Vana
# 	sibling:
# 		Zeran Vana
# 	sailor:
# 		a boat docked in the port of Ebrook
# Roa Morteheart:
# 	connected:
# 		ruins
# 	rival:
# 		Aeromu Aerle
# 		Coang Adea
# 	treasure_hunter:
# 		ruins
# Penon Moka:
# 	connected:
# 		the  auction house of Melamb
# 	spouse:
# 		Atrean Moka
# 	related_to:
# 		Atrean Moka
# 		Lesa Moka
# 	parent:
# 		Lesa Moka
# 	boss:
# 		Lesa Moka
# 		Kefelo Yugo
# 		Umber Penin
# 	auctioneer:
# 		the  auction house of Melamb
# Eddy Sophia:
# 	coworker:
# 		Eda Steingan
# 		Ice Ryith
# 		Rynoa Roan
# 		Vermillion Seford
# 	connected:
# 		the marketplace of Garitrea
# 	spouse:
# 		Kathryn Sophia
# 	related_to:
# 		Celau Sophia
# 		Kathryn Sophia
# 	parent:
# 		Celau Sophia
# 	victim:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	vendor:
# 		the marketplace of Garitrea
# 	scared:
# 		Umain Owryl
# 		Whirlwind Savi
# 		Cyog Cous
# 	likes:
# 		Whirlwind Savi -9
# 		Umain Owryl -8
# 		Cyog Cous -4
# Tibin Deathsun:
# 	employee:
# 		Cele Deathsun
# 	coworker:
# 		Riomu Yugo
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Drought Deathsun
# 	related_to:
# 		Cele Deathsun
# 		Drought Deathsun
# 	parent:
# 		Cele Deathsun
# 	boss:
# 		Edwin Seldane
# 		Atrean Moka
# 		Quiku Della
# 		Odtzer Della
# 		Abraham Glaucous
# 		Baris Ceryl
# 		Zemdane Ceryl
# 	rival:
# 		Riomu Yugo
# 	diva:
# 		the  opera house of Melamb
# Kefelo Yugo:
# 	employee:
# 		Penon Moka
# 	coworker:
# 		Lesa Moka
# 		Umber Penin
# 	connected:
# 		the  auction house of Melamb
# 	spouse:
# 		Riomu Yugo
# 	related_to:
# 		Odra Yugo
# 		Riomu Yugo
# 	parent:
# 		Odra Yugo
# 	curator:
# 		the  auction house of Melamb
# Anvil Coith:
# 	employee:
# 		Kefka Atrein
# 	coworker:
# 		Gara Terus
# 		Frith Leocursor
# 		Zerro Calandrasun
# 		Zeran Vana
# 	connected:
# 		the docks of Ebrook
# 	related_to:
# 		Quiea Coith
# 		Quisog Coith
# 		Freeze Coith
# 	child:
# 		Quisog Coith
# 		Quiea Coith
# 	sibling:
# 		Freeze Coith
# 	dockworker:
# 		the docks of Ebrook
# Umaa Marguerite:
# 	connected:
# 		Library of Edon manor
# 	servant:
# 		Barelia Edon
# 	librarian:
# 		Library of Edon manor
# Odtzer Della:
# 	employee:
# 		Tibin Deathsun
# 		Riomu Yugo
# 		Cele Deathsun
# 	coworker:
# 		Abraham Glaucous
# 		Zemdane Ceryl
# 		Baris Ceryl
# 		Atrean Moka
# 		Quiku Della
# 		Edwin Seldane
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Quiku Della
# 	related_to:
# 		Quiku Della
# 	bard:
# 		the  opera house of Melamb
# Chadartzer Atretis:
# 	connected:
# 		The Red Lion Inn
# 	regular:
# 		The Red Lion Inn
# Branvi Eva:
# 	connected:
# 		Mable's Tavern
# 	regular:
# 		Mable's Tavern
# Zerog Tellom:
# 	connected:
# 		Old Wana's Inn
# 	regular:
# 		Old Wana's Inn
# Quisnoa Letomu:
# 	employee:
# 		Tellelia Merlynwind
# 	coworker:
# 		Ashea Orsawind
# 		Eddy Cyryl
# 	connected:
# 		Old Tellelia's Tavern
# 	barkeep:
# 		Old Tellelia's Tavern
# 	tourist:
# 		the  opera house of Melamb
# Seifan Earnest:
# 	coworker:
# 		Frrett Earnest
# 		Pylae Zio
# 		Pileus Freyro
# 		Kefus Vizer
# 	connected:
# 		the marketplace of Tenepo
# 	spouse:
# 		Frrett Earnest
# 	related_to:
# 		Wana Earnest
# 		Frrett Earnest
# 	parent:
# 		Wana Earnest
# 	victim:
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 		Aero Noctstalker
# 	vendor:
# 		the marketplace of Tenepo
# 	scared:
# 		Aero Noctstalker
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 	likes:
# 		Updraft Earnest -4
# 		Tier Noctstalker -1
# 		Monook Solstalker -8
# 		Wana Earnest -5
# 		Aero Noctstalker -8
# Irene Emil:
# 	coworker:
# 		Coine Edbin
# 		Celer Celer
# 		Ice Pearl
# 		Typhoon Pearl
# 		Elbert Edbin
# 	connected:
# 		ruins
# 	bard:
# 		ruins
# Sefros Alvin:
# 	employee:
# 		Freyan Mole
# 	coworker:
# 		Nacreous Banyu
# 		Auvi Moelo
# 		Cyang Lionelwind
# 		Riog Banbin
# 		Yuyu Barang
# 	connected:
# 		the den of the thieves guild of Figliz
# 	thief:
# 		the den of the thieves guild of Figliz
# Leta Palis:
# 	coworker:
# 		Adros Kefka
# 		Palan Chadaris
# 	connected:
# 		the gaol of Baltissia castle
# 	spouse:
# 		Sepia Palis
# 	related_to:
# 		Sepia Palis
# 		Lizzie Palis
# 		Sleet Palis
# 	tourist:
# 		amphitheatre
# 	fealty:
# 		Waa Secil
# 	parent:
# 		Sleet Palis
# 		Lizzie Palis
# 	guard:
# 		Anvil Noctwalker
# 		Sepia Palis
# 		the gaol of Baltissia castle
# Edau Zergo:
# 	connected:
# 		Old Tellelia's Tavern
# 	regular:
# 		Old Tellelia's Tavern
# 	tourist:
# 		amphitheatre
# Tifis Tidane:
# 	connected:
# 		Old Lerett's Inn
# 	regular:
# 		Old Lerett's Inn
# 	tourist:
# 		amphitheatre
# 		the  opera house of Melamb
# Jay Freygo:
# 	connected:
# 		Royal Library of Baltissia
# 	spouse:
# 		Air Freygo
# 	related_to:
# 		Air Freygo
# 	fealty:
# 		Waa Secil
# 	librarian:
# 		Royal Library of Baltissia
# Elbert Edbin:
# 	coworker:
# 		Coine Edbin
# 		Celer Celer
# 		Irene Emil
# 		Ice Pearl
# 		Typhoon Pearl
# 	connected:
# 		ruins
# 	spouse:
# 		Coine Edbin
# 	related_to:
# 		Coine Edbin
# 	bard:
# 		ruins
# Vaith Pendia:
# 	connected:
# 		Old Lerett's Inn
# 	regular:
# 		Old Lerett's Inn
# Chadarrett Moith:
# 	connected:
# 		the docks of Ebrook
# 	prostitute:
# 		the docks of Ebrook
# Downburst Pensa:
# 	connected:
# 		the marketplace of Jundacio
# 	spouse:
# 		Quisah Pensa
# 	related_to:
# 		Quisah Pensa
# 	tourist:
# 		the  opera house of Melamb
# 	boss:
# 		Burlywood Yudus
# 		Aerka Alma
# Rina Rinoa:
# 	connected:
# 		The Old Lonely Yak
# 		A classroom of Yarmecia Academy
# 	regular:
# 		The Old Lonely Yak
# 	tourist:
# 		amphitheatre
# 	professor:
# 		A classroom of Yarmecia Academy
# Celer Celer:
# 	coworker:
# 		Coine Edbin
# 		Irene Emil
# 		Ice Pearl
# 		Typhoon Pearl
# 		Elbert Edbin
# 	connected:
# 		ruins
# 	bard:
# 		ruins
# Umain Owryl:
# 	connected:
# 		the marketplace of Garitrea
# 	boss:
# 		Cyog Cous
# 		Whirlwind Savi
# Auides Glaucous:
# 	employee:
# 		Drought Deathsun
# 	coworker:
# 		Odra Yugo
# 	connected:
# 		The Red Lion Inn
# 	barkeep:
# 		The Red Lion Inn
# 	spouse:
# 		Abraham Glaucous
# 	related_to:
# 		Abraham Glaucous
# Umaah Viryl:
# 	connected:
# 		The Old Lonely Yak
# 	regular:
# 		The Old Lonely Yak
# Palan Chadaris:
# 	coworker:
# 		Adros Kefka
# 		Leta Palis
# 	connected:
# 		the gaol of Baltissia castle
# 	fealty:
# 		Waa Secil
# 	guard:
# 		Anvil Noctwalker
# 		Sepia Palis
# 		the gaol of Baltissia castle
# Viridian Ola:
# 	employee:
# 		Adzer Moan
# 	coworker:
# 		Yuomu Eddie
# 		Banrett Sedus
# 		Gust Seifer
# 		Cean Seifer
# 		Pentzer Letel
# 		Penro Quitis
# 	connected:
# 		the mines of Dolbrae
# 	worker:
# 		the mines of Dolbrae
# 	miner:
# 		the mines of Dolbrae
# Fog Rira:
# 	tourist:
# 		amphitheatre
# Updraft Lunafighter:
# 	connected:
# 		Library of Yarmecia Academy
# 	librarian:
# 		Library of Yarmecia Academy
# Odea Bainoa:
# 	connected:
# 		Library of Edon manor
# 	servant:
# 		Barelia Edon
# 	librarian:
# 		Library of Edon manor
# Adzer Moan:
# 	connected:
# 		the mines of Dolbrae
# 	spouse:
# 		Amos Moan
# 	related_to:
# 		Amos Moan
# 	boss:
# 		Penro Quitis
# 		Cean Seifer
# 		Viridian Ola
# 		Yuomu Eddie
# 		Banrett Sedus
# 		Gust Seifer
# 		Pentzer Letel
# 	foreman:
# 		the mines of Dolbrae
# Straog Katis:
# 	tourist:
# 		amphitheatre
# Eddy Cyryl:
# 	employee:
# 		Tellelia Merlynwind
# 	coworker:
# 		Ashea Orsawind
# 		Quisnoa Letomu
# 	connected:
# 		Old Tellelia's Tavern
# 	barkeep:
# 		Old Tellelia's Tavern
# Thunder Liferunner:
# 	connected:
# 		The Poisoned Kobold Tavern
# 	regular:
# 		The Poisoned Kobold Tavern
# Auoth Edwin:
# 	connected:
# 		Throne Room of Baltissia
# 	fealty:
# 		Waa Secil
# 	chancellor:
# 		Waa Secil
# Calamine Letel:
# 	connected:
# 		the blacksmith of Dolbrae
# 	spouse:
# 		Pentzer Letel
# 	related_to:
# 		Pentzer Letel
# 	boss:
# 		Amos Moan
# 		Roin Kefdane
# 	smithy:
# 		the blacksmith of Dolbrae
# Gust Shininghunter:
# 	coworker:
# 		Fractus Deathhart
# 		Rime Riryl
# 		Frith Mortewind
# 		Terdia Shaa
# 	connected:
# 		the marketplace of Melamb
# 	victim:
# 		Yuel Leroy
# 		Jet Umadus
# 		Edna Kinoa
# 	vendor:
# 		the marketplace of Melamb
# 	scared:
# 		Edna Kinoa
# 		Yuel Leroy
# 		Jet Umadus
# 	likes:
# 		Jet Umadus -6
# 		Ira Lifemoon -5
# 		Yuel Leroy -8
# Irma Baika:
# 	connected:
# 		Library of Edon manor
# 	servant:
# 		Barelia Edon
# 	tutor:
# 		Library of Edon manor
# Air Freygo:
# 	connected:
# 		Royal Library of Baltissia
# 	spouse:
# 		Jay Freygo
# 	related_to:
# 		Jay Freygo
# 	fealty:
# 		Waa Secil
# 	tutor:
# 		Royal Library of Baltissia
# 		Chill Zema
# 		Dora Zema
# Ollie Lerett:
# 	connected:
# 		Old Lerett's Inn
# 	boss:
# 		Downburst Darkcursor
# 		Quiel Shayu
# 	owner:
# 		Old Lerett's Inn
# Auvi Moelo:
# 	employee:
# 		Freyan Mole
# 	coworker:
# 		Nacreous Banyu
# 		Cyang Lionelwind
# 		Riog Banbin
# 		Yuyu Barang
# 		Sefros Alvin
# 	connected:
# 		the den of the thieves guild of Figliz
# 	thief:
# 		the den of the thieves guild of Figliz
# Zemdane Ceryl:
# 	employee:
# 		Tibin Deathsun
# 		Riomu Yugo
# 		Cele Deathsun
# 	coworker:
# 		Odtzer Della
# 		Abraham Glaucous
# 		Baris Ceryl
# 		Atrean Moka
# 		Quiku Della
# 		Edwin Seldane
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Baris Ceryl
# 	related_to:
# 		Baris Ceryl
# 	bard:
# 		the  opera house of Melamb
# Kiine Zema:
# 	connected:
# 		Throne Room of Baltissia
# 	spouse:
# 		Waa Secil
# 	parent:
# 		Chill Zema
# 		Dora Zema
# Barka Nighthart:
# 	connected:
# 		Melvin's Inn
# 	regular:
# 		Melvin's Inn
# Storm Branith:
# 	coworker:
# 		Jet Seldane
# 		Zerin Sanoa
# 	connected:
# 		the  gardens of Edon manor
# 	worker:
# 		the  gardens of Edon manor
# 	servant:
# 		Barelia Edon
# Adros Kefka:
# 	coworker:
# 		Leta Palis
# 		Palan Chadaris
# 	connected:
# 		the gaol of Baltissia castle
# 	spouse:
# 		Sleet Kefka
# 	related_to:
# 		Sleet Kefka
# 		Crest Kefka
# 	fealty:
# 		Waa Secil
# 	parent:
# 		Crest Kefka
# 	guard:
# 		Anvil Noctwalker
# 		Sepia Palis
# 		the gaol of Baltissia castle
# Ashau Andorwalker:
# 	coworker:
# 		Quisah Pensa
# 		Flurry Adgo
# 		Kana Rogan
# 		Nacreous Codus
# 		Bancil Quion
# 	connected:
# 		the marketplace of Jundacio
# 	spouse:
# 		Pileus Andorwalker
# 	related_to:
# 		Karo Andorwalker
# 		Pileus Andorwalker
# 		Riine Andorwalker
# 	parent:
# 		Karo Andorwalker
# 		Riine Andorwalker
# 	victim:
# 		Burlywood Yudus
# 		Downburst Pensa
# 		Aerka Alma
# 	vendor:
# 		the marketplace of Jundacio
# 	scared:
# 		Downburst Pensa
# 		Aerka Alma
# 		Burlywood Yudus
# 	likes:
# 		Burlywood Yudus -6
# 		Aerka Alma -8
# 		Waan Cerise -4
# 		Tifyu Highvenator -4
# 		Downburst Pensa -5
# Abraham Glaucous:
# 	employee:
# 		Tibin Deathsun
# 		Riomu Yugo
# 		Cele Deathsun
# 	coworker:
# 		Odtzer Della
# 		Zemdane Ceryl
# 		Baris Ceryl
# 		Atrean Moka
# 		Quiku Della
# 		Edwin Seldane
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Auides Glaucous
# 	related_to:
# 		Advi Leelia
# 		Porah Leelia
# 		Auides Glaucous
# 	child:
# 		Advi Leelia
# 		Porah Leelia
# 	bard:
# 		the  opera house of Melamb
# Karett Mortehunter:
# 	connected:
# 		Old Lerett's Inn
# 	regular:
# 		Old Lerett's Inn
# Eva Sefo:
# 	connected:
# 		Old Lerett's Inn
# 	regular:
# 		Old Lerett's Inn
# Tifsa Pylaewalker:
# 	employee:
# 		Front Opal
# 	coworker:
# 		Kirett Roelo
# 	connected:
# 		the blacksmith of Jundacio
# 	spouse:
# 		Kadia Pylaewalker
# 	related_to:
# 		Thunder Pylaewalker
# 		Wind Pylaewalker
# 		Kadia Pylaewalker
# 	parent:
# 		Wind Pylaewalker
# 		Thunder Pylaewalker
# 	smith_apprentice:
# 		the blacksmith of Jundacio
# Kefus Vizer:
# 	coworker:
# 		Frrett Earnest
# 		Pylae Zio
# 		Pileus Freyro
# 		Seifan Earnest
# 	connected:
# 		the marketplace of Tenepo
# 	victim:
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 		Aero Noctstalker
# 	vendor:
# 		the marketplace of Tenepo
# 	scared:
# 		Aero Noctstalker
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 	likes:
# 		Bandia Penin -1
# 		Updraft Earnest -3
# 		Monook Solstalker -1
# 		Wana Earnest -5
# 		Aero Noctstalker -5
# Updraft Earnest:
# 	employee:
# 		Bandia Penin
# 	coworker:
# 		Tier Noctstalker
# 		Aero Noctstalker
# 	connected:
# 		the marketplace of Tenepo
# 	spouse:
# 		Wana Earnest
# 	related_to:
# 		Owa Earnest
# 		Wana Earnest
# 	parent:
# 		Owa Earnest
# 	enforcer:
# 		the marketplace of Tenepo
# Ira Lifemoon:
# 	connected:
# 		the marketplace of Melamb
# 	pickpocket:
# 		the marketplace of Melamb
# Tiah Bramwalker:
# 	connected:
# 		the  gallery of Edon manor
# 	spouse:
# 		Tidia Bramwalker
# 	related_to:
# 		Vian Bramwalker
# 		Tidia Bramwalker
# 	parent:
# 		Vian Bramwalker
# 	servant:
# 		Barelia Edon
# 	artist:
# 		the  gallery of Edon manor
# Baiea Chiffon:
# 	connected:
# 		Library of Edon manor
# 	servant:
# 		Barelia Edon
# 	librarian:
# 		Library of Edon manor
# Ben Banelia:
# 	connected:
# 		Library of Yarmecia Academy
# 	librarian:
# 		Library of Yarmecia Academy
# Palros Waan:
# 	connected:
# 		Mable's Tavern
# 	regular:
# 		Mable's Tavern
# Frith Leocursor:
# 	employee:
# 		Kefka Atrein
# 	coworker:
# 		Anvil Coith
# 		Zerro Calandrasun
# 		Gara Terus
# 		Zeran Vana
# 	connected:
# 		the docks of Ebrook
# 	dockworker:
# 		the docks of Ebrook
# Tifis Calandrastalker:
# 	connected:
# 		ruins
# 	archaelogist:
# 		ruins
# 	rival:
# 		Roa Morteheart
# 		Coang Adea
# 		Aeromu Aerle
# Leola Steinvi:
# 	connected:
# 		Old Wana's Inn
# 	regular:
# 		Old Wana's Inn
# Jet Umadus:
# 	connected:
# 		the marketplace of Melamb
# 	boss:
# 		Edna Kinoa
# 		Yuel Leroy
# Waa Secil:
# 	connected:
# 		Throne Room of Baltissia
# 	spouse:
# 		Kiine Zema
# 	related_to:
# 		Sepia Palis
# 		Branka Secil
# 		Jet Secil
# 	child:
# 		Jet Secil
# 		Branka Secil
# 	sibling:
# 		Sepia Palis
# 	parent:
# 		Chill Zema
# 		Dora Zema
# Ashea Orsawind:
# 	employee:
# 		Tellelia Merlynwind
# 	coworker:
# 		Quisnoa Letomu
# 		Eddy Cyryl
# 	connected:
# 		Old Tellelia's Tavern
# 	barkeep:
# 		Old Tellelia's Tavern
# 	tourist:
# 		the  opera house of Melamb
# Kefvi Frides:
# 	employee:
# 		Ryle Vana
# 		Horace Seifis
# 		Jeanette Vana
# 	coworker:
# 		Brangan Ria
# 		Ledane Steingo
# 		Kiau Morteheart
# 	connected:
# 		the shipyard of Ebrook
# 	spouse:
# 		Jessie Frides
# 	ship_builder:
# 		the shipyard of Ebrook
# 	related_to:
# 		Jessie Frides
# Porvi Sefa:
# 	connected:
# 		Old Tellelia's Tavern
# 	regular:
# 		Old Tellelia's Tavern
# Advi Leelia:
# 	spouse:
# 		Porah Leelia
# 	related_to:
# 		Abraham Glaucous
# 		Porah Leelia
# 	parent:
# 		Abraham Glaucous
# Yuer Selah:
# 	tourist:
# 		amphitheatre
# Cele Deathsun:
# 	connected:
# 		the  opera house of Melamb
# 	related_to:
# 		Tibin Deathsun
# 		Drought Deathsun
# 	child:
# 		Tibin Deathsun
# 		Drought Deathsun
# 	boss:
# 		Edwin Seldane
# 		Atrean Moka
# 		Quiku Della
# 		Odtzer Della
# 		Tibin Deathsun
# 		Abraham Glaucous
# 		Riomu Yugo
# 		Baris Ceryl
# 		Zemdane Ceryl
# 	impresario:
# 		the  opera house of Melamb
# Ledane Steingo:
# 	employee:
# 		Ryle Vana
# 		Horace Seifis
# 		Jeanette Vana
# 	coworker:
# 		Brangan Ria
# 		Kefvi Frides
# 		Kiau Morteheart
# 	connected:
# 		the shipyard of Ebrook
# 	ship_builder:
# 		the shipyard of Ebrook
# Pylae Zio:
# 	coworker:
# 		Frrett Earnest
# 		Pileus Freyro
# 		Kefus Vizer
# 		Seifan Earnest
# 	connected:
# 		the marketplace of Tenepo
# 	victim:
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 		Aero Noctstalker
# 	vendor:
# 		the marketplace of Tenepo
# 	scared:
# 		Aero Noctstalker
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 	likes:
# 		Bandia Penin -5
# 		Updraft Earnest -4
# 		Tier Noctstalker -3
# 		Wana Earnest -6
# 		Aero Noctstalker -3
# Ice Pearl:
# 	coworker:
# 		Celer Celer
# 		Irene Emil
# 		Coine Edbin
# 		Typhoon Pearl
# 		Elbert Edbin
# 	connected:
# 		ruins
# 	spouse:
# 		Typhoon Pearl
# 	related_to:
# 		Typhoon Pearl
# 	bard:
# 		ruins
# Lewis Yuine:
# 	tourist:
# 		the  opera house of Melamb
# Ziro Marguerite:
# 	employee:
# 		Mable Steinon
# 	coworker:
# 		Barvi Riryl
# 	connected:
# 		Mable's Tavern
# 	barkeep:
# 		Mable's Tavern
# Riog Banbin:
# 	employee:
# 		Freyan Mole
# 	coworker:
# 		Nacreous Banyu
# 		Auvi Moelo
# 		Cyang Lionelwind
# 		Yuyu Barang
# 		Sefros Alvin
# 	connected:
# 		the den of the thieves guild of Figliz
# 	thief:
# 		the den of the thieves guild of Figliz
# Aertzer Barzer:
# 	connected:
# 		the  gallery of Edon manor
# 	servant:
# 		Barelia Edon
# 	artist:
# 		the  gallery of Edon manor
# Aerbin Nina:
# 	connected:
# 		The Old Lonely Yak
# 	regular:
# 		The Old Lonely Yak
# Nacreous Wilma:
# 	spy:
# 		the den of the thieves guild of Figliz
# 	employee:
# 		Vida Dasa
# 	coworker:
# 		Kefom Zeres
# 		Irma Adomu
# 	connected:
# 		the den of the thieves guild of Figliz
# Baris Ceryl:
# 	employee:
# 		Tibin Deathsun
# 		Riomu Yugo
# 		Cele Deathsun
# 	coworker:
# 		Odtzer Della
# 		Abraham Glaucous
# 		Zemdane Ceryl
# 		Atrean Moka
# 		Quiku Della
# 		Edwin Seldane
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Zemdane Ceryl
# 	related_to:
# 		Zemdane Ceryl
# 	bard:
# 		the  opera house of Melamb
# Typhoon Pearl:
# 	coworker:
# 		Coine Edbin
# 		Celer Celer
# 		Irene Emil
# 		Ice Pearl
# 		Elbert Edbin
# 	connected:
# 		ruins
# 	spouse:
# 		Ice Pearl
# 	related_to:
# 		Ice Pearl
# 	bard:
# 		ruins
# Zerro Calandrasun:
# 	employee:
# 		Kefka Atrein
# 	coworker:
# 		Anvil Coith
# 		Frith Leocursor
# 		Gara Terus
# 		Zeran Vana
# 	connected:
# 		the docks of Ebrook
# 	dockworker:
# 		the docks of Ebrook
# Leola Bernice:
# 	tourist:
# 		the  opera house of Melamb
# Eddy Goro:
# 	connected:
# 		The Old Lonely Yak
# 	regular:
# 		The Old Lonely Yak
# 	tourist:
# 		the  opera house of Melamb
# Celau Sophia:
# 	connected:
# 		Old Wana's Inn
# 		the marketplace of Garitrea
# 	pickpocket:
# 		the marketplace of Garitrea
# 	regular:
# 		Old Wana's Inn
# 	related_to:
# 		Kathryn Sophia
# 		Eddy Sophia
# 	child:
# 		Eddy Sophia
# 		Kathryn Sophia
# Yuomu Eddie:
# 	employee:
# 		Adzer Moan
# 	coworker:
# 		Banrett Sedus
# 		Gust Seifer
# 		Cean Seifer
# 		Pentzer Letel
# 		Penro Quitis
# 		Viridian Ola
# 	connected:
# 		the mines of Dolbrae
# 	worker:
# 		the mines of Dolbrae
# 	miner:
# 		the mines of Dolbrae
# Pileus Ecru:
# 	connected:
# 		Library of Edon manor
# 	servant:
# 		Barelia Edon
# 	tutor:
# 		Library of Edon manor
# Gara Terus:
# 	employee:
# 		Kefka Atrein
# 	coworker:
# 		Anvil Coith
# 		Zerro Calandrasun
# 		Frith Leocursor
# 		Zeran Vana
# 	connected:
# 		the docks of Ebrook
# 	dockworker:
# 		the docks of Ebrook
# Persimmon Owgo:
# 	connected:
# 		Library of Yarmecia Academy
# 	librarian:
# 		Library of Yarmecia Academy
# Sepia Palis:
# 	spouse:
# 		Leta Palis
# 	related_to:
# 		Sleet Palis
# 		Lizzie Palis
# 		Branka Secil
# 		Waa Secil
# 		Leta Palis
# 		Jet Secil
# 	child:
# 		Jet Secil
# 		Branka Secil
# 	sibling:
# 		Waa Secil
# 	parent:
# 		Sleet Palis
# 		Lizzie Palis
# 	confined:
# 		the gaol of Baltissia castle
# Cydia Ellen:
# 	connected:
# 		Library of Yarmecia Academy
# 	researcher:
# 		Library of Yarmecia Academy
# Wayne Noctwalker:
# 	connected:
# 		Royal Library of Baltissia
# 	spouse:
# 		Anvil Noctwalker
# 	related_to:
# 		Quisom Noctwalker
# 		Umadus Noctwalker
# 		Anvil Noctwalker
# 	fealty:
# 		Waa Secil
# 	parent:
# 		Umadus Noctwalker
# 		Quisom Noctwalker
# 	librarian:
# 		Royal Library of Baltissia
# Zion Ziro:
# 	connected:
# 		castle kitchen of Baltissia
# 	tourist:
# 		amphitheatre
# 	fealty:
# 		Waa Secil
# 	boss:
# 		Quisom Noctwalker
# 		Sleet Kefka
# 		Raindrop Kaon
# 		Branka Noctwalker
# 	chef:
# 		castle kitchen of Baltissia
# Edna Kinoa:
# 	employee:
# 		Jet Umadus
# 	coworker:
# 		Yuel Leroy
# 	connected:
# 		the marketplace of Melamb
# 	enforcer:
# 		the marketplace of Melamb
# Kefine Senook:
# 	connected:
# 		Mable's Tavern
# 	regular:
# 		Mable's Tavern
# Pileus Freyro:
# 	coworker:
# 		Frrett Earnest
# 		Pylae Zio
# 		Kefus Vizer
# 		Seifan Earnest
# 	connected:
# 		the marketplace of Tenepo
# 	victim:
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 		Aero Noctstalker
# 	vendor:
# 		the marketplace of Tenepo
# 	scared:
# 		Aero Noctstalker
# 		Bandia Penin
# 		Tier Noctstalker
# 		Updraft Earnest
# 	likes:
# 		Bandia Penin -7
# 		Updraft Earnest -4
# 		Tier Noctstalker -5
# 		Monook Solstalker -2
# 		Wana Earnest -9
# 		Aero Noctstalker -3
# Horace Seifis:
# 	connected:
# 		the shipyard of Ebrook
# 	boss:
# 		Kefvi Frides
# 		Ryle Vana
# 		Brangan Ria
# 		Ledane Steingo
# 		Kiau Morteheart
# 		Jeanette Vana
# 	owner:
# 		the shipyard of Ebrook
# Lena Umana:
# 	connected:
# 		Melvin's Inn
# 	regular:
# 		Melvin's Inn
# Branka Noctwalker:
# 	employee:
# 		Zion Ziro
# 		Umadus Noctwalker
# 	coworker:
# 		Quisom Noctwalker
# 		Raindrop Kaon
# 		Sleet Kefka
# 	connected:
# 		castle kitchen of Baltissia
# 	spouse:
# 		Umadus Noctwalker
# 	related_to:
# 		Vanook Noctwalker
# 		Umadus Noctwalker
# 	worker:
# 		castle kitchen of Baltissia
# 	fealty:
# 		Waa Secil
# 	parent:
# 		Vanook Noctwalker
# Porah Leelia:
# 	connected:
# 		The Old Lonely Yak
# 	spouse:
# 		Advi Leelia
# 	related_to:
# 		Advi Leelia
# 		Abraham Glaucous
# 	parent:
# 		Abraham Glaucous
# 	boss:
# 		Quiso Gordon
# 		Terku Ashvi
# 	owner:
# 		The Old Lonely Yak
# Tifyu Highvenator:
# 	connected:
# 		the marketplace of Jundacio
# 	pickpocket:
# 		the marketplace of Jundacio
# Coang Adea:
# 	connected:
# 		ruins
# 	tourist:
# 		the  opera house of Melamb
# 	rival:
# 		Roa Morteheart
# 		Aeromu Aerle
# 	treasure_hunter:
# 		ruins
# Mable Steinon:
# 	connected:
# 		Mable's Tavern
# 	boss:
# 		Ziro Marguerite
# 		Barvi Riryl
# 	owner:
# 		Mable's Tavern
# Gust Seifer:
# 	employee:
# 		Adzer Moan
# 	coworker:
# 		Yuomu Eddie
# 		Banrett Sedus
# 		Cean Seifer
# 		Viridian Ola
# 		Pentzer Letel
# 		Penro Quitis
# 	connected:
# 		the mines of Dolbrae
# 	spouse:
# 		Cean Seifer
# 	related_to:
# 		Chadarrett Sais
# 		Cean Seifer
# 		Bransa Sais
# 		Kaelia Seifer
# 	worker:
# 		the mines of Dolbrae
# 	child:
# 		Chadarrett Sais
# 		Bransa Sais
# 	miner:
# 		the mines of Dolbrae
# 	parent:
# 		Kaelia Seifer
# Rime Riryl:
# 	coworker:
# 		Fractus Deathhart
# 		Gust Shininghunter
# 		Frith Mortewind
# 		Terdia Shaa
# 	connected:
# 		the marketplace of Melamb
# 	victim:
# 		Yuel Leroy
# 		Jet Umadus
# 		Edna Kinoa
# 	vendor:
# 		the marketplace of Melamb
# 	scared:
# 		Edna Kinoa
# 		Yuel Leroy
# 		Jet Umadus
# 	likes:
# 		Jet Umadus -7
# 		Ira Lifemoon -7
# 		Yuel Leroy -8
# 		Edna Kinoa -1
# Nacreous Banyu:
# 	employee:
# 		Freyan Mole
# 	coworker:
# 		Auvi Moelo
# 		Cyang Lionelwind
# 		Riog Banbin
# 		Yuyu Barang
# 		Sefros Alvin
# 	connected:
# 		the den of the thieves guild of Figliz
# 	thief:
# 		the den of the thieves guild of Figliz
# Wadia Yugo:
# 	connected:
# 		A classroom of Yarmecia Academy
# 	spouse:
# 		Odra Yugo
# 	related_to:
# 		Baromu Yugo
# 		Odra Yugo
# 	parent:
# 		Baromu Yugo
# 	professor:
# 		A classroom of Yarmecia Academy
# Goan Celle:
# 	connected:
# 		Old Wana's Inn
# 	regular:
# 		Old Wana's Inn
# Kathryn Sophia:
# 	connected:
# 		Old Wana's Inn
# 	spouse:
# 		Eddy Sophia
# 	related_to:
# 		Celau Sophia
# 		Eddy Sophia
# 	parent:
# 		Celau Sophia
# 	boss:
# 		Owea Tia
# 		Sefzer Umaphie
# 	owner:
# 		Old Wana's Inn
# Lesa Moka:
# 	employee:
# 		Penon Moka
# 	coworker:
# 		Kefelo Yugo
# 		Umber Penin
# 	connected:
# 		the  auction house of Melamb
# 	related_to:
# 		Atrean Moka
# 		Penon Moka
# 	child:
# 		Penon Moka
# 		Atrean Moka
# 	curator:
# 		the  auction house of Melamb
# Zibin Darkrunner:
# 	connected:
# 		Old Tellelia's Tavern
# 	regular:
# 		Old Tellelia's Tavern
# Kefom Zeres:
# 	spy:
# 		the den of the thieves guild of Figliz
# 	employee:
# 		Vida Dasa
# 	coworker:
# 		Nacreous Wilma
# 		Irma Adomu
# 	connected:
# 		the den of the thieves guild of Figliz
# Sefa Yuis:
# 	connected:
# 		Mable's Tavern
# 	regular:
# 		Mable's Tavern
# Shower Brightheart:
# 	connected:
# 		a boat docked in the port of Ebrook
# 	boss:
# 		Freeze Coith
# 		Jessie Frides
# 		Quisan Tidia
# 		Steindow Vana
# 		Chadara Goah
# 	captain:
# 		a boat docked in the port of Ebrook
# Penel Baier:
# 	connected:
# 		The Red Lion Inn
# 	regular:
# 		The Red Lion Inn
# Drought Deathsun:
# 	connected:
# 		The Red Lion Inn
# 	spouse:
# 		Tibin Deathsun
# 	related_to:
# 		Cele Deathsun
# 		Tibin Deathsun
# 	parent:
# 		Cele Deathsun
# 	boss:
# 		Auides Glaucous
# 		Odra Yugo
# 	owner:
# 		The Red Lion Inn
# Fractus Deathhart:
# 	coworker:
# 		Gust Shininghunter
# 		Rime Riryl
# 		Frith Mortewind
# 		Terdia Shaa
# 	connected:
# 		The Poisoned Kobold Tavern
# 		the marketplace of Melamb
# 	regular:
# 		The Poisoned Kobold Tavern
# 	victim:
# 		Yuel Leroy
# 		Jet Umadus
# 		Edna Kinoa
# 	vendor:
# 		the marketplace of Melamb
# 	scared:
# 		Edna Kinoa
# 		Yuel Leroy
# 		Jet Umadus
# 	likes:
# 		Ira Lifemoon -5
# 		Yuel Leroy -5
# 		Edna Kinoa -8
# Coine Edbin:
# 	coworker:
# 		Celer Celer
# 		Irene Emil
# 		Ice Pearl
# 		Typhoon Pearl
# 		Elbert Edbin
# 	connected:
# 		ruins
# 	spouse:
# 		Elbert Edbin
# 	related_to:
# 		Elbert Edbin
# 	bard:
# 		ruins
# Downburst Darkcursor:
# 	employee:
# 		Ollie Lerett
# 	coworker:
# 		Quiel Shayu
# 	connected:
# 		Old Lerett's Inn
# 	barkeep:
# 		Old Lerett's Inn
# 	tourist:
# 		the  opera house of Melamb
# Kier Kefom:
# 	connected:
# 		The Red Lion Inn
# 	regular:
# 		The Red Lion Inn
# Pentzer Letel:
# 	employee:
# 		Adzer Moan
# 	coworker:
# 		Yuomu Eddie
# 		Banrett Sedus
# 		Viridian Ola
# 		Gust Seifer
# 		Cean Seifer
# 		Penro Quitis
# 	connected:
# 		the mines of Dolbrae
# 	spouse:
# 		Calamine Letel
# 	related_to:
# 		Calamine Letel
# 	tourist:
# 		amphitheatre
# 	worker:
# 		the mines of Dolbrae
# 	miner:
# 		the mines of Dolbrae
# Terku Ashvi:
# 	employee:
# 		Porah Leelia
# 	coworker:
# 		Quiso Gordon
# 	connected:
# 		The Old Lonely Yak
# 	barkeep:
# 		The Old Lonely Yak
# Ryle Vana:
# 	employee:
# 		Horace Seifis
# 	connected:
# 		the shipyard of Ebrook
# 	spouse:
# 		Jeanette Vana
# 	related_to:
# 		Steindow Vana
# 		Zeran Vana
# 		Jeanette Vana
# 	tourist:
# 		amphitheatre
# 	parent:
# 		Steindow Vana
# 		Zeran Vana
# 	boss:
# 		Kefvi Frides
# 		Brangan Ria
# 		Ledane Steingo
# 		Kiau Morteheart
# 	engineer:
# 		the shipyard of Ebrook
# Anvil Noctwalker:
# 	spouse:
# 		Wayne Noctwalker
# 	related_to:
# 		Quisom Noctwalker
# 		Umadus Noctwalker
# 		Wayne Noctwalker
# 	parent:
# 		Umadus Noctwalker
# 		Quisom Noctwalker
# 	confined:
# 		the gaol of Baltissia castle
# Vile Mona:
# 	connected:
# 		Old Lerett's Inn
# 	regular:
# 		Old Lerett's Inn
# Auer Mildred:
# 	connected:
# 		Old Wana's Inn
# 	regular:
# 		Old Wana's Inn
# Russet Shiningfighter:
# 	connected:
# 		The Poisoned Kobold Tavern
# 	regular:
# 		The Poisoned Kobold Tavern
# Quisah Pensa:
# 	coworker:
# 		Ashau Andorwalker
# 		Flurry Adgo
# 		Kana Rogan
# 		Nacreous Codus
# 		Bancil Quion
# 	connected:
# 		the marketplace of Jundacio
# 	spouse:
# 		Downburst Pensa
# 	related_to:
# 		Downburst Pensa
# 	tourist:
# 		amphitheatre
# 	victim:
# 		Burlywood Yudus
# 		Downburst Pensa
# 		Aerka Alma
# 	vendor:
# 		the marketplace of Jundacio
# 	scared:
# 		Downburst Pensa
# 		Aerka Alma
# 		Burlywood Yudus
# 	likes:
# 		Aerka Alma -5
# 		Waan Cerise -8
# 		Tifyu Highvenator -9
# 		Downburst Pensa -7
# Aeromu Aerle:
# 	connected:
# 		ruins
# 	rival:
# 		Roa Morteheart
# 		Coang Adea
# 	treasure_hunter:
# 		ruins
# Kefro Sefgo:
# 	connected:
# 		The Old Lonely Yak
# 	regular:
# 		The Old Lonely Yak
# Edwin Seldane:
# 	employee:
# 		Tibin Deathsun
# 		Riomu Yugo
# 		Cele Deathsun
# 	coworker:
# 		Odtzer Della
# 		Abraham Glaucous
# 		Zemdane Ceryl
# 		Baris Ceryl
# 		Atrean Moka
# 		Quiku Della
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Jet Seldane
# 	related_to:
# 		Jet Seldane
# 	bard:
# 		the  opera house of Melamb
# Kiau Morteheart:
# 	employee:
# 		Ryle Vana
# 		Horace Seifis
# 		Jeanette Vana
# 	coworker:
# 		Brangan Ria
# 		Ledane Steingo
# 		Kefvi Frides
# 	connected:
# 		the shipyard of Ebrook
# 	ship_builder:
# 		the shipyard of Ebrook
# Jet Seldane:
# 	coworker:
# 		Storm Branith
# 		Zerin Sanoa
# 	connected:
# 		the  gardens of Edon manor
# 	spouse:
# 		Edwin Seldane
# 	related_to:
# 		Edwin Seldane
# 	worker:
# 		the  gardens of Edon manor
# 	servant:
# 		Barelia Edon
# Riomu Yugo:
# 	employee:
# 		Cele Deathsun
# 	coworker:
# 		Tibin Deathsun
# 	connected:
# 		the  opera house of Melamb
# 	spouse:
# 		Kefelo Yugo
# 	related_to:
# 		Odra Yugo
# 		Kefelo Yugo
# 	parent:
# 		Odra Yugo
# 	boss:
# 		Edwin Seldane
# 		Atrean Moka
# 		Quiku Della
# 		Odtzer Della
# 		Abraham Glaucous
# 		Baris Ceryl
# 		Zemdane Ceryl
# 	rival:
# 		Tibin Deathsun
# 	diva:
# 		the  opera house of Melamb
# Dora Zema:
# 	connected:
# 		Royal Library of Baltissia
# 		Throne Room of Baltissia
# 	child:
# 		Waa Secil
# 	sibling:
# 		Chill Zema
# Chill Zema:
# 	connected:
# 		Royal Library of Baltissia
# 		Throne Room of Baltissia
# 	child:
# 		Waa Secil
# 	sibling:
# 		Dora Zema
# Jet Secil:
# 	spouse:
# 		Branka Secil
# 	related_to:
# 		Sepia Palis
# 		Branka Secil
# 		Waa Secil
# 	parent:
# 		Sepia Palis
# 		Waa Secil
# Branka Secil:
# 	spouse:
# 		Jet Secil
# 	related_to:
# 		Sepia Palis
# 		Waa Secil
# 		Jet Secil
# 	parent:
# 		Sepia Palis
# 		Waa Secil
# Crest Kefka:
# 	related_to:
# 		Sleet Kefka
# 		Adros Kefka
# 	child:
# 		Sleet Kefka
# 		Adros Kefka
# Vanook Noctwalker:
# 	related_to:
# 		Branka Noctwalker
# 		Umadus Noctwalker
# 	child:
# 		Umadus Noctwalker
# 		Branka Noctwalker
# Sleet Palis:
# 	related_to:
# 		Sepia Palis
# 		Lizzie Palis
# 		Leta Palis
# 	child:
# 		Leta Palis
# 		Sepia Palis
# 	sibling:
# 		Lizzie Palis
# Lizzie Palis:
# 	related_to:
# 		Sepia Palis
# 		Leta Palis
# 		Sleet Palis
# 	child:
# 		Leta Palis
# 		Sepia Palis
# 	sibling:
# 		Sleet Palis
# Bransa Sais:
# 	spouse:
# 		Chadarrett Sais
# 	related_to:
# 		Chadarrett Sais
# 		Gust Seifer
# 	parent:
# 		Gust Seifer
# Chadarrett Sais:
# 	spouse:
# 		Bransa Sais
# 	related_to:
# 		Bransa Sais
# 		Gust Seifer
# 	parent:
# 		Gust Seifer
# Kaelia Seifer:
# 	related_to:
# 		Cean Seifer
# 		Gust Seifer
# 	child:
# 		Gust Seifer
# 		Cean Seifer
# Quiea Coith:
# 	spouse:
# 		Quisog Coith
# 	related_to:
# 		Quisog Coith
# 		Anvil Coith
# 		Freeze Coith
# 	parent:
# 		Freeze Coith
# 		Anvil Coith
# Quisog Coith:
# 	spouse:
# 		Quiea Coith
# 	related_to:
# 		Quiea Coith
# 		Anvil Coith
# 		Freeze Coith
# 	parent:
# 		Anvil Coith
# 		Freeze Coith
# Barelia Edon:
# 	connected:
# 		Library of Edon manor
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	spouse:
# 		Shavi Edon
# 	parent:
# 		Branka Edon
# 	owner:
# 		Library of Edon manor
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  auction house of Melamb
# 		the  opera house of Melamb
# Shavi Edon:
# 	connected:
# 		Library of Edon manor
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	spouse:
# 		Barelia Edon
# 	parent:
# 		Branka Edon
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Branka Edon:
# 	connected:
# 		Library of Edon manor
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	child:
# 		Barelia Edon
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Updraft Kaom:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Ryle Clearstalker:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Polar Hawkinshart:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Gerald Saer:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Aeran Ada:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Tellka Banus:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Strais Quier:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Thelma Brighthart:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Cerulean Terrasoul:
# 	connected:
# 		the  opera house of Melamb
# 		Library of Edon manor
# 		the  auction house of Melamb
# 		the  gallery of Edon manor
# 		the  ballroom of Edon manor
# 		the  gardens of Edon manor
# 	patron:
# 		the  opera house of Melamb
# 		the  auction house of Melamb
# 	guest:
# 		the  gardens of Edon manor
# 		the  gallery of Edon manor
# 		Library of Edon manor
# 		the  ballroom of Edon manor
# Vian Bramwalker:
# 	related_to:
# 		Tidia Bramwalker
# 		Tiah Bramwalker
# 	child:
# 		Tidia Bramwalker
# 		Tiah Bramwalker
# Pengo Noxheart:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Updraft Baris:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Ashan Pentzer:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Atrezer Zemin:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Azure Vaah:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Raindrop Steingo:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Sable Yuer:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Kielo Baicil:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Auin Lucile:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Banan Atreom:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Shaom Odford:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Lula Brantzer:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Viel Tawny:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Winifred Zerna:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Cela Dazer:
# 	connected:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# 	student:
# 		A classroom of Yarmecia Academy
# 		Library of Yarmecia Academy
# Baromu Yugo:
# 	related_to:
# 		Odra Yugo
# 		Wadia Yugo
# 	child:
# 		Odra Yugo
# 		Wadia Yugo
# Gael Gordon:
# 	related_to:
# 		Quiso Gordon
# 		Flurry Gordon
# 		Baron Gordon
# 	child:
# 		Baron Gordon
# 		Quiso Gordon
# 	sibling:
# 		Flurry Gordon
# Flurry Gordon:
# 	related_to:
# 		Quiso Gordon
# 		Gael Gordon
# 		Baron Gordon
# 	child:
# 		Baron Gordon
# 		Quiso Gordon
# 	sibling:
# 		Gael Gordon
# Kaa Leo:
# 	connected:
# 		The Temple of Tenepo
# 	boss:
# 		Storm Riros
# 		Charlie Steinon
# 		Rycil Terle
# 		Gaelo Palphie
# 		Steiner Broncofighter
# 		Kaford Rielia
# 		Rime Frtis
# 		Leom Quisrett
# 		Anna Caelumsoul
# 		Crest Terraingredior
# 	high_priest:
# 		The Temple of Tenepo
# Rime Frtis:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	priest:
# 		The Temple of Tenepo
# Anna Caelumsoul:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	priest:
# 		The Temple of Tenepo
# Crest Terraingredior:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	priest:
# 		The Temple of Tenepo
# Charlie Steinon:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	monk:
# 		The Temple of Tenepo
# Steiner Broncofighter:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	monk:
# 		The Temple of Tenepo
# Rycil Terle:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	monk:
# 		The Temple of Tenepo
# Gaelo Palphie:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	monk:
# 		The Temple of Tenepo
# Kaford Rielia:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	monk:
# 		The Temple of Tenepo
# Storm Riros:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	monk:
# 		The Temple of Tenepo
# Leom Quisrett:
# 	employee:
# 		Kaa Leo
# 	connected:
# 		The Temple of Tenepo
# 	monk:
# 		The Temple of Tenepo
# Ashides Sophie:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Yua Celka:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Quisan Delphinerunner:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Penith Ada:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Adelo Umana:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Kigo Edenwalker:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Atrean Quia:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Reshabar Magnolia:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Palzer Banvi:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Typhoon Fryu:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Gaan Tio:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Ashan Coquelicot:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Nacreous Codus:
# 	coworker:
# 		Quisah Pensa
# 		Ashau Andorwalker
# 		Flurry Adgo
# 		Kana Rogan
# 		Bancil Quion
# 	connected:
# 		The Temple of Tenepo
# 		the marketplace of Jundacio
# 	victim:
# 		Burlywood Yudus
# 		Downburst Pensa
# 		Aerka Alma
# 	vendor:
# 		the marketplace of Jundacio
# 	scared:
# 		Downburst Pensa
# 		Aerka Alma
# 		Burlywood Yudus
# 	likes:
# 		Burlywood Yudus -3
# 		Aerka Alma -4
# 		Waan Cerise -5
# 		Tifyu Highvenator -8
# 		Downburst Pensa -3
# 	follower:
# 		The Temple of Tenepo
# Kadia Pylaewalker:
# 	employee:
# 		Breeze Melvin
# 	coworker:
# 		Calamine Quion
# 		Pileus Andorwalker
# 	connected:
# 		The Temple of Tenepo
# 		Melvin's Inn
# 	barkeep:
# 		Melvin's Inn
# 	spouse:
# 		Tifsa Pylaewalker
# 	related_to:
# 		Tifsa Pylaewalker
# 		Thunder Pylaewalker
# 		Wind Pylaewalker
# 	parent:
# 		Wind Pylaewalker
# 		Thunder Pylaewalker
# 	follower:
# 		The Temple of Tenepo
# Barrett Poran:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Katherine Steinros:
# 	connected:
# 		The Temple of Tenepo
# 		Melvin's Inn
# 	regular:
# 		Melvin's Inn
# 	follower:
# 		The Temple of Tenepo
# Kago Guy:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Eddy Sefrett:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Calamine Quion:
# 	employee:
# 		Breeze Melvin
# 	coworker:
# 		Kadia Pylaewalker
# 		Pileus Andorwalker
# 	connected:
# 		The Temple of Tenepo
# 		Melvin's Inn
# 	barkeep:
# 		Melvin's Inn
# 	spouse:
# 		Bancil Quion
# 	related_to:
# 		Bancil Quion
# 		Flurry Adgo
# 		Brandia Adgo
# 	child:
# 		Brandia Adgo
# 		Flurry Adgo
# 	follower:
# 		The Temple of Tenepo
# Tertis Kaka:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Col Auford:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Zema Aerna:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Riine Branah:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Umaan Eva:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Shower Senoa:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Aues Kefog:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Zerdia Lunahunter:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Gale Owgo:
# 	connected:
# 		The Temple of Tenepo
# 	follower:
# 		The Temple of Tenepo
# Kana Rogan:
# 	coworker:
# 		Quisah Pensa
# 		Ashau Andorwalker
# 		Flurry Adgo
# 		Nacreous Codus
# 		Bancil Quion
# 	connected:
# 		The Temple of Tenepo
# 		the marketplace of Jundacio
# 	victim:
# 		Burlywood Yudus
# 		Downburst Pensa
# 		Aerka Alma
# 	vendor:
# 		the marketplace of Jundacio
# 	scared:
# 		Downburst Pensa
# 		Aerka Alma
# 		Burlywood Yudus
# 	likes:
# 		Aerka Alma -3
# 		Waan Cerise -6
# 		Tifyu Highvenator -3
# 		Downburst Pensa -9
# 	follower:
# 		The Temple of Tenepo
# Aerka Alma:
# 	employee:
# 		Downburst Pensa
# 	coworker:
# 		Burlywood Yudus
# 	connected:
# 		The Temple of Tenepo
# 		the marketplace of Jundacio
# 	enforcer:
# 		the marketplace of Jundacio
# 	follower:
# 		The Temple of Tenepo
# Owa Earnest:
# 	related_to:
# 		Updraft Earnest
# 		Wana Earnest
# 	child:
# 		Wana Earnest
# 		Updraft Earnest
# Umaoth Noctstalker:
# 	related_to:
# 		Aero Noctstalker
# 		Tier Noctstalker
# 		Blow Noctstalker
# 	child:
# 		Tier Noctstalker
# 		Aero Noctstalker
# 	sibling:
# 		Blow Noctstalker
# Blow Noctstalker:
# 	related_to:
# 		Aero Noctstalker
# 		Umaoth Noctstalker
# 		Tier Noctstalker
# 	child:
# 		Tier Noctstalker
# 		Aero Noctstalker
# 	sibling:
# 		Umaoth Noctstalker
# Freeze Seifan:
# 	spouse:
# 		Smalt Seifan
# 	related_to:
# 		Manuel Seifan
# 		Smalt Seifan
# 	parent:
# 		Manuel Seifan
# Smalt Seifan:
# 	spouse:
# 		Freeze Seifan
# 	related_to:
# 		Manuel Seifan
# 		Freeze Seifan
# 	parent:
# 		Manuel Seifan
# Manuel Seifan:
# 	related_to:
# 		Smalt Seifan
# 		Freeze Seifan
# 	child:
# 		Smalt Seifan
# 		Freeze Seifan
# Rian Rier:
# 	spouse:
# 		Roer Rier
# 	related_to:
# 		Roer Rier
# Roer Rier:
# 	spouse:
# 		Rian Rier
# 	related_to:
# 		Rian Rier
# Thunder Pylaewalker:
# 	related_to:
# 		Tifsa Pylaewalker
# 		Wind Pylaewalker
# 		Kadia Pylaewalker
# 	child:
# 		Kadia Pylaewalker
# 		Tifsa Pylaewalker
# 	sibling:
# 		Wind Pylaewalker
# Wind Pylaewalker:
# 	related_to:
# 		Tifsa Pylaewalker
# 		Thunder Pylaewalker
# 		Kadia Pylaewalker
# 	child:
# 		Kadia Pylaewalker
# 		Tifsa Pylaewalker
# 	sibling:
# 		Thunder Pylaewalker
# Karo Andorwalker:
# 	related_to:
# 		Pileus Andorwalker
# 		Riine Andorwalker
# 		Ashau Andorwalker
# 	child:
# 		Pileus Andorwalker
# 		Ashau Andorwalker
# 	sibling:
# 		Riine Andorwalker
# Riine Andorwalker:
# 	related_to:
# 		Pileus Andorwalker
# 		Ashau Andorwalker
# 		Karo Andorwalker
# 	child:
# 		Pileus Andorwalker
# 		Ashau Andorwalker
# 	sibling:
# 		Karo Andorwalker
# None

# %%
print(len(sequence.active_module.population))
import json
with open('population.json','w') as outfile:
    outfile.write(json.dumps(sequence.active_module.to_json(), sort_keys=True, indent=4))
# Out:
# 319
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-47f8cbb56173> in <module>
#       2 import json
#       3 with open('population.json','w') as outfile:
# ----> 4     outfile.write(json.dumps(sequence.active_module.to_json(), sort_keys=True, indent=4))
#
# ~\anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232     if cls is None:
#     233         cls = JSONEncoder
# --> 234     return cls(
#     235         skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#
# ~\anaconda3\lib\json\encoder.py in encode(self, o)
#     199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# --> 201             chunks = list(chunks)
#     202         return ''.join(chunks)
#     203
#
# ~\anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# ~\anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~\anaconda3\lib\json\encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~\anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~\anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     374                 continue
#     375             else:
# --> 376                 raise TypeError(f'keys must be str, int, float, bool or None, '
#     377                                 f'not {key.__class__.__name__}')
#     378             if first:
#
# TypeError: keys must be str, int, float, bool or None, not tuple

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.array(
    [[1600,160,49.2],
        [800,80,29.7],
        [400,80,20],
        [400,40,19.6],
        [200,20,14.7],
        [100,10,12.7],
        [40, 2,9.31],
        [20, 2,8.42],
        [10, 10,6.94],
        [10, 1, 7.05]])
plt.plot(data[:,0],data[:,2],'bx')
print(data[:,2]/data[:,0])

# %%
sequence.active_module.to_json()

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_location_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp -t 8

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_location_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp -t 8

# %%
print(sequence.active_module.display_traits(ignore_default_traits=True))

# %%
! clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population_locations.lp C:\Users\adams\Documents\Research\Kismet\kismet\volition.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_history.lp
# Out:
# clingo version 5.4.0
# Reading from ...ents\Research\Kismet\kismet\default.lp ...
# UNKNOWN
#
# Models       : 0+
# Calls        : 1
# Time         : 0.178s (Solving: 0.00s 1st Model: 0.00s Unsat: 0.00s)
# CPU Time     : 0.172s
# C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp:1016:1-149: error: unsafe variables in:
#   update(Disliker,likes,Self,1):-[#inc_base];occurred(action(stand_up_for_friend_and_persuade,Self,Other,Friend,null,null));not #p_is(#b(Disliker),likes,#b(Self),#p).
# C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp:1016:8-16: note: 'Disliker' is unsafe
#
# C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp:1018:1-153: error: unsafe variables in:
#   update(Disliker,likes,Friend,1):-[#inc_base];occurred(action(stand_up_for_friend_and_persuade,Self,Other,Friend,null,null));not #p_is(#b(Disliker),likes,#b(Friend),#p).
# C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp:1018:8-16: note: 'Disliker' is unsafe
#
# C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp:1052:1-146: error: unsafe variables in:
#   update(Disliker,likes,Self,-1):-[#inc_base];occurred(action(stand_up_for_friend_and_fail,Self,Other,Friend,null,null));not #p_is(#b(Disliker),likes,#b(Self),#p).
# C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp:1052:8-16: note: 'Disliker' is unsafe
#
# C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp:1064:1-150: error: unsafe variables in:
#   update(Disliker,likes,Friend,-1):-[#inc_base];occurred(action(stand_up_for_friend_and_fail,Self,Other,Friend,null,null));not #p_is(#b(Disliker),likes,#b(Friend),#p).
# C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp:1064:8-16: note: 'Disliker' is unsafe
#
# *** ERROR: (clingo): grounding stopped because of errors
