# %%
if True:
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet.ebnv
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_initialization.ebnf
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_sequence.ebnf

# %%
import KismetSequence

# %%
sequence = KismetSequence.KismetSequence(sequence_file = 'gtbbt.seq')#'gtbbt.seq')
# Out:
# SEQUENCE STATEMENT [('Load', [('File', 'fantasy_broad.kismet'), ('TRACERY', []), ('File', '../tracery/fantasy.tracery')])]
# SEQUENCE STATEMENT [('Initialize', [('File', 'fantasy_setting.init')])]
# INITIALIZATION []
# SEQUENCE STATEMENT [('Run', [('Until', [('UntilClauses', [('Duration', [('Num', '10'), ('Name', 'steps')])])])])]

# %%
# %%time
from IPython.display import clear_output


clear_output(wait=True)
sequence()
# Out:
# Running Kismet Sequence from "gtbbt.seq"
# Starting New Step: Loading ['fantasy_broad.kismet'] with Tracery Files ['../tracery/fantasy.tracery']
# *************************POTENTIAL PROBLEMS*************************
# Locations: Not referenced in actions or traits
# 	shipyard
# 	marketplace
# 	amphitheatre
# 	docks
# 	elders_house
# 	ballroom
# 	house
# 	library
# 	opera_house
# 	boat
# 	classroom
# 	temple
# 	ruins
# 	thieves_den
# 	kitchen
# 	garden
# 	throne_room
# 	auction_house
# 	mine
# 	town
# 	smith
# Tags: Not referenced in traits
# 	criticial
# 	open
# 	physical
# 	work
# 	creative
# 	angry
# 	criminal
# 	mariner
# Tags: Referenced in traits but not found in actions
# 	agree
# 	abusive
# Traits: Not referenced in actions
# 	carer
# 	family_ties
# 	introvert
# 	visiting_places_you_like
# 	gruff
# 	abusive_if_abusive
# 	free_spirited
# 	cautious
# 	do_more_specific_things
# 	visiting_as_regular
# 	confident
# 	no_pedophilia
# 	comic
# 	critical
# 	feral
# ...

# %%
sequence.active_module.pretty_print_history()
# Out:
# [('season', 'summer'), ('year', 1099)]
# At their own mind:
# 	worry_about_future200 Saelia Walter
# At Throne Room of Baltissia:
# 	chit_chat80 Chadarcil Vita, Morett Terrawind
# 	consult_with_chancellor191 Morett Terrawind, Cyelo Terrarunner
# 	sway_monarch_to_kindness193 Cyelo Terrarunner, Morett Terrawind
# At Royal Library of Baltissia:
# 	Agnes Lean bores Flumen Terrawind who grows to dislike Agnes Lean
# 	insult95 Zerides Goka, Barrett Beatrice
# 	criticize104 Flumen Terrawind, Zerides Goka
# 	stock_books150 Barrett Beatrice
# At castle kitchen of Baltissia:
# 	bitch_about_boss161 Straro Kefryl, Alta Terau, Gale Arnold
# 	pine_over89 Tifnook Terrawind, Straro Kefryl
# 	bitch_about_boss161 Alta Terau, Straro Kefryl, Gale Arnold
# At the barracks of Baltissia castle:
# 	guard_prison255 Waoth Deathhart
# At the Lillian house in Baltissia:
# 	complain_to_and_make_annoyed81 Bert Lillian, Gaford Clearsun
# 	pine_over89 Gaford Clearsun, Vazer Elsie
# ...

# %%
sequence.active_module.population
# Out:
# {'character0': {'name': 'Zerides Goka',
#   'asp_name': 'zerides_goka',
#   'traits': {'abusive_if_abusive',
#    'confident',
#    'conscientious',
#    'do_more_specific_things',
#    'do_role_specific_actions',
#    'fail_when_interactin_with_person_who_dislikes_you1',
#    'fail_when_interactin_with_person_who_dislikes_you2',
#    'family_ties',
#    'go_to_locations_you_have_connection_with',
#    'introvert',
#    'mean_to_people_you_dislike1',
#    'mean_to_people_you_dislike2',
#    'mean_to_people_you_dislike3',
#    'nice_to_people_you_like1',
#    'no_pedophilia',
#    'people_are_usually_serious',
#    'people_joke_with_joker',
#    'rare_things_rare',
#    'romantic_towards_crush',
#    'scholar',
#    'stay_at_hometown',
#    'stay_in_confinement',
#    'stern',
#    'visiting_as_regular',
#    'visiting_places_you_like',
#    'xrare_things_xrare'},
#   'status': {('last_birthday',): 'time(summer,1098)',
#    ('skin',): 'beige',
#    ('hair',): 'purple',
# ...

# %%
sequence.active_module.display_statuses()
# Out:
# Zerides Goka:
# 	last_birthday : time(summer,1098)
# 	skin : beige
# 	hair : purple
# 	eye : orange
# 	presentation : butch
# 	pronouns : he/him
# 	age : 57
# 	self_worth : -1
# 	crushing_on Agnes Lean
# 	introvert
# 	confident
# 	conscientious
# 	stern
# 	scholar
# Virga Aertis:
# 	last_birthday : time(fall,1098)
# 	skin : ivory
# 	hair : purple
# 	eye : green
# 	presentation : butch
# 	pronouns : she/her
# 	age : 37
# 	self_worth : 1
# 	happiness : 1
# 	drunk
# 	tiredness : 0
# 	introvert
# 	careless
# 	duty_bound
# 	scholar
# Selomu Solheart:
# 	last_birthday : time(spring,1098)
# 	skin : amber
# 	hair : pink
# 	eye : orange
# 	presentation : butch
# 	pronouns : they/them
# 	age : 49
# 	crushing_on Yuah Ashtzer
# 	comic
# 	careless
# 	curious
# 	compassionate
# Saang Auea:
# 	last_birthday : time(summer,1098)
# 	skin : almond
# 	hair : blue
# 	eye : blue
# 	presentation : butch
# 	pronouns : she/her
# 	age : 48
# 	crushing_on Tellel Tira
# 	self_worth : -1
# 	careless
# ...

# %%
print(len(sequence.active_module.population))
sequence.active_module.display_relationships()
# Out:
# 241
# Zerides Goka:
# 	tourist:
# 		the  opera house of Melamb
# 	likes:
# 		Flumen Terrawind -1
# 		Senook Conallrunner -2
# 		Spindrift Tigan 1
# 		Teran Umaoth -3
# 		Cya Zerdus 1
# 		Edna Strana -1
# 		Baiine Kidane -1
# 	loves:
# 		Spindrift Tigan 1
# 		Edna Strana 1
# Virga Aertis:
# 	tourist:
# 		amphitheatre
# 	likes:
# 		Kaa Banryl 1
# 		Yuis Clearcursor -1
# 		Kais Seryl -1
# 		Hail Teran 1
# 		Clyde Riyu -1
# 		Palom Coea 2
# 		Bartzer Zemog -3
# Selomu Solheart:
# 	tourist:
# 		the  opera house of Melamb
# 	likes:
# 		Moel Conallrunner 1
# 		Allen Frnook 4
# 		Yuah Ashtzer 1
# 		Agnes Lean 1
# 		Seifford Frnook 1
# 		Baiine Kidane 1
# 		Haze Aqualinasoul 1
# 		Essie Umaoth 1
# 		Letang Kidane -1
# 		Umain Calamine -5
# 		Teran Umaoth -1
# 	loves:
# 		Moel Conallrunner 1
# 		Yuah Ashtzer 1
# 		Agnes Lean 1
# Saang Auea:
# 	tourist:
# 		amphitheatre
# 	loves:
# 		Tifes Straa 1
# 		Palom Coea 1
# 		Kaau Terelia 1
# 		Letog Frieda 1
# 	likes:
# 		Agnes Lean 1
# ...

# %%
print(len(sequence.active_module.population))
import json
with open('population.json','w') as outfile:
    outfile.write(json.dumps(sequence.active_module.to_json(), sort_keys=True, indent=4))
# Out:
# 241

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.array(
    [[1600,160,49.2],
        [800,80,29.7],
        [400,80,20],
        [400,40,19.6],
        [200,20,14.7],
        [100,10,12.7],
        [40, 2,9.31],
        [20, 2,8.42],
        [10, 10,6.94],
        [10, 1, 7.05]])
plt.plot(data[:,0],data[:,2],'bx')
print(data[:,2]/data[:,0])
# Out:
# [0.03075  0.037125 0.05     0.049    0.0735   0.127    0.23275  0.421
#  0.694    0.705   ]

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_actions.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population_locations.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_history.lp C:\Users\adams\Documents\Research\Kismet\kismet\results_processing.lp
# Out:
# clingo version 5.4.0
# Reading from ...ents\Research\Kismet\kismet\default.lp ...
# Solving...
# Answer: 1
# ...

# %%
print(sequence.active_module.display_traits(ignore_default_traits=True))
# Out:
# Zerides Goka:
# 	introvert
# 	confident
# 	conscientious
# 	stern
# 	scholar
# Virga Aertis:
# 	introvert
# 	careless
# 	duty_bound
# 	scholar
# Selomu Solheart:
# 	comic
# 	careless
# 	curious
# 	compassionate
# Saang Auea:
# 	careless
# 	duty_bound
# 	romantic
# 	agreeable
# 	scholar
# Pileus Penoth:
# 	introvert
# 	feral
# 	romantic
# 	bully
# Frost Ariellawalker:
# 	gruff
# 	extrovert
# 	neurotic
# 	compassionate
# Rainbow Leah:
# 	carer
# 	extrovert
# 	duty_bound
# 	romantic
# 	ignoramus
# Kaau Terelia:
# 	cautious
# 	critical
# 	conscientious
# 	ignoramus
# 	bully
# Tifes Straa:
# 	introvert
# 	feral
# 	indifferent
# 	duty_bound
# 	scholar
# Wanook Earthhart:
# 	feral
# 	indifferent
# 	duty_bound
# 	agreeable
# 	bully
# Yuah Ashtzer:
# 	free_spirited
# 	comic
# 	critical
# 	neurotic
# Tellel Tira:
# 	free_spirited
# 	feral
# 	careless
# 	romantic
# Jane Auelia:
# 	careless
# 	agreeable
# 	ignoramus
# 	family_oriented
# Chill Adeline:
# 	critical
# 	romantic
# 	family_oriented
# ...

# %%
! clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population_locations.lp C:\Users\adams\Documents\Research\Kismet\kismet\volition.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_history.lp
# Out:
# clingo version 5.4.0
# Reading from ...ents\Research\Kismet\kismet\default.lp ...
# Solving...
# Answer: 1
# ...

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population_locations.lp C:\Users\adams\Documents\Research\Kismet\kismet\volition.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_history.lp
# Out:
# clingo version 5.4.0
# Reading from ...ents\Research\Kismet\kismet\default.lp ...
# Solving...
# Answer: 1
# ...

# %%
import pyximport; pyximport.install()
import parse_terms
parse_terms.parse_terms('hello(world,goodbye(world))')
# Out:
# ([{'predicate': 'hello',
#    'terms': [{'predicate': 'world'},
#     {'predicate': 'goodbye', 'terms': [{'predicate': 'world'}]}]}],
#  '')
