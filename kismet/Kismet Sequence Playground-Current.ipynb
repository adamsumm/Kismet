# %%
if True:
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet.ebnv
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_initialization.ebnf
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_sequence.ebnf

# %%
import KismetSequence
import random
import numpy as np

seed = 10
np.random.seed(seed)
random.seed(seed)

# %%
sequence = KismetSequence.KismetSequence(sequence_file = 'gtbbt.seq')#'gtbbt.seq')
# Out:
# SEQUENCE STATEMENT [('Load', [('File', 'fantasy_broad.kismet'), ('TRACERY', []), ('File', '../tracery/fantasy.tracery')])]
# SEQUENCE STATEMENT [('Initialize', [('File', 'fantasy_setting.init')])]
# SEQUENCE STATEMENT [('Run', [('Until', [('UntilClauses', [('UntilClause', [('Quantity', [('Num', '0')]), ('Characters',), ('InPattern', [('Name', 'lacking_path'), ('Num', '2')])])])])])]

# %%
# %%time
from IPython.display import clear_output


clear_output(wait=True)
sequence()
# Out:
# Running Kismet Sequence from "gtbbt.seq"
# Starting New Step: Loading ['fantasy_broad.kismet'] with Tracery Files ['../tracery/fantasy.tracery']
# *************************POTENTIAL PROBLEMS*************************
# Locations: Not referenced in actions or traits
# 	elders_house
# 	auction_house
# 	town
# 	docks
# 	throne_room
# 	smith
# 	house
# 	library
# 	amphitheatre
# 	boat
# 	ruins
# 	mine
# 	kitchen
# 	temple
# 	marketplace
# 	shipyard
# 	barracks
# 	garden
# 	thieves_den
# 	opera_house
# 	ballroom
# 	classroom
# Tags: Not referenced in traits
# 	creative
# 	work
# 	criticial
# 	physical
# 	open
# 	angry
# 	mariner
# 	criminal
# Tags: Referenced in traits but not found in actions
# 	abusive
# 	agree
# Traits: Not referenced in actions
# 	knights_go_around
# 	curious
# 	people_are_usually_serious
# 	feral
# 	cautious
# 	family_oriented
# 	make_chosen_one_connections_occurLACKING
# 	visiting_places_you_like
# 	make_chosen_one_connections_occur
# 	careless
# 	conscientious
# ...

# %%
sequence.active_module.pretty_print_history()
# Out:
# [('season', 'summer'), ('year', 1057)]
# At Throne Room of Baltissia:
# 	sway_monarch_to_indifference185 Zerrett Kaan, Myrtle Russet
# 	chit_chat71 Ader Edea, Freyel Penryl
# 	consult_with_chancellor182 Myrtle Russet, Zerrett Kaan
# 	develop_crush79 Freyel Penryl, Myrtle Russet
# 	insult_as_bully85 Pearl Riea, Myrtle Russet
# 	criticize95 Sefgo Barryl, Pearl Riea
# At Royal Library of Baltissia:
# 	attend_class236 Vaus Kaan
# At castle kitchen of Baltissia:
# 	chit_chat71 Fog Kaan, Zerer Teromu
# 	flirt_with75 Kefer Kaan, Fog Kaan
# 	mentor_cook150 Baiog Edmund, Zerer Teromu
# 	bitch_about_boss152 Zerer Teromu, Zeres Kiryl, Baiog Edmund
# 	bitch_about_boss152 Zeres Kiryl, Zerer Teromu, Baiog Edmund
# At the barracks of Baltissia castle:
# 	develop_crush79 Fog Noctstalker, Tigan Barnook
# 	guard_prison246 Cean Kiith
# 	bitch_about_boss152 Tigan Barnook, Cean Kiith, Freyel Penryl
# 	guard_prison246 Martin Frsa
# 	joke_around_with_the_wrong_person94 Loretta Ashoth, Cean Kiith
# ...

# %%
sequence.active_module.display_statuses()
# Out:
# Porah Adog:
# 	last_birthday : time(fall,1056)
# 	skin : espresso
# 	hair : orange
# 	eye : brown
# 	presentation : butch
# 	pronouns : he/him
# 	hometown : Ebrook
# 	purpose
# 	age : 54
# 	self_worth : 9
# 	tiredness : 7
# 	likes Pordow Isabel : 2
# 	anger : 4
# 	likes Col Amos : 2
# 	likes Pewter Bramhart : 4
# 	likes Kaoth Wesley : 4
# 	likes Aureolin Selom : 2
# 	loves Steinrett Marion : 2
# 	likes Caelum Adine : -2
# 	family_oriented
# 	agreeable
# 	indifferent
# 	stern
# Kefgo Teran:
# 	last_birthday : time(spring,1057)
# 	skin : chocolate
# 	hair : darkbrown
# 	eye : orange
# 	presentation : butch
# 	pronouns : she/her
# 	hometown : Ebrook
# 	purpose
# 	age : 40
# 	self_worth : 1
# 	tiredness : 5
# 	likes Aerdia Quisdow : 4
# 	likes Storm Teran : 1
# 	anger : 2
# 	crushing_on Storm Teran
# 	likes Baiom Osborningredior : 2
# 	loves Baiom Osborningredior : 2
# 	loves Goa Chadardia : 2
# 	likes Mabel Tertis : -2
# 	crushing_on Steinrett Marion
# 	loves Storm Teran : 2
# ...

# %%
if False:
    sequence.active_module.display_patterns(pattern_filter=['has_connection'])

    sequence.active_module.display_patterns(pattern_filter=['lacking_path'])

    sequence.active_module.display_patterns(pattern_filter=['has_path'])

# %%
print(len(sequence.active_module.population))
sequence.active_module.display_relationships()
# Out:
# 165
# Porah Adog:
# 	fisher:
# 		the docks of Ebrook
# 	connected:
# 		the docks of Ebrook
# 	likes:
# 		Pordow Isabel 1
# 		Col Amos 1
# 		Pewter Bramhart 2
# 		Kaoth Wesley 2
# 		Aureolin Selom 1
# 		Caelum Adine -1
# 	loves:
# 		Steinrett Marion 1
# Kefgo Teran:
# 	fisher:
# 		the docks of Ebrook
# 	connected:
# 		the docks of Ebrook
# 	likes:
# 		Aerdia Quisdow 3
# 		Storm Teran 1
# 		Baiom Osborningredior 1
# 		Mabel Tertis -1
# 		Pordow Isabel -1
# 		Atregan Cyrett 1
# 	loves:
# 		Baiom Osborningredior 1
# 		Goa Chadardia 1
# 		Storm Teran 1
# 		Atregan Cyrett 1
# Vaus Kaan:
# 	tourist:
# 		the  opera house of Melamb
# 	parent:
# 		Zerrett Kaan
# 		Kefer Kaan
# 		Fog Kaan
# 	connected:
# 		Throne Room of Baltissia
# 	spouse:
# 		Ashros Kaan
# 	likes:
# 		Fog Kaan -1
# 		Kefer Kaan 2
# 		Ridow Saom -1
# 		Ader Edea 1
# 		Celides Barendwind 1
# 		Quisoth Kaes 2
# 		Frost Seifom 2
# Ashros Kaan:
# 	spouse:
# 		Vaus Kaan
# 	parent:
# 		Zerrett Kaan
# 		Kefer Kaan
# 		Fog Kaan
# ...

# %%
print(len(sequence.active_module.population))
import json
with open('population.json','w') as outfile:
    outfile.write(json.dumps(sequence.active_module.to_json(), sort_keys=True, indent=4))
    
    
with open('../../GTBBTUnity/Assets/Kismet/population.json','w') as outfile:
    outfile.write(json.dumps(sequence.active_module.to_json(), sort_keys=True, indent=4))
# Out:
# 165

# %%
# !dir
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 5EF3-BA6E
#
#  Directory of C:\Users\adams\Documents\Research\KismetFresh\kismet
#
# 09/03/2022  03:29 PM    <DIR>          .
# 09/03/2022  03:29 PM    <DIR>          ..
# 09/03/2022  02:09 PM             2,353 .gitignore
# 09/03/2022  02:13 PM    <DIR>          .ipynb_checkpoints
# 09/03/2022  02:09 PM            16,083 ages.lp
# 09/03/2022  02:09 PM             8,929 age_nonbit.lp
# 09/03/2022  02:09 PM         2,079,769 antlr-4.7.2-complete.jar
# 09/03/2022  02:09 PM         2,089,101 antlr-4.8-complete.jar
# 09/03/2022  02:09 PM               101 astronaut.kisseq
# 09/03/2022  02:09 PM             2,958 astronaut_early_life.init
# 09/03/2022  02:09 PM               661 astronaut_early_life.kismet
# 09/03/2022  02:09 PM               407 astronaut_early_life.kismet_rules.lp
# 09/03/2022  02:09 PM               981 benchmark.kismet
# 09/03/2022  02:09 PM               859 chosen_one_events.kismet
# ...

# %%
' '.join(['C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\default.lp', 'C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp', 'C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_population.lp', 'C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_history.lp', 'C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\pattern_detection.lp'])
# Out:
# 'C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\default.lp C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_history.lp C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\pattern_detection.lp'

# %%
# !clingo C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\default.lp C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\fantasy_broad.kismet_conglomeration.kismet_history.lp C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\pattern_detection.lp
# Out:
# clingo version 5.4.0
# Reading from ...earch\\KismetFresh\\kismet\\default.lp ...
# Solving...
# Answer: 1
# passes
# SATISFIABLE
#
# Models       : 1
# Calls        : 1
# Time         : 0.199s (Solving: 0.00s 1st Model: 0.00s Unsat: 0.00s)
# CPU Time     : 0.203s
# C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\default.lp:7:48-62: info: atom does not occur in any rule head:
#   status(Status)
#
# C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\default.lp:7:64-82: info: atom does not occur in any rule head:
#   isPerson(Status,N)
#
# C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\default.lp:8:48-62: info: atom does not occur in any rule head:
#   status(Status)
#
# C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\default.lp:8:64-82: info: atom does not occur in any rule head:
#   isPerson(Status,N)
#
# C:\\Users\\adams\\Documents\\Research\\KismetFresh\\kismet\\default.lp:9:42-56: info: atom does not occur in any rule head:
# ...

# %%
# !clingo  C:\Users\adams\Documents\Research\KismetFresh\kismet\fantasy_broad.kismet_conglomeration.kismet_action_results.lp C:\Users\adams\Documents\Research\KismetFresh\kismet\fantasy_broad.kismet_conglomeration.kismet_event_rules.lp C:\Users\adams\Documents\Research\KismetFresh\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\KismetFresh\kismet\fantasy_broad.kismet_conglomeration.kismet_occurred_events.lp C:\Users\adams\Documents\Research\KismetFresh\kismet\fantasy_broad.kismet_conglomeration.kismet_population_locations.lp C:\Users\adams\Documents\Research\KismetFresh\kismet\fantasy_broad.kismet_conglomeration.kismet_history.lp  C:\Users\adams\Documents\Research\KismetFresh\kismet\fantasy_broad.kismet_conglomeration.kismet_actions.lp
# Out:
# clingo version 5.4.0
# Reading from ...onglomeration.kismet_action_results.lp ...
# Solving...
# Answer: 1
# ...
