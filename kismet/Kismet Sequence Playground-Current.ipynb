# %%
if False:
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet.ebnv
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_initialization.ebnf
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_sequence.ebnf

# %%
import KismetSequence

# %%
sequence = KismetSequence.KismetSequence(sequence_file = 'gtbbt.seq')#'gtbbt.seq')
# Out:
# ANTLR runtime and generated code versions disagree: 4.9.3!=4.7.2
# ANTLR runtime and generated code versions disagree: 4.9.3!=4.7.2
# SEQUENCE STATEMENT [('Load', [('File', 'fantasy_broad.kismet'), ('TRACERY', []), ('File', '../tracery/fantasy.tracery')])]
# SEQUENCE STATEMENT [('Initialize', [('File', 'fantasy_setting.init')])]
# INITIALIZATION []
# SEQUENCE STATEMENT [('Run', [('Until', [('UntilClauses', [('Duration', [('Num', '1'), ('Name', 'steps')])])])])]

# %%
# %%time
from IPython.display import clear_output

clear_output(wait=True)
sequence()
# Out:
# Running Kismet Sequence from "gtbbt.seq"
# Starting New Step: Loading ['fantasy_broad.kismet'] with Tracery Files ['../tracery/fantasy.tracery']
# ANTLR runtime and generated code versions disagree: 4.9.3!=4.7.2
# ANTLR runtime and generated code versions disagree: 4.9.3!=4.7.2
# *************************POTENTIAL PROBLEMS*************************
# Locations: Not referenced in actions or traits
# 	quad
# 	opera_house
# 	kitchen
# 	dungeon
# 	ruins
# 	library
# 	amphitheatre
# 	temple
# 	boat
# 	shipyard
# 	mine
# 	auction_house
# 	thieves_den
# 	garden
# 	marketplace
# 	ballroom
# 	smith
# 	classroom
# 	elders_house
# 	docks
# 	tavern
# Tags: Not referenced in traits
# 	angry
# Tags: Referenced in traits but not found in actions
# 	free
# 	agree
# 	duty
# 	careless
# 	religious
# 	bold
# 	risky
# 	scholarly
# Traits: Not referenced in actions
# 	believer
# 	indifferent
# 	respect_towards
# 	gruff
# 	visiting_as_regular
# 	rivalry
# 	ignoramus
# 	mean_to_people_you_dislike3
# 	stern
# 	stay_at_hometown
# 	stay_in_confinement
# 	embarrassed_by
# 	guilt
# 	friends_with
# 	family_oriented
# 	critical
# 	curious
# 	people_joke_with_joker
# 	careless
# 	visiting_places_you_like
# 	age
# 	introvert
# 	scholar
# 	neurotic
# 	romantic
# 	family_ties
# 	mean_to_people_you_dislike2
# 	nice_to_people_you_like1
# 	carer
# 	cautious
# 	duty_bound
# 	free_spirited
# 	people_are_usually_serious
# 	confident
# 	skeptic
# 	conscientious
# 	proud_of
# 	extrovert
# 	mean_to_people_you_dislike1
# 	comic
# 	protective_of
# 	dissapointed_in
# 	feral
# *************************Reference Section*************************
# Actions
# 	complain_to_compassionate
# 	make_out_with
# 	sulk
# 	reject_romance
# 	insult_as_bully
# 	chit_chat
# 	try_to_help_struggling_friend
# 	help_struggling_friend
# 	plot_about_sabotaging_romantic_rival
# 	joke_around_with
# 	flirt_at
# 	complain_to_and_make_annoyed
# 	insult
# 	joke_around_with_the_wrong_person
# 	have_catharsis
# 	flirt_with
# 	help_really_struggling_person
# 	provide_critical_feedback
# 	blowup_love_triangle
# 	criticize
# Patterns
# 	non_joker
# 		 referenced in: joke_around_with_the_wrong_person
# Tags
# 	worry
# 		 referenced in: neurotic, confident
# 	free
# 		 referenced in: duty_bound, free_spirited
# 	agree
# 		 referenced in: critical, agreeable, gruff
# 	duty
# 		 referenced in: duty_bound, free_spirited
# 	silly
# 		 referenced in: comic, people_are_usually_serious, people_joke_with_joker, stern
# 	religious
# 		 referenced in: skeptic, believer, feral
# 	talk
# 		 referenced in: feral, extrovert, introvert
# 	romance
# 		 referenced in: romantic, family_ties
# 	thoughtful
# 		 referenced in: family_oriented, family_ties, indifferent, conscientious, careless, compassionate, comic, stern
# 	kind
# 		 referenced in: bully, family_oriented, family_ties, indifferent, carer, compassionate
# 	bold
# 		 referenced in: neurotic, confident
# 	mean
# 		 referenced in: bully, family_oriented, family_ties, mean_to_people_you_dislike2, nice_to_people_you_like1, carer, mean_to_people_you_dislike1, mean_to_people_you_dislike3
# 	risky
# 		 referenced in: cautious, curious, feral
# 	scholarly
# 		 referenced in: ignoramus, scholar
# Traits
# 	bully
# 		 referenced in: insult_as_bully, insult
# 	believer
# 	indifferent
# 	respect_towards
# 	gruff
# 	visiting_as_regular
# 	rivalry
# 	ignoramus
# 	mean_to_people_you_dislike3
# 	likes
# 		 referenced in: complain_to_compassionate, make_out_with, joke_around_with_the_wrong_person, help_struggling_friend, plot_about_sabotaging_romantic_rival, reject_romance, flirt_with, joke_around_with, flirt_at, complain_to_and_make_annoyed, try_to_help_struggling_friend, chit_chat, insult_as_bully, help_really_struggling_person, provide_critical_feedback, blowup_love_triangle, criticize, insult
# 	stern
# 	stay_at_hometown
# 	feral
# 	stay_in_confinement
# 	embarrassed_by
# 	friends_with
# 	family_oriented
# 	guilt
# 	like
# 	critical
# 		 referenced in: critical, agreeable, gruff, family_ties
# 	curious
# 	people_joke_with_joker
# 	careless
# 		 referenced in: conscientious, careless
# 	visiting_places_you_like
# 	age
# 	introvert
# 	scholar
# 	neurotic
# 	loves
# 		 referenced in: make_out_with, plot_about_sabotaging_romantic_rival, reject_romance, flirt_with, flirt_at, blowup_love_triangle
# 	romantic
# 	family_ties
# 	mean_to_people_you_dislike2
# 	nice_to_people_you_like1
# 	carer
# 	cautious
# 	duty_bound
# 	free_spirited
# 	self_worth
# 		 referenced in: complain_to_compassionate, have_catharsis, help_struggling_friend, sulk, reject_romance, insult_as_bully, try_to_help_struggling_friend, help_really_struggling_person, insult
# 	people_are_usually_serious
# 	shame
# 		 referenced in: reject_romance
# 	love
# 	skeptic
# 	conscientious
# 	proud_of
# 	extrovert
# 	agreeable
# 		 referenced in: provide_critical_feedback
# 	compassionate
# 		 referenced in: complain_to_compassionate, complain_to_and_make_annoyed
# 	mean_to_people_you_dislike1
# 	comic
# 	protective_of
# 	dissapointed_in
# 	confident
# Requirements:
# chit_chat
# complain_to_and_make_annoyed
# 	References: compassionate
# complain_to_compassionate
# 	References: compassionate
# flirt_at
# flirt_with
# make_out_with
# 	References: love
# blowup_love_triangle
# 	References: love
# plot_about_sabotaging_romantic_rival
# 	References: love
# reject_romance
# 	References: loves, likes
# insult_as_bully
# 	References: bully
# insult
# 	References: bully
# sulk
# 	References: self_worth
# have_catharsis
# 	References: self_worth
# try_to_help_struggling_friend
# 	References: self_worth, likes
# help_struggling_friend
# 	References: like, self_worth
# help_really_struggling_person
# 	References: self_worth
# joke_around_with
# joke_around_with_the_wrong_person
# 	References: non_joker
# criticize
# provide_critical_feedback
# 	References: agreeable
# introvert
# 	References: talk
# extrovert
# 	References: talk
# skeptic
# 	References: religious
# believer
# 	References: religious
# curious
# 	References: risky
# cautious
# 	References: risky
# bully
# 	References: mean, kind
# carer
# 	References: mean, kind
# scholar
# 	References: scholarly
# ignoramus
# 	References: scholarly
# conscientious
# 	References: thoughtful, careless
# careless
# 	References: thoughtful, careless
# agreeable
# 	References: critical, agree
# critical
# 	References: critical, agree
# compassionate
# 	References: thoughtful, kind
# indifferent
# 	References: thoughtful, kind
# neurotic
# 	References: bold, worry
# confident
# 	References: bold, worry
# family_oriented
# 	References: mean, thoughtful, kind
# duty_bound
# 	References: free, duty
# free_spirited
# 	References: free, duty
# romantic
# 	References: romance
# gruff
# 	References: critical, agree
# feral
# 	References: risky, talk, religious
# comic
# 	References: thoughtful, silly
# stern
# 	References: thoughtful, silly
# stay_in_confinement
# visiting_places_you_like
# visiting_as_regular
# stay_at_hometown
# family_ties
# 	References: thoughtful, kind, critical, mean, romance
# mean_to_people_you_dislike1
# 	References: mean
# mean_to_people_you_dislike2
# 	References: mean
# mean_to_people_you_dislike3
# 	References: mean
# nice_to_people_you_like1
# 	References: mean
# people_are_usually_serious
# 	References: silly
# people_joke_with_joker
# 	References: silly
# likes
# loves
# respect_towards
# rivalry
# dissapointed_in
# proud_of
# embarrassed_by
# protective_of
# friends_with
# guilt
# shame
# self_worth
# Starting New Step: Initializing from fantasy_setting.init
# ANTLR runtime and generated code versions disagree: 4.9.3!=4.7.2
# ANTLR runtime and generated code versions disagree: 4.9.3!=4.7.2
# *************************POTENTIAL PROBLEMS BETWEEN INIT AND KISMET*************************
# Traits: Referenced in initialization but not found
# 	ruler
# 	servant
# 	thief
# 	pickpocket
# 	master_thief
# 	presentation
# 	spouse
# 	bard
# 	enforcer
# 	mariner
# 	tourist
# 	worker
# 	parent
# 	smith_apprentice
# 	artist
# 	confined
# 	boss
# 	coworker
# 	rival
# 	archaelogist
# 	foreman
# 	follower
# 	monk
# 	fealty
# 	chancellor
# 	hometown
# 	guard
# 	drinker
# 	treasure_hunter
# 	criminal
# 	guest
# 	sailor
# 	professor
# 	ship_builder
# 	citizen
# 	fisher
# 	engineer
# 	tutor
# 	spy
# 	monarch
# 	captain
# 	smithy
# 	librarian
# 	student
# 	patron
# 	employee
# 	dockworker
# 	pronouns
# 	related_to
# 	skin
# 	sibling
# 	regular
# 	elder
# 	child
# 	rich
# 	miner
# 	vocation
# 	researcher
# 	victim
# 	priest
# 	curator
# 	diva
# 	prostitute
# 	chef
# 	spy_master
# 	royalty
# 	last_birthday
# 	vendor
# 	owner
# 	high_priest
# 	barkeep
# 	scared
# 	auctioneer
# Starting New Step: Running...
# [('season', 'summer'), ('year', 1017)]
# Wall time: 5.97 s

# %%
print(sequence.active_module.display_statuses())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ASUMME~1\AppData\Local\Temp\4/ipykernel_9492/2554275325.py in <module>
# ----> 1 print(sequence.active_module.display_statuses())
#
# AttributeError: 'NoneType' object has no attribute 'display_statuses'

# %%
print(sequence.active_module.display_relationships())

# %%
print(len(sequence.active_module.population))
import json
with open('population.json','w') as outfile:
    outfile.write(json.dumps(sequence.active_module.to_json(), sort_keys=True, indent=4))

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.array(
    [[1600,160,49.2],
        [800,80,29.7],
        [400,80,20],
        [400,40,19.6],
        [200,20,14.7],
        [100,10,12.7],
        [40, 2,9.31],
        [20, 2,8.42],
        [10, 10,6.94],
        [10, 1, 7.05]])
plt.plot(data[:,0],data[:,2],'bx')
print(data[:,2]/data[:,0])

# %%
sequence.active_module.to_json()

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp -t 8

# %%
# !clingo --outf=2 C:\Users\asummerville\Documents\Research\Kismet\kismet\default.lp C:\Users\asummerville\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_rules.lp C:\Users\asummerville\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\asummerville\Documents\Research\Kismet\kismet\location_volition.lp -t 8
