# %%
if False:
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet.ebnv
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_initialization.ebnf
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_sequence.ebnf

# %%
import KismetSequence

# %%
sequence = KismetSequence.KismetSequence(sequence_file = 'gtbbt.seq')#'gtbbt.seq')
# Out:
# SEQUENCE STATEMENT [('Load', [('File', 'fantasy_broad.kismet'), ('TRACERY', []), ('File', '../tracery/fantasy.tracery')])]
# SEQUENCE STATEMENT [('Initialize', [('File', 'fantasy_setting.init')])]
# INITIALIZATION []
# SEQUENCE STATEMENT [('Run', [('Until', [('UntilClauses', [('Duration', [('Num', '10'), ('Name', 'steps')])])])])]

# %%
# %%time
from IPython.display import clear_output


clear_output(wait=True)
sequence()
# Out:
# Running Kismet Sequence from "gtbbt.seq"
# Starting New Step: Loading ['fantasy_broad.kismet'] with Tracery Files ['../tracery/fantasy.tracery']
# *************************POTENTIAL PROBLEMS*************************
# Locations: Not referenced in actions or traits
# 	quad
# 	elders_house
# 	mine
# 	classroom
# 	docks
# 	thieves_den
# 	temple
# 	auction_house
# 	amphitheatre
# 	opera_house
# 	ruins
# 	throne_room
# 	shipyard
# 	garden
# 	library
# 	tavern
# 	ballroom
# 	dungeon
# 	smith
# 	kitchen
# 	marketplace
# 	boat
# Tags: Not referenced in traits
# 	mariner
# 	criticial
# 	work
# 	criminal
# 	angry
# Tags: Referenced in traits but not found in actions
# 	agree
# Traits: Not referenced in actions
# 	stay_in_confinement
# 	ignoramus
# 	gruff
# 	proud_of
# 	people_are_usually_serious
# 	family_oriented
# 	extrovert
# 	carer
# 	sadness
# 	visiting_as_regular
# 	critical
# 	neurotic
# 	conscientious
# 	mean_to_people_you_dislike1
# 	friends_with
# 	comic
# 	cautious
# 	dissapointed_in
# 	protective_of
# 	stern
# 	guilt
# 	romantic
# 	visiting_places_you_like
# 	nice_to_people_you_like1
# 	rare_things_rare
# 	careless
# 	rivalry
# 	confident
# 	go_to_locations_you_have_connection_with
# 	mean_to_people_you_dislike3
# 	people_joke_with_joker
# 	curious
# 	do_more_specific_things
# 	do_role_specific_actions
# 	introvert
# 	mean_to_people_you_dislike2
# 	embarrassed_by
# 	free_spirited
# 	no_pedophilia
# 	family_ties
# 	fail_when_interactin_with_person_who_dislikes_you1
# 	feral
# 	romantic_towards_crush
# 	fail_when_interactin_with_person_who_dislikes_you2
# 	stay_at_hometown
# Traits: Referenced in actions but not found
# 	ex_royalty
# 	hometown
# 	royalty
# 	sibling
# 	child
# 	coworker
# 	patron
# 	researcher
# 	rich
# 	diva
# 	auctioneer
# 	plotting_against
# 	fears
# 	free_sprited
# 	worker
# 	tourist
# 	crushing_on
# 	rival
# 	student
# 	employee
# 	guest
# 	spy
# 	important
# 	fealty
# 	devotion
# 	knows_personal_info_about
# *************************Reference Section*************************
# Actions
# 	insult_as_bully
# 	annoy_diva_for_laughs
# 	play_together
# 	trigger_trap
# 	make_callous_decree
# 	flirt_with
# 	convince_importance_of_duty
# 	cast_treasure_hunter
# 	make_imprudent_decree
# 	sulk
# 	conspire_against
# 	fight_seagull
# 	perform_research
# 	joke_around_with_the_wrong_person
# 	reject_romance
# 	help_struggling_friend
# 	catalog_findings
# 	acquire_ingredients
# 	make_judicious_decree
# 	play
# 	sell_wares
# 	perform_to_no_effect
# 	strike_motherlode
# 	plot_about_sabotaging_romantic_rival
# 	curate_collection
# 	cast_professor
# 	endanger_miners
# 	sway_monarch_to_indifference
# 	mentor_cook
# 	argue_with_treasure_hunter
# 	rough_up
# 	be_open_about_crush
# 	have_crisis_of_faith
# 	cast_archaelogist
# 	develop_begrudging_respect_towards
# 	boss_cooks_around
# 	provide_critical_feedback
# 	amuse_with_performance
# 	criticize
# 	impress
# 	perform_ritual
# 	assist_research
# 	get_into_argument
# 	cast_spy_master
# 	share_personal_info
# 	cast_enforcer
# 	find_treasure
# 	become_annoyed_with_bard
# 	have_catharsis
# 	hold_auction
# 	consult_with_chancellor
# 	try_to_help_struggling_friend
# 	manage_dispute_between_miners
# 	stand_up_for_friend_and_fail
# 	cast_bard
# 	blow_up_love_triangle
# 	boss_miner_around
# 	use_humor_to_spark_love
# 	stand_up_for_friend_and_persuade
# 	banish_monarchling
# 	cast_monarch
# 	try_to_impress_and_fail
# 	create_culinary_masterpiece
# 	chit_chat
# 	hold_lecture
# 	cast_foreman
# 	bitch_about_boss_to_resistance
# 	hustle
# 	grouse_backstage
# 	worry_about_future
# 	cast_librarian
# 	cast_ur_job
# 	hold_boring_lecture
# 	pray
# 	sway_monarch_to_kindness
# 	complain_to_compassionate
# 	screw_up_ritual
# 	be_amused_by_bard
# 	shun_banished_sibling
# 	cast_curator
# 	manage_mine
# 	shush_patron
# 	investigate_ruins
# 	worry_about_mortality
# 	joke_around_with
# 	give_deal_to
# 	collect_protection_fees
# 	overcome_rivalry_to_work_together
# 	help_really_struggling_person
# 	support_banished_sibling
# 	cast_monk
# 	standup_to_enforcer_together
# 	encourage_fellow_performer
# 	search_for_treasure
# 	acquire_artifacts
# 	assist_student
# 	stock_books
# 	insult
# 	cast_chef
# 	bitch_about_boss
# 	cast_miner
# 	make_benevolent_decree
# 	demand_a_new_piece
# 	undercut
# 	work_at_mine
# 	complain_to_and_make_annoyed
# 	be_open_about_crush_and_burn
# 	cast_dockworker
# 	pine_over
# 	send_underlings
# 	discuss_collection
# 	argue_about_duty
# 	argue_with_playmate
# 	cast_vendor
# 	cast_chancellor
# 	load_cargo
# 	praise_boss
# 	develop_crush
# 	make_out_with
# 	commiserate_with_fellow_vendor
# 	praise_boss_to_resistance
# 	flirt_at
# 	sabotage_rival_treasure_hunter
# 	develop_recipe
# Patterns
# 	dislikes_friend
# 		 referenced in: stand_up_for_friend_and_persuade, stand_up_for_friend_and_fail
# 	non_joker
# 		 referenced in: joke_around_with_the_wrong_person
# Roles
# 	professor
# 		 referenced in: hold_lecture, perform_research, hold_boring_lecture, cast_professor
# 	treasure_hunter
# 		 referenced in: overcome_rivalry_to_work_together, cast_treasure_hunter, trigger_trap, develop_begrudging_respect_towards, search_for_treasure, find_treasure, sabotage_rival_treasure_hunter, argue_with_treasure_hunter
# 	curator
# 		 referenced in: cast_curator, acquire_artifacts, demand_a_new_piece, curate_collection, discuss_collection
# 	miner
# 		 referenced in: cast_miner, work_at_mine, endanger_miners, boss_miner_around, strike_motherlode, manage_dispute_between_miners
# 	monarch
# 		 referenced in: make_benevolent_decree, make_judicious_decree, banish_monarchling, cast_monarch, sway_monarch_to_kindness, make_imprudent_decree, make_callous_decree, consult_with_chancellor, sway_monarch_to_indifference
# 	dockworker
# 		 referenced in: fight_seagull, load_cargo, cast_dockworker
# 	chancellor
# 		 referenced in: sway_monarch_to_kindness, consult_with_chancellor, sway_monarch_to_indifference, cast_chancellor
# 	bard
# 		 referenced in: perform_to_no_effect, annoy_diva_for_laughs, be_amused_by_bard, grouse_backstage, amuse_with_performance, encourage_fellow_performer, become_annoyed_with_bard, cast_bard
# 	spy_master
# 		 referenced in: conspire_against, cast_spy_master, send_underlings
# 	ur_job
# 		 referenced in: cast_vendor, cast_bard, cast_professor, cast_chancellor, cast_curator, cast_ur_job, cast_miner, cast_librarian, cast_treasure_hunter, cast_archaelogist, cast_spy_master, cast_monk, cast_monarch, cast_enforcer, cast_foreman, cast_dockworker, cast_chef
# 	enforcer
# 		 referenced in: cast_enforcer, collect_protection_fees, rough_up
# 	chef
# 		 referenced in: acquire_ingredients, boss_cooks_around, create_culinary_masterpiece, develop_recipe, mentor_cook, cast_chef
# 	archaelogist
# 		 referenced in: cast_archaelogist, develop_begrudging_respect_towards, investigate_ruins, argue_with_treasure_hunter, catalog_findings
# 	foreman
# 		 referenced in: manage_mine, endanger_miners, boss_miner_around, cast_foreman, strike_motherlode, manage_dispute_between_miners
# 	monk
# 		 referenced in: screw_up_ritual, have_crisis_of_faith, cast_monk, pray, perform_ritual
# 	vendor
# 		 referenced in: commiserate_with_fellow_vendor, collect_protection_fees, undercut, hustle, cast_vendor, acquire_ingredients, standup_to_enforcer_together, sell_wares, give_deal_to, rough_up
# 	librarian
# 		 referenced in: cast_librarian, shush_patron, assist_student, stock_books, assist_research
# Tags
# 	agree
# 		 referenced in: agreeable, critical, gruff
# 	bold
# 		 referenced in: confident, neurotic
# 	mean
# 		 referenced in: compassionate, family_ties, mean_to_people_you_dislike3, mean_to_people_you_dislike1, mean_to_people_you_dislike2, bully, family_oriented, carer, nice_to_people_you_like1, indifferent
# 	romance
# 		 referenced in: romantic_towards_crush, family_ties, romantic, no_pedophilia
# 	kind
# 		 referenced in: compassionate, family_ties, bully, family_oriented, carer, indifferent
# 	religious
# 		 referenced in: feral
# 	duty
# 		 referenced in: duty_bound, free_spirited
# 	risky
# 		 referenced in: curious, cautious, feral
# 	rare
# 		 referenced in: rare_things_rare
# 	silly
# 		 referenced in: people_are_usually_serious, people_joke_with_joker, stern, comic
# 	specific
# 		 referenced in: do_more_specific_things
# 	talk
# 		 referenced in: introvert, extrovert, feral
# 	failure
# 		 referenced in: fail_when_interactin_with_person_who_dislikes_you1, fail_when_interactin_with_person_who_dislikes_you2
# 	scholarly
# 		 referenced in: scholar, ignoramus
# 	thoughtful
# 		 referenced in: compassionate, conscientious, family_ties, comic, family_oriented, stern, indifferent, careless
# 	role_specific
# 		 referenced in: do_role_specific_actions
# 	free
# 		 referenced in: duty_bound, free_spirited
# 	worry
# 		 referenced in: confident, neurotic
# Traits
# 	ex_royalty
# 		 referenced in: shun_banished_sibling, support_banished_sibling, banish_monarchling
# 	hometown
# 		 referenced in: banish_monarchling
# 	family_oriented
# 	child
# 		 referenced in: banish_monarchling
# 	carer
# 	happiness
# 		 referenced in: argue_with_playmate, play_together, play, create_culinary_masterpiece, worry_about_mortality
# 	rich
# 		 referenced in: find_treasure
# 	neurotic
# 	comic
# 	fears
# 		 referenced in: standup_to_enforcer_together, rough_up
# 	dissapointed_in
# 	guilt
# 	visiting_places_you_like
# 	crushing_on
# 		 referenced in: develop_crush, be_open_about_crush_and_burn, use_humor_to_spark_love, be_open_about_crush
# 	tiredness
# 		 referenced in: perform_to_no_effect, worry_about_future, load_cargo, work_at_mine, search_for_treasure, worry_about_mortality, stock_books
# 	employee
# 		 referenced in: bitch_about_boss_to_resistance, praise_boss_to_resistance, praise_boss, bitch_about_boss
# 	free_spirited
# 	fail_when_interactin_with_person_who_dislikes_you1
# 	agreeable
# 		 referenced in: provide_critical_feedback
# 	stay_at_hometown
# 	knows_personal_info_about
# 		 referenced in: share_personal_info
# 	anger
# 		 referenced in: fight_seagull
# 	proud_of
# 	extrovert
# 	sadness
# 	critical
# 		 referenced in: family_ties, agreeable, critical, gruff
# 	conscientious
# 	auctioneer
# 		 referenced in: hold_auction, demand_a_new_piece
# 	age
# 		 referenced in: argue_with_playmate, play_together, worry_about_future, play, banish_monarchling, worry_about_mortality
# 	mean_to_people_you_dislike1
# 	friends_with
# 	free_sprited
# 		 referenced in: convince_importance_of_duty, argue_about_duty
# 	protective_of
# 	worker
# 		 referenced in: boss_cooks_around, mentor_cook
# 	romantic
# 	confident
# 	do_more_specific_things
# 	introvert
# 	embarrassed_by
# 	self_worth
# 		 referenced in: insult_as_bully, annoy_diva_for_laughs, trigger_trap, stand_up_for_friend_and_persuade, try_to_impress_and_fail, create_culinary_masterpiece, hold_lecture, undercut, hustle, have_crisis_of_faith, hold_boring_lecture, amuse_with_performance, be_open_about_crush_and_burn, sulk, impress, assist_research, perform_research, reject_romance, help_struggling_friend, complain_to_compassionate, find_treasure, have_catharsis, hold_auction, try_to_help_struggling_friend, stand_up_for_friend_and_fail, help_really_struggling_person, acquire_artifacts, strike_motherlode, assist_student, develop_recipe, insult
# 	family_ties
# 	ignoramus
# 	compassionate
# 		 referenced in: sway_monarch_to_kindness, sway_monarch_to_indifference, complain_to_and_make_annoyed, complain_to_compassionate
# 	royalty
# 		 referenced in: shun_banished_sibling, support_banished_sibling, banish_monarchling
# 	coworker
# 		 referenced in: bitch_about_boss_to_resistance, praise_boss_to_resistance, praise_boss, bitch_about_boss
# 	patron
# 		 referenced in: hold_auction
# 	researcher
# 	indifferent
# 		 referenced in: sway_monarch_to_kindness, sway_monarch_to_indifference
# 	diva
# 		 referenced in: annoy_diva_for_laughs
# 	visiting_as_regular
# 	plotting_against
# 		 referenced in: conspire_against, send_underlings
# 	cautious
# 	stern
# 	shame
# 		 referenced in: shush_patron, reject_romance
# 	rare_things_rare
# 	rivalry
# 	like
# 	go_to_locations_you_have_connection_with
# 	mean_to_people_you_dislike3
# 	curious
# 	bully
# 		 referenced in: insult_as_bully, insult
# 	likes
# 		 referenced in: insult_as_bully, annoy_diva_for_laughs, play_together, bitch_about_boss, sabotage_rival_treasure_hunter, make_benevolent_decree, stand_up_for_friend_and_persuade, endanger_miners, banish_monarchling, try_to_impress_and_fail, make_callous_decree, chit_chat, hold_lecture, demand_a_new_piece, mentor_cook, argue_with_treasure_hunter, rough_up, bitch_about_boss_to_resistance, flirt_with, undercut, hustle, be_open_about_crush, grouse_backstage, convince_importance_of_duty, develop_begrudging_respect_towards, boss_cooks_around, hold_boring_lecture, complain_to_and_make_annoyed, provide_critical_feedback, amuse_with_performance, make_imprudent_decree, criticize, impress, conspire_against, assist_research, get_into_argument, joke_around_with_the_wrong_person, reject_romance, help_struggling_friend, complain_to_compassionate, screw_up_ritual, argue_about_duty, be_amused_by_bard, shun_banished_sibling, argue_with_playmate, acquire_ingredients, shush_patron, praise_boss, make_judicious_decree, share_personal_info, make_out_with, assist_student, become_annoyed_with_bard, consult_with_chancellor, joke_around_with, try_to_help_struggling_friend, manage_dispute_between_miners, give_deal_to, stand_up_for_friend_and_fail, sell_wares, commiserate_with_fellow_vendor, collect_protection_fees, overcome_rivalry_to_work_together, help_really_struggling_person, support_banished_sibling, blow_up_love_triangle, standup_to_enforcer_together, boss_miner_around, encourage_fellow_performer, use_humor_to_spark_love, praise_boss_to_resistance, strike_motherlode, flirt_at, plot_about_sabotaging_romantic_rival, insult
# 	feral
# 	romantic_towards_crush
# 	fail_when_interactin_with_person_who_dislikes_you2
# 	important
# 		 referenced in: conspire_against
# 	stay_in_confinement
# 	gruff
# 	respects
# 		 referenced in: endanger_miners, create_culinary_masterpiece, strike_motherlode, sabotage_rival_treasure_hunter, manage_dispute_between_miners, discuss_collection
# 	people_are_usually_serious
# 	duty_bound
# 		 referenced in: convince_importance_of_duty, argue_about_duty
# 	loves
# 		 referenced in: flirt_with, be_open_about_crush, blow_up_love_triangle, be_open_about_crush_and_burn, make_out_with, use_humor_to_spark_love, pine_over, flirt_at, plot_about_sabotaging_romantic_rival, reject_romance
# 	sibling
# 		 referenced in: shun_banished_sibling, support_banished_sibling
# 	love
# 	tourist
# 		 referenced in: be_amused_by_bard, become_annoyed_with_bard, amuse_with_performance
# 	scholar
# 		 referenced in: assist_research
# 	nice_to_people_you_like1
# 	careless
# 		 referenced in: careless, conscientious
# 	rival
# 		 referenced in: sabotage_rival_treasure_hunter, develop_begrudging_respect_towards, overcome_rivalry_to_work_together, argue_with_treasure_hunter
# 	student
# 		 referenced in: assist_student, hold_lecture, hold_boring_lecture
# 	people_joke_with_joker
# 	do_role_specific_actions
# 	mean_to_people_you_dislike2
# 	guest
# 		 referenced in: assist_research, create_culinary_masterpiece, shush_patron
# 	no_pedophilia
# 	spy
# 		 referenced in: send_underlings
# 	fealty
# 		 referenced in: make_imprudent_decree, make_callous_decree, make_benevolent_decree, make_judicious_decree
# 	devotion
# 		 referenced in: screw_up_ritual, have_crisis_of_faith, perform_ritual, pray
# Requirements:
# chit_chat
# complain_to_and_make_annoyed
# 	References: compassionate
# complain_to_compassionate
# 	References: compassionate
# flirt_at
# flirt_with
# use_humor_to_spark_love
# be_open_about_crush
# 	References: crushing_on, loves
# be_open_about_crush_and_burn
# 	References: crushing_on, loves
# develop_crush
# pine_over
# make_out_with
# 	References: love
# blow_up_love_triangle
# 	References: love
# plot_about_sabotaging_romantic_rival
# 	References: love
# reject_romance
# 	References: loves, likes
# insult_as_bully
# 	References: bully
# insult
# 	References: bully
# sulk
# 	References: self_worth
# have_catharsis
# 	References: self_worth
# try_to_help_struggling_friend
# 	References: self_worth, likes
# help_struggling_friend
# 	References: self_worth, like
# share_personal_info
# help_really_struggling_person
# 	References: self_worth
# joke_around_with
# joke_around_with_the_wrong_person
# 	References: non_joker
# criticize
# provide_critical_feedback
# 	References: agreeable
# get_into_argument
# 	References: likes
# impress
# try_to_impress_and_fail
# stand_up_for_friend_and_persuade
# 	References: dislikes_friend
# stand_up_for_friend_and_fail
# 	References: dislikes_friend
# pray
# 	References: monk
# perform_ritual
# 	References: monk
# screw_up_ritual
# 	References: monk
# have_crisis_of_faith
# 	References: monk
# manage_mine
# 	References: foreman
# boss_miner_around
# 	References: foreman, miner
# manage_dispute_between_miners
# 	References: foreman, miner, likes
# endanger_miners
# 	References: foreman, miner
# strike_motherlode
# 	References: foreman, miner
# work_at_mine
# 	References: miner
# hold_auction
# 	References: patron, auctioneer
# discuss_collection
# 	References: curator
# demand_a_new_piece
# 	References: curator, auctioneer
# curate_collection
# 	References: curator
# acquire_artifacts
# 	References: curator
# sell_wares
# 	References: vendor
# give_deal_to
# 	References: vendor, likes
# hustle
# 	References: vendor, likes
# commiserate_with_fellow_vendor
# 	References: vendor
# undercut
# 	References: vendor, likes
# standup_to_enforcer_together
# 	References: vendor, fears
# collect_protection_fees
# 	References: vendor, enforcer
# rough_up
# 	References: vendor, enforcer
# load_cargo
# 	References: dockworker
# fight_seagull
# 	References: dockworker
# stock_books
# 	References: librarian
# shush_patron
# 	References: guest, librarian
# assist_research
# 	References: scholar, guest, librarian
# assist_student
# 	References: student, librarian
# acquire_ingredients
# 	References: chef, vendor
# develop_recipe
# 	References: chef
# boss_cooks_around
# 	References: chef, worker
# mentor_cook
# 	References: chef, worker
# create_culinary_masterpiece
# 	References: chef, guest
# bitch_about_boss
# 	References: employee, coworker
# bitch_about_boss_to_resistance
# 	References: employee, coworker, likes
# praise_boss
# 	References: employee, coworker, likes
# praise_boss_to_resistance
# 	References: employee, coworker, likes
# search_for_treasure
# 	References: treasure_hunter
# find_treasure
# 	References: treasure_hunter
# investigate_ruins
# 	References: archaelogist
# trigger_trap
# 	References: treasure_hunter
# sabotage_rival_treasure_hunter
# 	References: rival, treasure_hunter
# overcome_rivalry_to_work_together
# 	References: rival, treasure_hunter
# catalog_findings
# 	References: archaelogist
# argue_with_treasure_hunter
# 	References: archaelogist, rival, treasure_hunter
# develop_begrudging_respect_towards
# 	References: archaelogist, rival, treasure_hunter
# perform_to_no_effect
# 	References: bard
# amuse_with_performance
# 	References: bard, tourist
# grouse_backstage
# 	References: bard
# encourage_fellow_performer
# 	References: bard
# annoy_diva_for_laughs
# 	References: bard, likes, diva
# become_annoyed_with_bard
# 	References: bard, tourist
# be_amused_by_bard
# 	References: bard, tourist
# make_judicious_decree
# 	References: fealty, monarch
# make_imprudent_decree
# 	References: fealty, monarch
# make_callous_decree
# 	References: fealty, monarch
# make_benevolent_decree
# 	References: fealty, monarch
# banish_monarchling
# 	References: age, royalty, monarch, child, likes
# consult_with_chancellor
# 	References: chancellor, monarch
# sway_monarch_to_kindness
# 	References: chancellor, monarch
# sway_monarch_to_indifference
# 	References: chancellor, monarch
# support_banished_sibling
# 	References: ex_royalty, sibling, royalty
# shun_banished_sibling
# 	References: ex_royalty, sibling, royalty
# play
# 	References: age
# play_together
# 	References: age
# argue_with_playmate
# 	References: age
# worry_about_future
# 	References: age
# worry_about_mortality
# 	References: age
# argue_about_duty
# 	References: duty_bound, free_sprited
# convince_importance_of_duty
# 	References: duty_bound, free_sprited
# hold_lecture
# 	References: professor, student
# hold_boring_lecture
# 	References: professor, student
# perform_research
# 	References: professor
# conspire_against
# 	References: important, spy_master
# send_underlings
# 	References: plotting_against, spy_master, spy
# cast_ur_job
# 	References: ur_job
# cast_monk
# 	References: ur_job
# cast_foreman
# 	References: ur_job
# cast_miner
# 	References: ur_job
# cast_curator
# 	References: ur_job
# cast_vendor
# 	References: ur_job
# cast_enforcer
# 	References: ur_job
# cast_dockworker
# 	References: ur_job
# cast_librarian
# 	References: ur_job
# cast_chef
# 	References: ur_job
# cast_treasure_hunter
# 	References: ur_job
# cast_archaelogist
# 	References: ur_job
# cast_bard
# 	References: ur_job
# cast_monarch
# 	References: ur_job
# cast_chancellor
# 	References: ur_job
# cast_professor
# 	References: ur_job
# cast_spy_master
# 	References: ur_job
# introvert
# 	References: talk
# extrovert
# 	References: talk
# curious
# 	References: risky
# cautious
# 	References: risky
# bully
# 	References: mean, kind
# carer
# 	References: mean, kind
# scholar
# 	References: scholarly
# ignoramus
# 	References: scholarly
# conscientious
# 	References: thoughtful, careless
# careless
# 	References: thoughtful, careless
# agreeable
# 	References: agree, critical
# critical
# 	References: agree, critical
# compassionate
# 	References: thoughtful, mean, kind
# indifferent
# 	References: thoughtful, mean, kind
# neurotic
# 	References: bold, worry
# confident
# 	References: bold, worry
# family_oriented
# 	References: thoughtful, mean, kind
# duty_bound
# 	References: free, duty
# free_spirited
# 	References: free, duty
# romantic
# 	References: romance
# gruff
# 	References: agree, critical
# feral
# 	References: risky, religious, talk
# comic
# 	References: thoughtful, silly
# stern
# 	References: thoughtful, silly
# rare_things_rare
# 	References: rare
# do_more_specific_things
# 	References: specific
# stay_in_confinement
# visiting_places_you_like
# visiting_as_regular
# romantic_towards_crush
# 	References: romance
# stay_at_hometown
# do_role_specific_actions
# 	References: role_specific
# go_to_locations_you_have_connection_with
# no_pedophilia
# 	References: romance
# family_ties
# 	References: mean, critical, kind, romance, thoughtful
# mean_to_people_you_dislike1
# 	References: mean
# mean_to_people_you_dislike2
# 	References: mean
# mean_to_people_you_dislike3
# 	References: mean
# nice_to_people_you_like1
# 	References: mean
# people_are_usually_serious
# 	References: silly
# fail_when_interactin_with_person_who_dislikes_you1
# 	References: failure
# fail_when_interactin_with_person_who_dislikes_you2
# 	References: failure
# people_joke_with_joker
# 	References: silly
# likes
# loves
# respects
# rivalry
# dissapointed_in
# proud_of
# embarrassed_by
# protective_of
# friends_with
# happiness
# anger
# tiredness
# sadness
# guilt
# shame
# self_worth
# Starting New Step: Initializing from fantasy_setting.init

# %%
print(sequence.active_module.pretty_print_history())

# %%
print(sequence.active_module.display_relationships())

# %%
print(len(sequence.active_module.population))
import json
with open('population.json','w') as outfile:
    outfile.write(json.dumps(sequence.active_module.to_json(), sort_keys=True, indent=4))

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.array(
    [[1600,160,49.2],
        [800,80,29.7],
        [400,80,20],
        [400,40,19.6],
        [200,20,14.7],
        [100,10,12.7],
        [40, 2,9.31],
        [20, 2,8.42],
        [10, 10,6.94],
        [10, 1, 7.05]])
plt.plot(data[:,0],data[:,2],'bx')
print(data[:,2]/data[:,0])

# %%
sequence.active_module.to_json()

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_location_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp -t 8

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_location_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp -t 8

# %%
print(sequence.active_module.display_traits(ignore_default_traits=True))

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_location_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp -t 8
