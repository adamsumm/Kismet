# %%
if False:
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet.ebnv
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_initialization.ebnf
    # !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_sequence.ebnf

# %%
import KismetSequence

# %%
sequence = KismetSequence.KismetSequence(sequence_file = 'gtbbt.seq')#'gtbbt.seq')
# Out:
# SEQUENCE STATEMENT [('Load', [('File', 'fantasy_broad.kismet'), ('TRACERY', []), ('File', '../tracery/fantasy.tracery')])]
# SEQUENCE STATEMENT [('Initialize', [('File', 'fantasy_setting.init')])]
# INITIALIZATION []
# SEQUENCE STATEMENT [('Run', [('Until', [('UntilClauses', [('Duration', [('Num', '10'), ('Name', 'steps')])])])])]

# %%
# %%time
from IPython.display import clear_output


clear_output(wait=True)
sequence()
# Out:
# Running Kismet Sequence from "gtbbt.seq"
# Starting New Step: Loading ['fantasy_broad.kismet'] with Tracery Files ['../tracery/fantasy.tracery']
# *************************POTENTIAL PROBLEMS*************************
# Locations: Not referenced in actions or traits
# 	ruins
# 	dungeon
# 	library
# 	throne_room
# 	boat
# 	tavern
# 	opera_house
# 	mine
# 	kitchen
# 	elders_house
# 	shipyard
# 	garden
# 	thieves_den
# 	classroom
# 	amphitheatre
# 	auction_house
# 	ballroom
# 	smith
# 	temple
# 	marketplace
# 	quad
# 	docks
# Tags: Not referenced in traits
# 	mariner
# 	criminal
# 	criticial
# 	angry
# 	work
# Tags: Referenced in traits but not found in actions
# 	agree
# Traits: Not referenced in actions
# 	do_more_specific_things
# 	rare_things_rare
# 	visiting_places_you_like
# 	family_ties
# 	stern
# 	family_oriented
# 	proud_of
# 	neurotic
# 	nice_to_people_you_like1
# 	introvert
# 	protective_of
# 	careless
# 	fail_when_interactin_with_person_who_dislikes_you1
# 	stay_in_confinement
# 	mean_to_people_you_dislike1
# 	no_pedophilia
# 	friends_with
# 	free_spirited
# 	extrovert
# 	mean_to_people_you_dislike3
# 	romantic_towards_crush
# 	people_joke_with_joker
# 	feral
# 	carer
# 	cautious
# 	rivalry
# 	guilt
# 	curious
# 	critical
# 	stay_at_hometown
# 	romantic
# 	ignoramus
# 	dissapointed_in
# 	people_are_usually_serious
# 	conscientious
# 	sadness
# 	gruff
# 	embarrassed_by
# 	fail_when_interactin_with_person_who_dislikes_you2
# 	visiting_as_regular
# 	mean_to_people_you_dislike2
# 	comic
# 	confident
# Traits: Referenced in actions but not found
# 	plotting_against
# 	coworker
# 	worker
# 	fealty
# 	free_sprited
# 	rich
# 	knows_personal_info_about
# 	student
# 	child
# 	patron
# 	royalty
# 	auctioneer
# 	diva
# 	researcher
# 	rival
# 	employee
# 	tourist
# 	crushing_on
# 	ex_royalty
# 	guest
# 	fears
# 	sibling
# 	devotion
# 	hometown
# 	important
# 	spy
# *************************Reference Section*************************
# Actions
# 	pine_over
# 	strike_motherlode
# 	play_together
# 	amuse_with_performance
# 	support_banished_sibling
# 	hustle
# 	assist_student
# 	argue_about_duty
# 	undercut
# 	hold_boring_lecture
# 	bitch_about_boss_to_resistance
# 	flirt_at
# 	cast_ur_job
# 	standup_to_enforcer_together
# 	cast_dockworker
# 	try_to_help_struggling_friend
# 	joke_around_with
# 	acquire_artifacts
# 	impress
# 	commiserate_with_fellow_vendor
# 	assist_research
# 	share_personal_info
# 	shun_banished_sibling
# 	insult
# 	rough_up
# 	screw_up_ritual
# 	sabotage_rival_treasure_hunter
# 	praise_boss_to_resistance
# 	perform_to_no_effect
# 	cast_enforcer
# 	mentor_cook
# 	overcome_rivalry_to_work_together
# 	convince_importance_of_duty
# 	cast_archaelogist
# 	grouse_backstage
# 	discuss_collection
# 	boss_miner_around
# 	have_crisis_of_faith
# 	boss_cooks_around
# 	search_for_treasure
# 	make_judicious_decree
# 	develop_crush
# 	plot_about_sabotaging_romantic_rival
# 	blow_up_love_triangle
# 	play
# 	have_catharsis
# 	cast_curator
# 	be_open_about_crush_and_burn
# 	develop_begrudging_respect_towards
# 	cast_librarian
# 	acquire_ingredients
# 	provide_critical_feedback
# 	stand_up_for_friend_and_fail
# 	get_into_argument
# 	make_out_with
# 	sulk
# 	cast_vendor
# 	encourage_fellow_performer
# 	worry_about_mortality
# 	give_deal_to
# 	flirt_with
# 	criticize
# 	complain_to_compassionate
# 	help_struggling_friend
# 	make_imprudent_decree
# 	try_to_impress_and_fail
# 	stock_books
# 	sway_monarch_to_indifference
# 	be_open_about_crush
# 	cast_chancellor
# 	sway_monarch_to_kindness
# 	make_callous_decree
# 	curate_collection
# 	investigate_ruins
# 	perform_ritual
# 	bitch_about_boss
# 	reject_romance
# 	cast_treasure_hunter
# 	cast_bard
# 	cast_spy_master
# 	shush_patron
# 	worry_about_future
# 	make_benevolent_decree
# 	manage_dispute_between_miners
# 	be_amused_by_bard
# 	cast_monarch
# 	hold_lecture
# 	hold_auction
# 	find_treasure
# 	cast_professor
# 	develop_recipe
# 	insult_as_bully
# 	conspire_against
# 	create_culinary_masterpiece
# 	help_really_struggling_person
# 	use_humor_to_spark_love
# 	catalog_findings
# 	trigger_trap
# 	endanger_miners
# 	complain_to_and_make_annoyed
# 	pray
# 	sell_wares
# 	stand_up_for_friend_and_persuade
# 	joke_around_with_the_wrong_person
# 	argue_with_treasure_hunter
# 	consult_with_chancellor
# 	argue_with_playmate
# 	send_underlings
# 	cast_miner
# 	annoy_diva_for_laughs
# 	cast_monk
# 	manage_mine
# 	become_annoyed_with_bard
# 	chit_chat
# 	collect_protection_fees
# 	cast_foreman
# 	perform_research
# 	praise_boss
# 	fight_seagull
# 	work_at_mine
# 	banish_monarchling
# 	cast_chef
# 	demand_a_new_piece
# 	load_cargo
# Patterns
# 	dislikes_friend
# 		 referenced in: stand_up_for_friend_and_fail, stand_up_for_friend_and_persuade
# 	non_joker
# 		 referenced in: joke_around_with_the_wrong_person
# Roles
# 	foreman
# 		 referenced in: strike_motherlode, boss_miner_around, cast_foreman, manage_dispute_between_miners, endanger_miners, manage_mine
# 	spy_master
# 		 referenced in: send_underlings, conspire_against, cast_spy_master
# 	librarian
# 		 referenced in: assist_research, shush_patron, cast_librarian, assist_student, stock_books
# 	dockworker
# 		 referenced in: cast_dockworker, load_cargo, fight_seagull
# 	chef
# 		 referenced in: develop_recipe, cast_chef, mentor_cook, boss_cooks_around, acquire_ingredients, create_culinary_masterpiece
# 	chancellor
# 		 referenced in: sway_monarch_to_indifference, consult_with_chancellor, sway_monarch_to_kindness, cast_chancellor
# 	miner
# 		 referenced in: work_at_mine, strike_motherlode, cast_miner, boss_miner_around, manage_dispute_between_miners, endanger_miners
# 	treasure_hunter
# 		 referenced in: find_treasure, argue_with_treasure_hunter, develop_begrudging_respect_towards, search_for_treasure, trigger_trap, sabotage_rival_treasure_hunter, cast_treasure_hunter, overcome_rivalry_to_work_together
# 	vendor
# 		 referenced in: give_deal_to, commiserate_with_fellow_vendor, sell_wares, collect_protection_fees, hustle, rough_up, standup_to_enforcer_together, cast_vendor, acquire_ingredients, undercut
# 	bard
# 		 referenced in: perform_to_no_effect, grouse_backstage, amuse_with_performance, cast_bard, be_amused_by_bard, annoy_diva_for_laughs, encourage_fellow_performer, become_annoyed_with_bard
# 	monk
# 		 referenced in: pray, have_crisis_of_faith, perform_ritual, screw_up_ritual, cast_monk
# 	ur_job
# 		 referenced in: cast_chancellor, cast_professor, cast_enforcer, cast_bard, cast_spy_master, cast_curator, cast_chef, cast_miner, cast_foreman, cast_ur_job, cast_librarian, cast_dockworker, cast_vendor, cast_monarch, cast_treasure_hunter, cast_monk, cast_archaelogist
# 	archaelogist
# 		 referenced in: investigate_ruins, argue_with_treasure_hunter, catalog_findings, develop_begrudging_respect_towards, cast_archaelogist
# 	professor
# 		 referenced in: perform_research, cast_professor, hold_lecture, hold_boring_lecture
# 	enforcer
# 		 referenced in: collect_protection_fees, cast_enforcer, rough_up
# 	monarch
# 		 referenced in: sway_monarch_to_indifference, banish_monarchling, sway_monarch_to_kindness, make_callous_decree, consult_with_chancellor, make_benevolent_decree, make_imprudent_decree, make_judicious_decree, cast_monarch
# 	curator
# 		 referenced in: curate_collection, cast_curator, discuss_collection, demand_a_new_piece, acquire_artifacts
# Tags
# 	worry
# 		 referenced in: confident, neurotic
# 	free
# 		 referenced in: free_spirited, duty_bound
# 	risky
# 		 referenced in: curious, cautious, feral
# 	bold
# 		 referenced in: confident, neurotic
# 	duty
# 		 referenced in: free_spirited, duty_bound
# 	religious
# 		 referenced in: feral
# 	kind
# 		 referenced in: family_ties, carer, family_oriented, bully, indifferent, compassionate
# 	failure
# 		 referenced in: fail_when_interactin_with_person_who_dislikes_you1, fail_when_interactin_with_person_who_dislikes_you2
# 	scholarly
# 		 referenced in: ignoramus, scholar
# 	silly
# 		 referenced in: people_are_usually_serious, stern, people_joke_with_joker, comic
# 	specific
# 		 referenced in: do_more_specific_things
# 	thoughtful
# 		 referenced in: family_ties, conscientious, comic, family_oriented, stern, indifferent, compassionate, careless
# 	mean
# 		 referenced in: mean_to_people_you_dislike1, mean_to_people_you_dislike3, family_ties, mean_to_people_you_dislike2, nice_to_people_you_like1, carer, family_oriented, bully, indifferent, compassionate
# 	romance
# 		 referenced in: family_ties, no_pedophilia, romantic_towards_crush, romantic
# 	rare
# 		 referenced in: rare_things_rare
# 	agree
# 		 referenced in: critical, gruff, agreeable
# 	talk
# 		 referenced in: extrovert, feral, introvert
# Traits
# 	rare_things_rare
# 	worker
# 		 referenced in: boss_cooks_around, mentor_cook
# 	family_ties
# 	fealty
# 		 referenced in: make_benevolent_decree, make_imprudent_decree, make_callous_decree, make_judicious_decree
# 	free_sprited
# 		 referenced in: argue_about_duty, convince_importance_of_duty
# 	child
# 		 referenced in: banish_monarchling
# 	mean_to_people_you_dislike3
# 	people_joke_with_joker
# 	carer
# 	auctioneer
# 		 referenced in: hold_auction, demand_a_new_piece
# 	cautious
# 	rivalry
# 	tiredness
# 		 referenced in: work_at_mine, perform_to_no_effect, stock_books, worry_about_future, search_for_treasure, worry_about_mortality, load_cargo
# 	hometown
# 		 referenced in: banish_monarchling
# 	mean_to_people_you_dislike2
# 	like
# 	plotting_against
# 		 referenced in: send_underlings, conspire_against
# 	family_oriented
# 	neurotic
# 	nice_to_people_you_like1
# 	careless
# 		 referenced in: conscientious, careless
# 	no_pedophilia
# 	student
# 		 referenced in: hold_lecture, assist_student, hold_boring_lecture
# 	friends_with
# 	free_spirited
# 	extrovert
# 	patron
# 		 referenced in: hold_auction
# 	feral
# 	respects
# 		 referenced in: strike_motherlode, discuss_collection, manage_dispute_between_miners, endanger_miners, sabotage_rival_treasure_hunter, create_culinary_masterpiece
# 	royalty
# 		 referenced in: shun_banished_sibling, support_banished_sibling, banish_monarchling
# 	diva
# 		 referenced in: annoy_diva_for_laughs
# 	guilt
# 	researcher
# 	curious
# 	stay_at_hometown
# 	romantic
# 	sadness
# 	crushing_on
# 		 referenced in: use_humor_to_spark_love, be_open_about_crush, develop_crush, be_open_about_crush_and_burn
# 	embarrassed_by
# 	ex_royalty
# 		 referenced in: shun_banished_sibling, support_banished_sibling, banish_monarchling
# 	fears
# 		 referenced in: standup_to_enforcer_together, rough_up
# 	happiness
# 		 referenced in: play_together, argue_with_playmate, worry_about_mortality, create_culinary_masterpiece, play
# 	ignoramus
# 	do_more_specific_things
# 	stern
# 	bully
# 		 referenced in: insult, insult_as_bully
# 	indifferent
# 		 referenced in: sway_monarch_to_indifference, sway_monarch_to_kindness
# 	knows_personal_info_about
# 		 referenced in: share_personal_info
# 	rich
# 		 referenced in: find_treasure
# 	introvert
# 	protective_of
# 	mean_to_people_you_dislike1
# 	loves
# 		 referenced in: be_open_about_crush, flirt_with, pine_over, use_humor_to_spark_love, flirt_at, make_out_with, be_open_about_crush_and_burn, reject_romance, plot_about_sabotaging_romantic_rival, blow_up_love_triangle
# 	age
# 		 referenced in: banish_monarchling, play_together, argue_with_playmate, worry_about_future, worry_about_mortality, play
# 	rival
# 		 referenced in: develop_begrudging_respect_towards, argue_with_treasure_hunter, sabotage_rival_treasure_hunter, overcome_rivalry_to_work_together
# 	critical
# 		 referenced in: critical, gruff, agreeable, family_ties
# 	duty_bound
# 		 referenced in: argue_about_duty, convince_importance_of_duty
# 	guest
# 		 referenced in: shush_patron, create_culinary_masterpiece, assist_research
# 	compassionate
# 		 referenced in: sway_monarch_to_indifference, sway_monarch_to_kindness, complain_to_and_make_annoyed, complain_to_compassionate
# 	scholar
# 		 referenced in: assist_research
# 	devotion
# 		 referenced in: perform_ritual, screw_up_ritual, pray, have_crisis_of_faith
# 	important
# 		 referenced in: conspire_against
# 	confident
# 	self_worth
# 		 referenced in: strike_motherlode, complain_to_compassionate, help_struggling_friend, trigger_trap, create_culinary_masterpiece, try_to_impress_and_fail, amuse_with_performance, stand_up_for_friend_and_persuade, hustle, have_crisis_of_faith, reject_romance, assist_student, annoy_diva_for_laughs, undercut, hold_boring_lecture, have_catharsis, be_open_about_crush_and_burn, perform_research, try_to_help_struggling_friend, acquire_artifacts, hold_lecture, stand_up_for_friend_and_fail, hold_auction, find_treasure, impress, insult_as_bully, develop_recipe, assist_research, insult, sulk, help_really_struggling_person
# 	spy
# 		 referenced in: send_underlings
# 	anger
# 		 referenced in: fight_seagull
# 	visiting_places_you_like
# 	coworker
# 		 referenced in: bitch_about_boss_to_resistance, praise_boss_to_resistance, bitch_about_boss, praise_boss
# 	proud_of
# 	fail_when_interactin_with_person_who_dislikes_you1
# 	stay_in_confinement
# 	romantic_towards_crush
# 	employee
# 		 referenced in: bitch_about_boss_to_resistance, praise_boss_to_resistance, bitch_about_boss, praise_boss
# 	tourist
# 		 referenced in: amuse_with_performance, be_amused_by_bard, become_annoyed_with_bard
# 	dissapointed_in
# 	people_are_usually_serious
# 	conscientious
# 	shame
# 		 referenced in: shush_patron, reject_romance
# 	gruff
# 	likes
# 		 referenced in: give_deal_to, flirt_with, criticize, use_humor_to_spark_love, strike_motherlode, play_together, complain_to_compassionate, help_struggling_friend, make_imprudent_decree, endanger_miners, mentor_cook, try_to_impress_and_fail, complain_to_and_make_annoyed, sabotage_rival_treasure_hunter, overcome_rivalry_to_work_together, convince_importance_of_duty, be_open_about_crush, grouse_backstage, amuse_with_performance, sell_wares, stand_up_for_friend_and_persuade, make_callous_decree, joke_around_with_the_wrong_person, argue_with_treasure_hunter, consult_with_chancellor, support_banished_sibling, hustle, boss_miner_around, argue_with_playmate, boss_cooks_around, bitch_about_boss, reject_romance, assist_student, argue_about_duty, annoy_diva_for_laughs, make_judicious_decree, plot_about_sabotaging_romantic_rival, blow_up_love_triangle, undercut, hold_boring_lecture, become_annoyed_with_bard, bitch_about_boss_to_resistance, chit_chat, flirt_at, collect_protection_fees, shush_patron, develop_begrudging_respect_towards, standup_to_enforcer_together, make_benevolent_decree, manage_dispute_between_miners, be_amused_by_bard, acquire_ingredients, try_to_help_struggling_friend, joke_around_with, praise_boss, provide_critical_feedback, hold_lecture, stand_up_for_friend_and_fail, banish_monarchling, impress, insult_as_bully, commiserate_with_fellow_vendor, get_into_argument, assist_research, share_personal_info, conspire_against, shun_banished_sibling, insult, make_out_with, rough_up, encourage_fellow_performer, screw_up_ritual, demand_a_new_piece, praise_boss_to_resistance, help_really_struggling_person
# 	love
# 	fail_when_interactin_with_person_who_dislikes_you2
# 	sibling
# 		 referenced in: shun_banished_sibling, support_banished_sibling
# 	visiting_as_regular
# 	comic
# 	agreeable
# 		 referenced in: provide_critical_feedback
# Requirements:
# chit_chat
# complain_to_and_make_annoyed
# 	References: compassionate
# complain_to_compassionate
# 	References: compassionate
# flirt_at
# flirt_with
# use_humor_to_spark_love
# be_open_about_crush
# 	References: loves, crushing_on
# be_open_about_crush_and_burn
# 	References: loves, crushing_on
# develop_crush
# pine_over
# make_out_with
# 	References: love
# blow_up_love_triangle
# 	References: love
# plot_about_sabotaging_romantic_rival
# 	References: love
# reject_romance
# 	References: likes, loves
# insult_as_bully
# 	References: bully
# insult
# 	References: bully
# sulk
# 	References: self_worth
# have_catharsis
# 	References: self_worth
# try_to_help_struggling_friend
# 	References: likes, self_worth
# help_struggling_friend
# 	References: like, self_worth
# share_personal_info
# help_really_struggling_person
# 	References: self_worth
# joke_around_with
# joke_around_with_the_wrong_person
# 	References: non_joker
# criticize
# provide_critical_feedback
# 	References: agreeable
# get_into_argument
# 	References: likes
# impress
# try_to_impress_and_fail
# stand_up_for_friend_and_persuade
# 	References: dislikes_friend
# stand_up_for_friend_and_fail
# 	References: dislikes_friend
# pray
# 	References: monk
# perform_ritual
# 	References: monk
# screw_up_ritual
# 	References: monk
# have_crisis_of_faith
# 	References: monk
# manage_mine
# 	References: foreman
# boss_miner_around
# 	References: foreman, miner
# manage_dispute_between_miners
# 	References: foreman, miner, likes
# endanger_miners
# 	References: foreman, miner
# strike_motherlode
# 	References: foreman, miner
# work_at_mine
# 	References: miner
# hold_auction
# 	References: patron, auctioneer
# discuss_collection
# 	References: curator
# demand_a_new_piece
# 	References: curator, auctioneer
# curate_collection
# 	References: curator
# acquire_artifacts
# 	References: curator
# sell_wares
# 	References: vendor
# give_deal_to
# 	References: likes, vendor
# hustle
# 	References: likes, vendor
# commiserate_with_fellow_vendor
# 	References: vendor
# undercut
# 	References: likes, vendor
# standup_to_enforcer_together
# 	References: vendor, fears
# collect_protection_fees
# 	References: enforcer, vendor
# rough_up
# 	References: enforcer, vendor
# load_cargo
# 	References: dockworker
# fight_seagull
# 	References: dockworker
# stock_books
# 	References: librarian
# shush_patron
# 	References: librarian, guest
# assist_research
# 	References: scholar, librarian, guest
# assist_student
# 	References: student, librarian
# acquire_ingredients
# 	References: chef, vendor
# develop_recipe
# 	References: chef
# boss_cooks_around
# 	References: chef, worker
# mentor_cook
# 	References: chef, worker
# create_culinary_masterpiece
# 	References: chef, guest
# bitch_about_boss
# 	References: coworker, employee
# bitch_about_boss_to_resistance
# 	References: likes, coworker, employee
# praise_boss
# 	References: likes, coworker, employee
# praise_boss_to_resistance
# 	References: likes, coworker, employee
# search_for_treasure
# 	References: treasure_hunter
# find_treasure
# 	References: treasure_hunter
# investigate_ruins
# 	References: archaelogist
# trigger_trap
# 	References: treasure_hunter
# sabotage_rival_treasure_hunter
# 	References: rival, treasure_hunter
# overcome_rivalry_to_work_together
# 	References: rival, treasure_hunter
# catalog_findings
# 	References: archaelogist
# argue_with_treasure_hunter
# 	References: rival, treasure_hunter, archaelogist
# develop_begrudging_respect_towards
# 	References: rival, treasure_hunter, archaelogist
# perform_to_no_effect
# 	References: bard
# amuse_with_performance
# 	References: tourist, bard
# grouse_backstage
# 	References: bard
# encourage_fellow_performer
# 	References: bard
# annoy_diva_for_laughs
# 	References: likes, diva, bard
# become_annoyed_with_bard
# 	References: bard, tourist
# be_amused_by_bard
# 	References: bard, tourist
# make_judicious_decree
# 	References: fealty, monarch
# make_imprudent_decree
# 	References: fealty, monarch
# make_callous_decree
# 	References: fealty, monarch
# make_benevolent_decree
# 	References: fealty, monarch
# banish_monarchling
# 	References: age, child, monarch, royalty, likes
# consult_with_chancellor
# 	References: chancellor, monarch
# sway_monarch_to_kindness
# 	References: chancellor, monarch
# sway_monarch_to_indifference
# 	References: chancellor, monarch
# support_banished_sibling
# 	References: ex_royalty, royalty, sibling
# shun_banished_sibling
# 	References: ex_royalty, royalty, sibling
# play
# 	References: age
# play_together
# 	References: age
# argue_with_playmate
# 	References: age
# worry_about_future
# 	References: age
# worry_about_mortality
# 	References: age
# argue_about_duty
# 	References: free_sprited, duty_bound
# convince_importance_of_duty
# 	References: free_sprited, duty_bound
# hold_lecture
# 	References: student, professor
# hold_boring_lecture
# 	References: student, professor
# perform_research
# 	References: professor
# conspire_against
# 	References: spy_master, important
# send_underlings
# 	References: spy_master, plotting_against, spy
# cast_ur_job
# 	References: ur_job
# cast_monk
# 	References: ur_job
# cast_foreman
# 	References: ur_job
# cast_miner
# 	References: ur_job
# cast_curator
# 	References: ur_job
# cast_vendor
# 	References: ur_job
# cast_enforcer
# 	References: ur_job
# cast_dockworker
# 	References: ur_job
# cast_librarian
# 	References: ur_job
# cast_chef
# 	References: ur_job
# cast_treasure_hunter
# 	References: ur_job
# cast_archaelogist
# 	References: ur_job
# cast_bard
# 	References: ur_job
# cast_monarch
# 	References: ur_job
# cast_chancellor
# 	References: ur_job
# cast_professor
# 	References: ur_job
# cast_spy_master
# 	References: ur_job
# introvert
# 	References: talk
# extrovert
# 	References: talk
# curious
# 	References: risky
# cautious
# 	References: risky
# bully
# 	References: mean, kind
# carer
# 	References: mean, kind
# scholar
# 	References: scholarly
# ignoramus
# 	References: scholarly
# conscientious
# 	References: thoughtful, careless
# careless
# 	References: thoughtful, careless
# agreeable
# 	References: critical, agree
# critical
# 	References: critical, agree
# compassionate
# 	References: thoughtful, mean, kind
# indifferent
# 	References: thoughtful, mean, kind
# neurotic
# 	References: worry, bold
# confident
# 	References: worry, bold
# family_oriented
# 	References: thoughtful, mean, kind
# duty_bound
# 	References: duty, free
# free_spirited
# 	References: duty, free
# romantic
# 	References: romance
# gruff
# 	References: critical, agree
# feral
# 	References: religious, talk, risky
# comic
# 	References: thoughtful, silly
# stern
# 	References: thoughtful, silly
# rare_things_rare
# 	References: rare
# do_more_specific_things
# 	References: specific
# stay_in_confinement
# visiting_places_you_like
# visiting_as_regular
# romantic_towards_crush
# 	References: romance
# stay_at_hometown
# no_pedophilia
# 	References: romance
# family_ties
# 	References: thoughtful, mean, critical, romance, kind
# mean_to_people_you_dislike1
# 	References: mean
# mean_to_people_you_dislike2
# 	References: mean
# mean_to_people_you_dislike3
# 	References: mean
# nice_to_people_you_like1
# 	References: mean
# people_are_usually_serious
# 	References: silly
# fail_when_interactin_with_person_who_dislikes_you1
# 	References: failure
# fail_when_interactin_with_person_who_dislikes_you2
# 	References: failure
# people_joke_with_joker
# 	References: silly
# likes
# loves
# respects
# rivalry
# dissapointed_in
# proud_of
# embarrassed_by
# protective_of
# friends_with
# happiness
# anger
# tiredness
# sadness
# guilt
# shame
# self_worth
# Starting New Step: Initializing from fantasy_setting.init
# *************************POTENTIAL PROBLEMS BETWEEN INIT AND KISMET*************************
# Traits: Referenced in initialization but not found
# 	captain
# 	victim
# 	high_priest
# 	sailor
# 	worker
# 	pronouns
# 	pickpocket
# 	fealty
# 	rich
# 	barkeep
# 	citizen
# 	regular
# 	presentation
# 	child
# 	criminal
# 	auctioneer
# 	prostitute
# 	believer
# 	ship_builder
# 	guard
# 	spouse
# 	rival
# 	last_birthday
# 	owner
# 	tutor
# 	elder
# 	follower
# 	smith_apprentice
# 	guest
# 	confined
# 	priest
# 	hometown
# 	important
# 	vocation
# 	spy
# 	ruler
# 	coworker
# 	related_to
# 	student
# 	artist
# 	skin
# 	impresario
# 	patron
# 	royalty
# 	scared
# 	thief
# 	diva
# 	researcher
# 	employee
# 	tourist
# 	engineer
# 	master_thief
# 	mariner
# 	fisher
# 	servant
# 	drinker
# 	sibling
# 	boss
# 	parent
# 	smithy
# Starting New Step: Running...
# [('season', 'summer'), ('year', 1027)]
# [('season', 'fall'), ('year', 1027)]
# [('season', 'winter'), ('year', 1028)]
# [('season', 'spring'), ('year', 1028)]
# [('season', 'summer'), ('year', 1028)]
# [('season', 'fall'), ('year', 1028)]
# [('season', 'winter'), ('year', 1029)]
# [('season', 'spring'), ('year', 1029)]
# [('season', 'summer'), ('year', 1029)]

# %%
print(sequence.active_module.pretty_print_history())

# %%
print(sequence.active_module.display_relationships())

# %%
print(len(sequence.active_module.population))
import json
with open('population.json','w') as outfile:
    outfile.write(json.dumps(sequence.active_module.to_json(), sort_keys=True, indent=4))

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.array(
    [[1600,160,49.2],
        [800,80,29.7],
        [400,80,20],
        [400,40,19.6],
        [200,20,14.7],
        [100,10,12.7],
        [40, 2,9.31],
        [20, 2,8.42],
        [10, 10,6.94],
        [10, 1, 7.05]])
plt.plot(data[:,0],data[:,2],'bx')
print(data[:,2]/data[:,0])

# %%
sequence.active_module.to_json()

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_location_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp -t 8

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_location_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_action_rules.lp -t 8

# %%
print(sequence.active_module.display_traits(ignore_default_traits=True))

# %%
# !clingo C:\Users\adams\Documents\Research\Kismet\kismet\default.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_location_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_pattern_rules.lp C:\Users\adams\Documents\Research\Kismet\kismet\fantasy_broad.kismet_conglomeration.kismet_population.lp C:\Users\adams\Documents\Research\Kismet\kismet\location_volition.lp -t 8
