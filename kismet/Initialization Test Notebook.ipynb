# %%
# !java -jar antlr-4.7.2-complete.jar -visitor -Dlanguage=Python3 kismet_initialization.ebnf

# %%
from Kismet import *
import KismetInitialization

# %%
kismetModule = KismetModule(['test.kismet'],'kismet_CultTown.init',['../tracery/edwardian.tracery'], 
                                    ignore_logit=3.0, 
                                    observation_temp=1.5,
                                    history_cutoff=10,
                                    action_budget = 3,
                                    default_cost = 3,)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4e6c5f45485b> in <module>
# ----> 1 kismetModule = KismetModule(['test.kismet'],'kismet_CultTown.init',['../tracery/edwardian.tracery'],
#       2                                     ignore_logit=3.0,
#       3                                     observation_temp=1.5,
#       4                                     history_cutoff=10,
#       5                                     action_budget = 3,
#
# ~\Documents\Research\Kismet\kismet\Kismet.py in __init__(self, module_files, tracery_files, temperature, observation_temp, ignore_logit, history_cutoff, action_budget, default_cost, clingo_exe, base_folder)
#    1324         self.tracery_grammar = {}
#    1325         for f in tracery_files:
# -> 1326             grammar = json.load(open(f,'r'))
#    1327             for key in grammar:
#    1328                 if key not in self.tracery_grammar:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'k'

# %%
kismetModule.make_population()

# %%
print(kismetModule.population)
# Out:
# {'damian_blackton': {'name': 'Damian Blackton', 'asp_name': 'damian_blackton', 'traits': {'violent', 'religious', 'snoopy'}, 'status': {('old',): None, ('angry',): 2, ('parent', 'petronia_blackton'): None, ('parent', 'mervyn_blackton'): None, ('parent', 'elaine_blackton'): None, ('parent', 'ursula_blackton'): None, ('parent', 'sibyl_blackton'): None, ('married', 'harold_blackton'): None, ('likes', 'harold_blackton'): 5, ('age',): 40, ('likes', 'damian_blackton'): 0, ('likes', 'petronia_blackton'): 0, ('likes', 'mervyn_blackton'): 0, ('likes', 'elaine_blackton'): 0, ('likes', 'ursula_blackton'): 0, ('likes', 'sibyl_blackton'): 0, ('likes', 'patrick_colefield'): 0, ('likes', 'constant_colefield'): 0, ('likes', 'oliver_colefield'): 0, ('likes', 'elise_alfling'): 0, ('likes', 'zoe_alfling'): 0, ('likes', 'gaston_alfling'): 0, ('likes', 'ernestine_alfling'): 0, ('likes', 'claud_alfling'): 0, ('likes', 'guy_alfling'): 0, ('likes', 'mercy_alfling'): 0, ('likes', 'pleasance_wimpleton'): 0, ('likes', 'florentina_wimpleton'): 0, ('likes', 'patricia_wimpleton'): 0, ('likes', 'ethelwyne_wimpleton'): 0, ('likes', 'rodolph_kirkstock'): 0, ('likes', 'catherine_kirkstock'): 0, ('likes', 'theobald_kirkstock'): 0, ('likes', 'vivia_kirkstock'): 0, ('likes', 'leopold_kirkstock'): 0, ('likes', 'sara_kirkstock'): 0, ('likes', 'dunstan_kirkstock'): 0}}, 'harold_blackton': {'name': 'Harold Blackton', 'asp_name': 'harold_blackton', 'traits': {'drunkard', 'introvert', 'atheist', 'sad_drunk', 'violent'}, 'status': {('married', 'damian_blackton'): None, ('parent', 'petronia_blackton'): None, ('parent', 'mervyn_blackton'): None, ('parent', 'elaine_blackton'): None, ('parent', 'ursula_blackton'): None, ('parent', 'sibyl_blackton'): None, ('age',): 25, ('likes', 'damian_blackton'): 0, ('likes', 'harold_blackton'): 0, ('likes', 'petronia_blackton'): 0, ('likes', 'mervyn_blackton'): 0, ('likes', 'elaine_blackton'): 0, ('likes', 'ursula_blackton'): 0, ('likes', 'sibyl_blackton'): 0, ('likes', 'patrick_colefield'): 0, ('likes', 'constant_colefield'): 0, ('likes', 'oliver_colefield'): 0, ('likes', 'elise_alfling'): 0, ('likes', 'zoe_alfling'): 0, ('likes', 'gaston_alfling'): 0, ('likes', 'ernestine_alfling'): 0, ('likes', 'claud_alfling'): 0, ('likes', 'guy_alfling'): 0, ('likes', 'mercy_alfling'): 0, ('likes', 'pleasance_wimpleton'): 0, ('likes', 'florentina_wimpleton'): 0, ('likes', 'patricia_wimpleton'): 0, ('likes', 'ethelwyne_wimpleton'): 0, ('likes', 'rodolph_kirkstock'): 0, ('likes', 'catherine_kirkstock'): 0, ('likes', 'theobald_kirkstock'): 0, ('likes', 'vivia_kirkstock'): 0, ('likes', 'leopold_kirkstock'): 0, ('likes', 'sara_kirkstock'): 0, ('likes', 'dunstan_kirkstock'): 0}}, 'petronia_blackton': {'name': 'Petronia Blackton', 'asp_name': 'petronia_blackton', 'traits': {'sad_drunk', 'violent', 'extrovert'}, 'status': {('young',): None, ('child', 'harold_blackton'): None, ('child', 'damian_blackton'): None, ('age',): 5, ('likes', 'damian_blackton'): 0, ('likes', 'harold_blackton'): 0, ('likes', 'petronia_blackton'): 0, ('likes', 'mervyn_blackton'): 0, ('likes', 'elaine_blackton'): 0, ('likes', 'ursula_blackton'): 0, ('likes', 'sibyl_blackton'): 0, ('likes', 'patrick_colefield'): 0, ('likes', 'constant_colefield'): 0, ('likes', 'oliver_colefield'): 0, ('likes', 'elise_alfling'): 0, ('likes', 'zoe_alfling'): 0, ('likes', 'gaston_alfling'): 0, ('likes', 'ernestine_alfling'): 0, ('likes', 'claud_alfling'): 0, ('likes', 'guy_alfling'): 0, ('likes', 'mercy_alfling'): 0, ('likes', 'pleasance_wimpleton'): 0, ('likes', 'florentina_wimpleton'): 0, ('likes', 'patricia_wimpleton'): 0, ('likes', 'ethelwyne_wimpleton'): 0, ('likes', 'rodolph_kirkstock'): 0, ('likes', 'catherine_kirkstock'): 0, ('likes', 'theobald_kirkstock'): 0, ('likes', 'vivia_kirkstock'): 0, ('likes', 'leopold_kirkstock'): 0, ('likes', 'sara_kirkstock'): 0, ('likes', 'dunstan_kirkstock'): 0}}, 'mervyn_blackton': {'name': 'Mervyn Blackton', 'asp_name': 'mervyn_blackton', 'traits': {'snoopy', 'intro ...

# %%
from tqdm.notebook import tqdm 

for _ in tqdm(range(10)):
    kismetModule.step_actions()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
