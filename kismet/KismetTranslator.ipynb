# %%
import Translator

# %%
Translator.translate_to_felt('test.kismet')
# Out:
# befriend_enemy_of_enemy False
# 	 befriend_enemy_of_enemy Person, EnemyOfEnemy
# waste_time True
# 	 Person is lazy and just whiles the day away.
# drink_the_day_away True
# 	 Person is lazy and goes to the bar to drink the day away
# sober_up True
# 	 Person sobers up
# mingle True
# 	 Person and Other mingle with each other
# mingle_loudly True
# 	 Person and Other mingle loudly with each other
# gossip_about False
# 	 gossip_about Gossiper, Gossipee, GossipedAbout
# flirt True
# 	 Person flirts with Other
# sulk False
# 	 sulk Person
# slap True
# 	 Slapper [slaps|hits|strikes] Slapped in the face
# become_bartender True
# 	 [TheTender finds a job as a bartender|TheTender decided to become a barkeep]
# repair_location False
# 	 repair_location Initiator
# tend_bar True
# 	 The Tender serves drinks at their work.
# be_sneaky False
# 	 be_sneaky Sneaker
# barroom_brawl True
# 	 Initiator started a drunken brawl with Combatant
# disregard False
# 	 disregard Person, RudePerson
# ...
